# %% [markdown]
# <a href="https://colab.research.google.com/github/lockiultra/SCAMT/blob/main/MPNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install rdkit-pypi
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 54.7 MB/s eta 0:00:00

# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import re
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.Draw import MolsToGridImage

warnings.filterwarnings("ignore")
RDLogger.DisableLog("rdApp.*")

np.random.seed(42)
tf.random.set_seed(42)

# Featurizers

class Featurizer:
    def __init__(self, allowable_sets):
        self.dim = 0
        self.feature_mapping = {}
        for k, s in allowable_sets.items():
            s = sorted(list(s))
            self.feature_mapping[k] = dict(zip(s, range(self.dim, self.dim + len(s))))
            self.dim += len(s)

    def encode(self, inputs):
        output = np.zeros((self.dim,))
        for name_feature, feature_mapping in self.feature_mapping.items():
            feature = getattr(self, name_feature)(inputs)
            if feature not in feature_mapping:
                continue
            output[feature_mapping[feature]] = 1.0
        return output


class AtomFeaturizer(Featurizer):
    def __init__(self, allowable_sets):
        super().__init__(allowable_sets)

    def symbol(self, atom):
        return atom.GetSymbol()

    def n_valence(self, atom):
        return atom.GetTotalValence()

    def n_hydrogens(self, atom):
        return atom.GetTotalNumHs()

    def hybridization(self, atom):
        return atom.GetHybridization().name.lower()


class BondFeaturizer(Featurizer):
    def __init__(self, allowable_sets):
        super().__init__(allowable_sets)

    def encode(self, bond):
        output = np.zeros((self.dim,))
        if bond is None:
            output[-1] = 1.0
            return output
        output = super().encode(bond)
        return output

    def bond_type(self, bond):
        return bond.GetBondType().name.lower()

    def conjugated(self, bond):
        return bond.GetIsConjugated()
# Model

class EdgeNetwork(layers.Layer):
    def build(self, input_shape):
        self.atom_dim = input_shape[0][-1]
        self.bond_dim = input_shape[1][-1]
        self.kernel  = self.add_weight(
            shape=(self.bond_dim, self.atom_dim * self.atom_dim),
            initializer="glorot_uniform",
            name="kernel",
        )
        self.bias = self.add_weight(
            shape=(self.atom_dim * self.atom_dim),
            initializer="zeros",
            name="bias",
        )
        self.built = True

    def call(self, inputs):
        atom_features, bond_features, pair_indices = inputs
        bond_features = tf.matmul(bond_features, self.kernel) + self.bias
        bond_features = tf.reshape(bond_features, (-1, self.atom_dim, self.atom_dim))
        atom_features_neighbors = tf.gather(atom_features, pair_indices[:, 1])
        atom_features_neighbors = tf.expand_dims(atom_features_neighbors, axis=-1)
        transformed_features = tf.matmul(bond_features, atom_features_neighbors)
        transformed_features = tf.squeeze(transformed_features, axis=-1)
        aggregated_features = tf.math.unsorted_segment_sum(
            transformed_features,
            pair_indices[:, 0],
            num_segments=tf.shape(atom_features)[0]
        )
        return aggregated_features

class MessagePassing(layers.Layer):
    def __init__(self, units, steps=4, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.steps = steps

    def build(self, input_shape):
        self.atom_dim = input_shape[0][-1]
        self.message_step = EdgeNetwork()
        self.pad_length = max(0, self.units - self.atom_dim)
        self.update_step = layers.GRUCell(self.atom_dim + self.pad_length)
        self.built = True

    def call(self, inputs):
        atom_features, bond_features, pair_indices = inputs
        atom_features_updated = tf.pad(atom_features, [[0, 0], [self.pad_length, 0]])
        for i in range(self.steps):
            atom_features_aggregated = self.message_step([atom_features_updated, bond_features, pair_indices])
            atom_features_updated, _ = self.update_step(atom_features_aggregated, atom_features_updated)
        return atom_features_updated

class PartitionPadding(layers.Layer):
    def __init__(self, batch_size, **kwargs):
        super().__init__(**kwargs)
        self.batch_size = batch_size

    def call(self, inputs):
        atom_features, molecule_indicator = inputs
        atom_features_partitioned = tf.dynamic_partition(atom_features, molecule_indicator, self.batch_size)
        num_atoms = [tf.shape(x)[0] for x in atom_features_partitioned]
        max_num_atoms = tf.reduce_max(num_atoms)
        atom_features_stacked = tf.stack(
            [
                tf.pad(f, [(0, max_num_atoms - n), (0, 0)]) for f, n in zip(atom_features_partitioned, num_atoms)
            ],
            axis=0
        )
        gather_indices = tf.where(tf.reduce_sum(atom_features_stacked, (1, 2)) != 0)
        gather_indices = tf.squeeze(gather_indices, axis=-1)
        return tf.gather(atom_features_stacked, gather_indices, axis=0)

class TransformerEncoderReadout(layers.Layer):
    def __init__(self, num_heads=8, embed_dim=64, dense_dim=512, batch_size=32, **kwargs):
        super().__init__(**kwargs)
        self.partition_padding = PartitionPadding(batch_size)
        self.attention = layers.MultiHeadAttention(num_heads, embed_dim)
        self.dense_proj = keras.Sequential(
            [
                layers.Dense(dense_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.average_pooling = layers.GlobalAveragePooling1D()

    def call(self, inputs):
        x = self.partition_padding(inputs)
        padding_mask = tf.reduce_any(tf.not_equal(x, 0.0), axis=-1)
        padding_mask = padding_mask[:, tf.newaxis, tf.newaxis, :]
        attention_output = self.attention(x, x, attention_mask=padding_mask)
        proj_input = self.layernorm_1(x + attention_output)
        proj_output = self.layernorm_2(proj_input + self.dense_proj(proj_input))
        return self.average_pooling(proj_output)

def MPNNModel(atom_dim, bond_dim, batch_size=128, message_units=64, message_steps=4, num_attention_heads=8, dense_units=512):
    atom_features = layers.Input((atom_dim,), dtype=tf.float32, name="atom_features")
    bond_features = layers.Input((bond_dim,), dtype=tf.float32, name="bond_features")
    pair_indices = layers.Input((2,), dtype=tf.int32, name="pair_indices")
    molecule_indicator = layers.Input((), dtype=tf.int32, name="molecule_indicator")
    x = MessagePassing(message_units, message_steps)([atom_features, bond_features, pair_indices])
    x = TransformerEncoderReadout(num_attention_heads, message_units, dense_units, batch_size)([x, molecule_indicator])
    x = layers.Dense(dense_units, activation='elu')(x)
    x = layers.Dense(1, activation="sigmoid")(x)
    model = keras.Model(inputs=[atom_features, bond_features, pair_indices, molecule_indicator], outputs=[x])
    return model

# %%
class DiseasePipeline:
  def __init__(self, data: pd.DataFrame):
    self.diseases = data.Disease.unique()
    self.atom_featurizer = AtomFeaturizer(
      allowable_sets={
        "symbol": {'B', 'Br', 'C', 'Ca', 'Cl', 'F', 'H', 'I', 'N', 'Na', 'O', 'P', 'S'},
        "n_valence": {0, 1, 2, 3, 4, 5, 6},
        "n_hydrogens": {0, 1, 2, 3, 4},
        "hybridization": {'s', 'sp', 'sp2', 'sp3'},
      }
    )
    self.bond_featurizer = BondFeaturizer(
      allowable_sets={
        "bond_type": {'single', 'double', 'triple', 'aromatic'},
        "conjugated": {False, True},
      }
    )
    self.data = data.copy()
    self.curr_df = None
    self.x_train, self.y_train, self.x_val, self.y_val = self.__get_train_val_data(data)
    self.models = {disease: MPNNModel(atom_dim=self.x_train[0][0][0].shape[0], bond_dim=self.x_train[1][0][0].shape[0]) for disease in self.diseases}
    self.is_trained = False
    self.train_history = dict()

  def train(self):
    for i, disease in enumerate(self.diseases):
      print(f'\n({i}) ======={disease}=======\n')
      self.curr_df = self.data.copy()
      self.curr_df['Disease'] = self.curr_df['Disease'].replace({x: 1 if x == disease else 0 for x in self.diseases})
      self.curr_df = self.curr_df.drop_duplicates(subset=['Drug'])
      x_train, y_train, x_val, y_val = self.__get_train_val_data(self.curr_df)
      train_dataset = self.__get_dataset(x_train, y_train, disease)
      val_dataset = self.__get_dataset(x_val, y_val, disease)
      self.models[disease].compile(
        loss=keras.losses.BinaryCrossentropy(),
        optimizer=keras.optimizers.AdamW(learning_rate=3e-4),
        metrics=[keras.metrics.AUC(name='AUC')],
      )
      history = self.models[disease].fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=40,
        verbose=2,
      )
      self.train_history[disease] = history
    self.is_trained = True

  def predict(self, smiles):
    if not self.is_trained:
      print('Error! Model is not trained')
      return
    result = {disease: None for disease in self.diseases}
    g = self.graph_from_smiles(smiles)
    dataset = tf.data.Dataset.from_tensors(((g), (1))).map(self.prepare_batch, -1).prefetch(-1)
    for disease, model in zip(self.models.keys(), self.models.values()):
      result[disease] = model.predict(dataset)
    return result


  def __get_train_val_data(self, data):
    data = data.dropna()
    permutation = np.random.permutation(np.arange(data.shape[0]))
    train_index = permutation#[:int(data.shape[0] * 0.8)]
    x_train = self.graph_from_smiles(data.iloc[train_index].Smiles)
    y_train = data.iloc[train_index].Disease
    val_index = permutation[int(data.shape[0] * 0.8):]
    x_val = self.graph_from_smiles(data.iloc[val_index].Smiles)
    y_val = data.iloc[val_index].Disease
    return (x_train, y_train, x_val, y_val)

  def __get_dataset(self, X, y, curr_disease, batch_size=128, shuffle=False):
    # replace_disease_dict = {
    #   x: 1 if x == curr_disease else 0 for x in self.diseases
    # }
    # y = y.replace(replace_disease_dict)
    dataset = tf.data.Dataset.from_tensor_slices((X, (y)))
    if shuffle:
      dataset = dataset.shuffle(1024)
    return dataset.batch(batch_size).map(self.prepare_batch, -1).prefetch(-1)

  def prepare_batch(self, x_batch, y_batch):
    atom_features, bond_features, pair_indices = x_batch
    num_atoms = atom_features.row_lengths()
    num_bonds = bond_features.row_lengths()
    molecule_indices = tf.range(len(num_atoms))
    molecule_indicator = tf.repeat(molecule_indices, num_atoms)
    gather_indices = tf.repeat(molecule_indices[:-1], num_bonds[1:])
    increment = tf.cumsum(num_atoms[:-1])
    increment = tf.pad(tf.gather(increment, gather_indices), [(num_bonds[0], 0)])
    pair_indices = pair_indices.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    pair_indices = pair_indices + increment[:, tf.newaxis]
    atom_features = atom_features.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    bond_features = bond_features.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    return (atom_features, bond_features, pair_indices, molecule_indicator), y_batch

  def molecule_from_smiles(self, smiles):
    molecule = Chem.MolFromSmiles(smiles, sanitize=False)
    flag = Chem.SanitizeMol(molecule, catchErrors=True)
    if flag != Chem.SanitizeFlags.SANITIZE_NONE:
        Chem.SanitizeMol(molecule, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ flag)
    Chem.AssignStereochemistry(molecule, cleanIt=True, force=True)
    return molecule

  def graph_from_molecule(self, molecule):
      atom_features = []
      bond_features = []
      pair_indices = []
      for atom in molecule.GetAtoms():
          atom_features.append(self.atom_featurizer.encode(atom))
          pair_indices.append((atom.GetIdx(), atom.GetIdx()))
          bond_features.append(self.bond_featurizer.encode(None))
          for neighbor in atom.GetNeighbors():
              bond = molecule.GetBondBetweenAtoms(atom.GetIdx(), neighbor.GetIdx())
              pair_indices.append((atom.GetIdx(), neighbor.GetIdx()))
              bond_features.append(self.bond_featurizer.encode(bond))
      return np.array(atom_features), np.array(bond_features), np.array(pair_indices)

  def graph_from_smiles(self, smiles_list):
      atom_features_list = []
      bond_features_list = []
      pair_indices_list = []
      for smiles in smiles_list:
          molecule = self.molecule_from_smiles(smiles)
          atom_features, bond_features, pair_indices = self.graph_from_molecule(molecule)
          atom_features_list.append(atom_features)
          bond_features_list.append(bond_features)
          pair_indices_list.append(pair_indices)
      return (
          tf.ragged.constant(atom_features_list, dtype=tf.float32),
          tf.ragged.constant(bond_features_list, dtype=tf.float32),
          tf.ragged.constant(pair_indices_list, dtype=tf.int64),
      )

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#       Unnamed: 0                                         Conditions  \
# 0              0                       Metastatic Colorectal Cancer
# 1              1  Ulcerative Colitis|Left-sided Ulcerative Colit...
# 2              2  Ulcerative Colitis|Left-sided Ulcerative Colit...
# 3              5    HER-2 Positive Gastric Cancer|Metastatic Cancer
# 4              6    HER-2 Positive Gastric Cancer|Metastatic Cancer
# ...          ...                                                ...
# 4870        4211  Metastatic Renal Cell Cancer|Stage IV Renal Ce...
# 4871        4214  Interstitial Fibrosis|Kidney Transplant; Compl...
# 4872        4221                    Clear Cell Renal Cell Carcinoma
# 4873        4223          Cannabis|Chronic Kidney Diseases|Dialysis
# 4874        4225                                     Kidney Disease
#
#                Drug                                             Smiles  \
# 0        Irinotecan  CCC1=C2CN3C(=CC4=C(C3=O)COC(=O)C4(CC)O)C2=NC5=...
# 1        Mesalazine                            C1=CC(=C(C=C1N)C(=O)O)O
# 2        Mesalamine                            C1=CC(=C(C=C1N)C(=O)O)O
# 3      Capecitabine      CCCCCOC(=O)NC1=NC(=O)N(C=C1F)C2C(C(C(O2)C)O)O
# 4         Cisplatin                                       N.N.Cl[Pt]Cl
# ...             ...                                                ...
# 4870      Ibrutinib  C=CC(=O)N1CCCC(C1)N2C3=NC=NC(=C3C(=N2)C4=CC=C(...
# 4871     Fingolimod                  CCCCCCCCC1=CC=C(C=C1)CCC(CO)(CO)N
# 4872       Imatinib  CC1=C(C=C(C=C1)NC(=O)C2=CC=C(C=C2)CN3CCN(CC3)C...
# 4873     Dronabinol          CCCCCC1=CC(=C2C3C=C(CCC3C(OC2=C1)(C)C)C)O
# 4874  Bremelanotide  CCCCC(C(=O)NC1CC(=O)NCCCCC(NC(=O)C(NC(=O)C(NC(...
#
#                  Study Status         Phases                   Disease
# 0                   COMPLETED  PHASE1|PHASE2  digestive_system_disease
# 1                     UNKNOWN         PHASE2  digestive_system_disease
# 2                     UNKNOWN         PHASE2  digestive_system_disease
# 3                     UNKNOWN         PHASE2  digestive_system_disease
# 4                     UNKNOWN         PHASE2  digestive_system_disease
# ...                       ...            ...                       ...
# 4870                COMPLETED  PHASE1|PHASE2    urinary_system_disease
# 4871  ENROLLING_BY_INVITATION         PHASE2    urinary_system_disease
# 4872                COMPLETED  PHASE1|PHASE2    urinary_system_disease
# 4873               RECRUITING         PHASE1    urinary_system_disease
# 4874               RECRUITING         PHASE2    urinary_system_disease
#
# [4875 rows x 7 columns]

# %%
disease_pipeline = DiseasePipeline(df)

# %%
disease_pipeline.train()
# Out:
# (0) =======digestive_system_disease=======
#
# Epoch 1/40
# 15/15 - 17s - loss: 0.7403 - AUC: 0.5035 - val_loss: 0.6918 - val_AUC: 0.5243 - 17s/epoch - 1s/step
# Epoch 2/40
# 15/15 - 3s - loss: 0.6918 - AUC: 0.5178 - val_loss: 0.6866 - val_AUC: 0.5249 - 3s/epoch - 216ms/step
# Epoch 3/40
# 15/15 - 3s - loss: 0.6902 - AUC: 0.5220 - val_loss: 0.6856 - val_AUC: 0.5335 - 3s/epoch - 214ms/step
# Epoch 4/40
# 15/15 - 3s - loss: 0.6896 - AUC: 0.5269 - val_loss: 0.6850 - val_AUC: 0.5341 - 3s/epoch - 227ms/step
# Epoch 5/40
# 15/15 - 3s - loss: 0.6887 - AUC: 0.5363 - val_loss: 0.6842 - val_AUC: 0.5397 - 3s/epoch - 213ms/step
# Epoch 6/40
# 15/15 - 3s - loss: 0.6868 - AUC: 0.5485 - val_loss: 0.6825 - val_AUC: 0.5468 - 3s/epoch - 227ms/step
# Epoch 7/40
# 15/15 - 3s - loss: 0.6842 - AUC: 0.5685 - val_loss: 0.6815 - val_AUC: 0.5664 - 3s/epoch - 220ms/step
# Epoch 8/40
# 15/15 - 3s - loss: 0.6835 - AUC: 0.5724 - val_loss: 0.6790 - val_AUC: 0.5748 - 3s/epoch - 216ms/step
# Epoch 9/40
# 15/15 - 3s - loss: 0.6798 - AUC: 0.5866 - val_loss: 0.6766 - val_AUC: 0.5850 - 3s/epoch - 229ms/step
# Epoch 10/40
# 15/15 - 3s - loss: 0.6791 - AUC: 0.5907 - val_loss: 0.6759 - val_AUC: 0.5913 - 3s/epoch - 221ms/step
# Epoch 11/40
# 15/15 - 3s - loss: 0.6773 - AUC: 0.5946 - val_loss: 0.6740 - val_AUC: 0.5953 - 3s/epoch - 218ms/step
# Epoch 12/40
# 15/15 - 3s - loss: 0.6758 - AUC: 0.6007 - val_loss: 0.6735 - val_AUC: 0.5999 - 3s/epoch - 231ms/step
# Epoch 13/40
# 15/15 - 3s - loss: 0.6748 - AUC: 0.6026 - val_loss: 0.6720 - val_AUC: 0.6040 - 3s/epoch - 218ms/step
# Epoch 14/40
# 15/15 - 3s - loss: 0.6730 - AUC: 0.6078 - val_loss: 0.6713 - val_AUC: 0.6080 - 3s/epoch - 218ms/step
# Epoch 15/40
# 15/15 - 3s - loss: 0.6723 - AUC: 0.6092 - val_loss: 0.6699 - val_AUC: 0.6149 - 3s/epoch - 222ms/step
# Epoch 16/40
# 15/15 - 3s - loss: 0.6709 - AUC: 0.6133 - val_loss: 0.6667 - val_AUC: 0.6231 - 3s/epoch - 227ms/step
# Epoch 17/40
# 15/15 - 3s - loss: 0.6696 - AUC: 0.6162 - val_loss: 0.6643 - val_AUC: 0.6319 - 3s/epoch - 218ms/step
# Epoch 18/40
# 15/15 - 3s - loss: 0.6694 - AUC: 0.6176 - val_loss: 0.6603 - val_AUC: 0.6393 - 3s/epoch - 218ms/step
# Epoch 19/40
# 15/15 - 3s - loss: 0.6677 - AUC: 0.6214 - val_loss: 0.6568 - val_AUC: 0.6462 - 3s/epoch - 222ms/step
# Epoch 20/40
# 15/15 - 3s - loss: 0.6657 - AUC: 0.6269 - val_loss: 0.6539 - val_AUC: 0.6474 - 3s/epoch - 227ms/step
# Epoch 21/40
# 15/15 - 3s - loss: 0.6631 - AUC: 0.6337 - val_loss: 0.6506 - val_AUC: 0.6536 - 3s/epoch - 218ms/step
# Epoch 22/40
# 15/15 - 3s - loss: 0.6632 - AUC: 0.6360 - val_loss: 0.6493 - val_AUC: 0.6617 - 3s/epoch - 222ms/step
# Epoch 23/40
# 15/15 - 3s - loss: 0.6655 - AUC: 0.6336 - val_loss: 0.6560 - val_AUC: 0.6604 - 3s/epoch - 227ms/step
# Epoch 24/40
# 15/15 - 3s - loss: 0.6648 - AUC: 0.6315 - val_loss: 0.6589 - val_AUC: 0.6615 - 3s/epoch - 218ms/step
# Epoch 25/40
# 15/15 - 3s - loss: 0.6625 - AUC: 0.6378 - val_loss: 0.6508 - val_AUC: 0.6646 - 3s/epoch - 215ms/step
# Epoch 26/40
# 15/15 - 3s - loss: 0.6565 - AUC: 0.6500 - val_loss: 0.6453 - val_AUC: 0.6764 - 3s/epoch - 228ms/step
# Epoch 27/40
# 15/15 - 3s - loss: 0.6562 - AUC: 0.6487 - val_loss: 0.6403 - val_AUC: 0.6818 - 3s/epoch - 217ms/step
# Epoch 28/40
# 15/15 - 3s - loss: 0.6535 - AUC: 0.6544 - val_loss: 0.6380 - val_AUC: 0.6781 - 3s/epoch - 215ms/step
# Epoch 29/40
# 15/15 - 3s - loss: 0.6547 - AUC: 0.6498 - val_loss: 0.6437 - val_AUC: 0.6655 - 3s/epoch - 221ms/step
# Epoch 30/40
# 15/15 - 3s - loss: 0.6610 - AUC: 0.6341 - val_loss: 0.6461 - val_AUC: 0.6650 - 3s/epoch - 221ms/step
# Epoch 31/40
# 15/15 - 3s - loss: 0.6572 - AUC: 0.6478 - val_loss: 0.6445 - val_AUC: 0.6607 - 3s/epoch - 221ms/step
# Epoch 32/40
# 15/15 - 4s - loss: 0.6508 - AUC: 0.6618 - val_loss: 0.6413 - val_AUC: 0.6711 - 4s/epoch - 235ms/step
# Epoch 33/40
# 15/15 - 3s - loss: 0.6561 - AUC: 0.6554 - val_loss: 0.6387 - val_AUC: 0.6842 - 3s/epoch - 220ms/step
# Epoch 34/40
# 15/15 - 3s - loss: 0.6560 - AUC: 0.6559 - val_loss: 0.6577 - val_AUC: 0.6691 - 3s/epoch - 216ms/step
# Epoch 35/40
# 15/15 - 3s - loss: 0.6517 - AUC: 0.6601 - val_loss: 0.6396 - val_AUC: 0.6848 - 3s/epoch - 219ms/step
# Epoch 36/40
# 15/15 - 3s - loss: 0.6464 - AUC: 0.6673 - val_loss: 0.6330 - val_AUC: 0.6899 - 3s/epoch - 226ms/step
# Epoch 37/40
# 15/15 - 3s - loss: 0.6519 - AUC: 0.6589 - val_loss: 0.6335 - val_AUC: 0.6919 - 3s/epoch - 220ms/step
# Epoch 38/40
# 15/15 - 3s - loss: 0.6655 - AUC: 0.6230 - val_loss: 0.6307 - val_AUC: 0.6876 - 3s/epoch - 220ms/step
# Epoch 39/40
# 15/15 - 3s - loss: 0.6651 - AUC: 0.6236 - val_loss: 0.6543 - val_AUC: 0.6416 - 3s/epoch - 228ms/step
# Epoch 40/40
# 15/15 - 3s - loss: 0.6555 - AUC: 0.6420 - val_loss: 0.6398 - val_AUC: 0.6618 - 3s/epoch - 220ms/step
#
# (1) =======skin_and_connective_tissue_disease=======
#
# Epoch 1/40
# 15/15 - 17s - loss: 0.1070 - AUC: 0.4921 - val_loss: 0.0592 - val_AUC: 0.5640 - 17s/epoch - 1s/step
# Epoch 2/40
# 15/15 - 3s - loss: 0.0797 - AUC: 0.4635 - val_loss: 0.0599 - val_AUC: 0.4672 - 3s/epoch - 214ms/step
# Epoch 3/40
# 15/15 - 3s - loss: 0.0797 - AUC: 0.4739 - val_loss: 0.0606 - val_AUC: 0.5527 - 3s/epoch - 214ms/step
# Epoch 4/40
# 15/15 - 3s - loss: 0.0791 - AUC: 0.5331 - val_loss: 0.0600 - val_AUC: 0.3286 - 3s/epoch - 215ms/step
# Epoch 5/40
# 15/15 - 4s - loss: 0.0791 - AUC: 0.5449 - val_loss: 0.0602 - val_AUC: 0.4002 - 4s/epoch - 235ms/step
# Epoch 6/40
# 15/15 - 3s - loss: 0.0790 - AUC: 0.5472 - val_loss: 0.0603 - val_AUC: 0.4005 - 3s/epoch - 215ms/step
# Epoch 7/40
# 15/15 - 3s - loss: 0.0788 - AUC: 0.5381 - val_loss: 0.0601 - val_AUC: 0.4257 - 3s/epoch - 210ms/step
# Epoch 8/40
# 15/15 - 3s - loss: 0.0787 - AUC: 0.5595 - val_loss: 0.0599 - val_AUC: 0.4446 - 3s/epoch - 212ms/step
# Epoch 9/40
# 15/15 - 3s - loss: 0.0786 - AUC: 0.5832 - val_loss: 0.0597 - val_AUC: 0.4602 - 3s/epoch - 221ms/step
# Epoch 10/40
# 15/15 - 3s - loss: 0.0785 - AUC: 0.5785 - val_loss: 0.0596 - val_AUC: 0.4688 - 3s/epoch - 210ms/step
# Epoch 11/40
# 15/15 - 3s - loss: 0.0783 - AUC: 0.5676 - val_loss: 0.0595 - val_AUC: 0.5872 - 3s/epoch - 227ms/step
# Epoch 12/40
# 15/15 - 4s - loss: 0.0782 - AUC: 0.5777 - val_loss: 0.0594 - val_AUC: 0.5985 - 4s/epoch - 254ms/step
# Epoch 13/40
# 15/15 - 3s - loss: 0.0781 - AUC: 0.5782 - val_loss: 0.0593 - val_AUC: 0.5988 - 3s/epoch - 216ms/step
# Epoch 14/40
# 15/15 - 3s - loss: 0.0779 - AUC: 0.5906 - val_loss: 0.0592 - val_AUC: 0.6094 - 3s/epoch - 211ms/step
# Epoch 15/40
# 15/15 - 3s - loss: 0.0778 - AUC: 0.5922 - val_loss: 0.0590 - val_AUC: 0.6204 - 3s/epoch - 210ms/step
# Epoch 16/40
# 15/15 - 3s - loss: 0.0777 - AUC: 0.5971 - val_loss: 0.0591 - val_AUC: 0.6107 - 3s/epoch - 216ms/step
# Epoch 17/40
# 15/15 - 3s - loss: 0.0775 - AUC: 0.6041 - val_loss: 0.0590 - val_AUC: 0.6144 - 3s/epoch - 213ms/step
# Epoch 18/40
# 15/15 - 3s - loss: 0.0773 - AUC: 0.6085 - val_loss: 0.0588 - val_AUC: 0.6323 - 3s/epoch - 210ms/step
# Epoch 19/40
# 15/15 - 4s - loss: 0.0772 - AUC: 0.6117 - val_loss: 0.0589 - val_AUC: 0.6267 - 4s/epoch - 243ms/step
# Epoch 20/40
# 15/15 - 3s - loss: 0.0771 - AUC: 0.6173 - val_loss: 0.0588 - val_AUC: 0.6432 - 3s/epoch - 223ms/step
# Epoch 21/40
# 15/15 - 3s - loss: 0.0768 - AUC: 0.6269 - val_loss: 0.0588 - val_AUC: 0.6316 - 3s/epoch - 212ms/step
# Epoch 22/40
# 15/15 - 3s - loss: 0.0767 - AUC: 0.6339 - val_loss: 0.0586 - val_AUC: 0.6515 - 3s/epoch - 225ms/step
# Epoch 23/40
# 15/15 - 3s - loss: 0.0763 - AUC: 0.6518 - val_loss: 0.0587 - val_AUC: 0.6529 - 3s/epoch - 211ms/step
# Epoch 24/40
# 15/15 - 3s - loss: 0.0765 - AUC: 0.6462 - val_loss: 0.0577 - val_AUC: 0.6363 - 3s/epoch - 216ms/step
# Epoch 25/40
# 15/15 - 3s - loss: 0.0763 - AUC: 0.6527 - val_loss: 0.0574 - val_AUC: 0.5991 - 3s/epoch - 219ms/step
# Epoch 26/40
# 15/15 - 3s - loss: 0.0764 - AUC: 0.6565 - val_loss: 0.0577 - val_AUC: 0.6877 - 3s/epoch - 216ms/step
# Epoch 27/40
# 15/15 - 3s - loss: 0.0755 - AUC: 0.6840 - val_loss: 0.0574 - val_AUC: 0.6900 - 3s/epoch - 211ms/step
# Epoch 28/40
# 15/15 - 3s - loss: 0.0754 - AUC: 0.6909 - val_loss: 0.0581 - val_AUC: 0.6661 - 3s/epoch - 212ms/step
# Epoch 29/40
# 15/15 - 3s - loss: 0.0747 - AUC: 0.7002 - val_loss: 0.0586 - val_AUC: 0.7086 - 3s/epoch - 230ms/step
# Epoch 30/40
# 15/15 - 3s - loss: 0.0744 - AUC: 0.7123 - val_loss: 0.0572 - val_AUC: 0.6993 - 3s/epoch - 210ms/step
# Epoch 31/40
# 15/15 - 3s - loss: 0.0750 - AUC: 0.7047 - val_loss: 0.0550 - val_AUC: 0.7404 - 3s/epoch - 214ms/step
# Epoch 32/40
# 15/15 - 3s - loss: 0.0748 - AUC: 0.7103 - val_loss: 0.0565 - val_AUC: 0.6565 - 3s/epoch - 229ms/step
# Epoch 33/40
# 15/15 - 3s - loss: 0.0717 - AUC: 0.7762 - val_loss: 0.0537 - val_AUC: 0.8027 - 3s/epoch - 212ms/step
# Epoch 34/40
# 15/15 - 3s - loss: 0.0725 - AUC: 0.7471 - val_loss: 0.0540 - val_AUC: 0.7987 - 3s/epoch - 216ms/step
# Epoch 35/40
# 15/15 - 3s - loss: 0.0710 - AUC: 0.7826 - val_loss: 0.0525 - val_AUC: 0.8448 - 3s/epoch - 220ms/step
# Epoch 36/40
# 15/15 - 3s - loss: 0.0728 - AUC: 0.7317 - val_loss: 0.0545 - val_AUC: 0.7172 - 3s/epoch - 213ms/step
# Epoch 37/40
# 15/15 - 4s - loss: 0.0741 - AUC: 0.7156 - val_loss: 0.0525 - val_AUC: 0.7994 - 4s/epoch - 246ms/step
# Epoch 38/40
# 15/15 - 3s - loss: 0.0722 - AUC: 0.7496 - val_loss: 0.0539 - val_AUC: 0.7447 - 3s/epoch - 212ms/step
# Epoch 39/40
# 15/15 - 3s - loss: 0.0717 - AUC: 0.7629 - val_loss: 0.0534 - val_AUC: 0.7938 - 3s/epoch - 214ms/step
# Epoch 40/40
# 15/15 - 3s - loss: 0.0734 - AUC: 0.7241 - val_loss: 0.0507 - val_AUC: 0.8322 - 3s/epoch - 217ms/step
#
# (2) =======cardiovascular_disease=======
#
# Epoch 1/40
# 15/15 - 18s - loss: 0.5509 - AUC: 0.5015 - val_loss: 0.4543 - val_AUC: 0.5159 - 18s/epoch - 1s/step
# Epoch 2/40
# 15/15 - 3s - loss: 0.4797 - AUC: 0.5019 - val_loss: 0.4597 - val_AUC: 0.5243 - 3s/epoch - 226ms/step
# Epoch 3/40
# 15/15 - 3s - loss: 0.4732 - AUC: 0.5158 - val_loss: 0.4549 - val_AUC: 0.5342 - 3s/epoch - 233ms/step
# Epoch 4/40
# 15/15 - 4s - loss: 0.4709 - AUC: 0.5522 - val_loss: 0.4527 - val_AUC: 0.5458 - 4s/epoch - 236ms/step
# Epoch 5/40
# 15/15 - 3s - loss: 0.4705 - AUC: 0.5522 - val_loss: 0.4510 - val_AUC: 0.5534 - 3s/epoch - 228ms/step
# Epoch 6/40
# 15/15 - 3s - loss: 0.4699 - AUC: 0.5583 - val_loss: 0.4497 - val_AUC: 0.5735 - 3s/epoch - 227ms/step
# Epoch 7/40
# 15/15 - 4s - loss: 0.4688 - AUC: 0.5699 - val_loss: 0.4497 - val_AUC: 0.5790 - 4s/epoch - 234ms/step
# Epoch 8/40
# 15/15 - 3s - loss: 0.4667 - AUC: 0.5832 - val_loss: 0.4483 - val_AUC: 0.5888 - 3s/epoch - 227ms/step
# Epoch 9/40
# 15/15 - 3s - loss: 0.4645 - AUC: 0.5939 - val_loss: 0.4465 - val_AUC: 0.5980 - 3s/epoch - 227ms/step
# Epoch 10/40
# 15/15 - 3s - loss: 0.4628 - AUC: 0.6029 - val_loss: 0.4456 - val_AUC: 0.6007 - 3s/epoch - 229ms/step
# Epoch 11/40
# 15/15 - 3s - loss: 0.4617 - AUC: 0.6076 - val_loss: 0.4446 - val_AUC: 0.6098 - 3s/epoch - 228ms/step
# Epoch 12/40
# 15/15 - 4s - loss: 0.4610 - AUC: 0.6119 - val_loss: 0.4436 - val_AUC: 0.6186 - 4s/epoch - 239ms/step
# Epoch 13/40
# 15/15 - 3s - loss: 0.4601 - AUC: 0.6164 - val_loss: 0.4424 - val_AUC: 0.6270 - 3s/epoch - 232ms/step
# Epoch 14/40
# 15/15 - 3s - loss: 0.4593 - AUC: 0.6200 - val_loss: 0.4422 - val_AUC: 0.6295 - 3s/epoch - 227ms/step
# Epoch 15/40
# 15/15 - 4s - loss: 0.4588 - AUC: 0.6215 - val_loss: 0.4426 - val_AUC: 0.6295 - 4s/epoch - 234ms/step
# Epoch 16/40
# 15/15 - 4s - loss: 0.4585 - AUC: 0.6233 - val_loss: 0.4399 - val_AUC: 0.6368 - 4s/epoch - 235ms/step
# Epoch 17/40
# 15/15 - 3s - loss: 0.4555 - AUC: 0.6310 - val_loss: 0.4375 - val_AUC: 0.6511 - 3s/epoch - 227ms/step
# Epoch 18/40
# 15/15 - 3s - loss: 0.4556 - AUC: 0.6320 - val_loss: 0.4385 - val_AUC: 0.6570 - 3s/epoch - 228ms/step
# Epoch 19/40
# 15/15 - 4s - loss: 0.4542 - AUC: 0.6376 - val_loss: 0.4344 - val_AUC: 0.6538 - 4s/epoch - 241ms/step
# Epoch 20/40
# 15/15 - 3s - loss: 0.4544 - AUC: 0.6359 - val_loss: 0.4336 - val_AUC: 0.6846 - 3s/epoch - 231ms/step
# Epoch 21/40
# 15/15 - 3s - loss: 0.4537 - AUC: 0.6403 - val_loss: 0.4395 - val_AUC: 0.6506 - 3s/epoch - 230ms/step
# Epoch 22/40
# 15/15 - 4s - loss: 0.4504 - AUC: 0.6464 - val_loss: 0.4267 - val_AUC: 0.6858 - 4s/epoch - 240ms/step
# Epoch 23/40
# 15/15 - 4s - loss: 0.4478 - AUC: 0.6540 - val_loss: 0.4319 - val_AUC: 0.6949 - 4s/epoch - 238ms/step
# Epoch 24/40
# 15/15 - 3s - loss: 0.4470 - AUC: 0.6561 - val_loss: 0.4325 - val_AUC: 0.6869 - 3s/epoch - 230ms/step
# Epoch 25/40
# 15/15 - 3s - loss: 0.4503 - AUC: 0.6489 - val_loss: 0.4336 - val_AUC: 0.6597 - 3s/epoch - 230ms/step
# Epoch 26/40
# 15/15 - 4s - loss: 0.4500 - AUC: 0.6482 - val_loss: 0.4318 - val_AUC: 0.6844 - 4s/epoch - 242ms/step
# Epoch 27/40
# 15/15 - 3s - loss: 0.4478 - AUC: 0.6525 - val_loss: 0.4289 - val_AUC: 0.7126 - 3s/epoch - 232ms/step
# Epoch 28/40
# 15/15 - 4s - loss: 0.4496 - AUC: 0.6503 - val_loss: 0.4284 - val_AUC: 0.7004 - 4s/epoch - 236ms/step
# Epoch 29/40
# 15/15 - 4s - loss: 0.4455 - AUC: 0.6558 - val_loss: 0.4246 - val_AUC: 0.6929 - 4s/epoch - 246ms/step
# Epoch 30/40
# 15/15 - 4s - loss: 0.4432 - AUC: 0.6670 - val_loss: 0.4257 - val_AUC: 0.6923 - 4s/epoch - 237ms/step
# Epoch 31/40
# 15/15 - 3s - loss: 0.4406 - AUC: 0.6734 - val_loss: 0.4248 - val_AUC: 0.7001 - 3s/epoch - 231ms/step
# Epoch 32/40
# 15/15 - 3s - loss: 0.4439 - AUC: 0.6628 - val_loss: 0.4268 - val_AUC: 0.7118 - 3s/epoch - 231ms/step
# Epoch 33/40
# 15/15 - 4s - loss: 0.4393 - AUC: 0.6708 - val_loss: 0.4216 - val_AUC: 0.7024 - 4s/epoch - 248ms/step
# Epoch 34/40
# 15/15 - 3s - loss: 0.4336 - AUC: 0.6850 - val_loss: 0.4160 - val_AUC: 0.7177 - 3s/epoch - 232ms/step
# Epoch 35/40
# 15/15 - 3s - loss: 0.4315 - AUC: 0.6959 - val_loss: 0.4209 - val_AUC: 0.7107 - 3s/epoch - 231ms/step
# Epoch 36/40
# 15/15 - 4s - loss: 0.4341 - AUC: 0.6915 - val_loss: 0.4170 - val_AUC: 0.7193 - 4s/epoch - 257ms/step
# Epoch 37/40
# 15/15 - 4s - loss: 0.4403 - AUC: 0.6701 - val_loss: 0.4323 - val_AUC: 0.6517 - 4s/epoch - 235ms/step
# Epoch 38/40
# 15/15 - 3s - loss: 0.4445 - AUC: 0.6689 - val_loss: 0.4313 - val_AUC: 0.7017 - 3s/epoch - 231ms/step
# Epoch 39/40
# 15/15 - 4s - loss: 0.4429 - AUC: 0.6813 - val_loss: 0.4157 - val_AUC: 0.7113 - 4s/epoch - 237ms/step
# Epoch 40/40
# 15/15 - 3s - loss: 0.4386 - AUC: 0.6797 - val_loss: 0.4217 - val_AUC: 0.7043 - 3s/epoch - 231ms/step
#
# (3) =======immune_system_disease=======
#
# Epoch 1/40
# 15/15 - 18s - loss: 0.4393 - AUC: 0.4776 - val_loss: 0.3538 - val_AUC: 0.4764 - 18s/epoch - 1s/step
# Epoch 2/40
# 15/15 - 4s - loss: 0.4005 - AUC: 0.4836 - val_loss: 0.3473 - val_AUC: 0.5113 - 4s/epoch - 252ms/step
# Epoch 3/40
# 15/15 - 3s - loss: 0.3968 - AUC: 0.4686 - val_loss: 0.3505 - val_AUC: 0.5101 - 3s/epoch - 227ms/step
# Epoch 4/40
# 15/15 - 3s - loss: 0.3916 - AUC: 0.4749 - val_loss: 0.3482 - val_AUC: 0.5463 - 3s/epoch - 224ms/step
# Epoch 5/40
# 15/15 - 4s - loss: 0.3916 - AUC: 0.4847 - val_loss: 0.3474 - val_AUC: 0.5068 - 4s/epoch - 235ms/step
# Epoch 6/40
# 15/15 - 3s - loss: 0.3928 - AUC: 0.4858 - val_loss: 0.3474 - val_AUC: 0.5105 - 3s/epoch - 225ms/step
# Epoch 7/40
# 15/15 - 3s - loss: 0.3930 - AUC: 0.4823 - val_loss: 0.3475 - val_AUC: 0.4980 - 3s/epoch - 225ms/step
# Epoch 8/40
# 15/15 - 4s - loss: 0.3928 - AUC: 0.4849 - val_loss: 0.3476 - val_AUC: 0.5165 - 4s/epoch - 254ms/step
# Epoch 9/40
# 15/15 - 3s - loss: 0.3924 - AUC: 0.4891 - val_loss: 0.3476 - val_AUC: 0.5160 - 3s/epoch - 228ms/step
# Epoch 10/40
# 15/15 - 3s - loss: 0.3922 - AUC: 0.4911 - val_loss: 0.3476 - val_AUC: 0.5030 - 3s/epoch - 225ms/step
# Epoch 11/40
# 15/15 - 4s - loss: 0.3920 - AUC: 0.4931 - val_loss: 0.3477 - val_AUC: 0.5129 - 4s/epoch - 252ms/step
# Epoch 12/40
# 15/15 - 3s - loss: 0.3917 - AUC: 0.4952 - val_loss: 0.3477 - val_AUC: 0.5034 - 3s/epoch - 231ms/step
# Epoch 13/40
# 15/15 - 3s - loss: 0.3913 - AUC: 0.4994 - val_loss: 0.3476 - val_AUC: 0.5040 - 3s/epoch - 226ms/step
# Epoch 14/40
# 15/15 - 4s - loss: 0.3910 - AUC: 0.5009 - val_loss: 0.3475 - val_AUC: 0.5203 - 4s/epoch - 252ms/step
# Epoch 15/40
# 15/15 - 3s - loss: 0.3906 - AUC: 0.5050 - val_loss: 0.3473 - val_AUC: 0.5261 - 3s/epoch - 230ms/step
# Epoch 16/40
# 15/15 - 3s - loss: 0.3904 - AUC: 0.5082 - val_loss: 0.3470 - val_AUC: 0.5412 - 3s/epoch - 225ms/step
# Epoch 17/40
# 15/15 - 3s - loss: 0.3900 - AUC: 0.5133 - val_loss: 0.3466 - val_AUC: 0.5382 - 3s/epoch - 226ms/step
# Epoch 18/40
# 15/15 - 4s - loss: 0.3899 - AUC: 0.5157 - val_loss: 0.3462 - val_AUC: 0.5415 - 4s/epoch - 254ms/step
# Epoch 19/40
# 15/15 - 3s - loss: 0.3893 - AUC: 0.5244 - val_loss: 0.3459 - val_AUC: 0.5511 - 3s/epoch - 225ms/step
# Epoch 20/40
# 15/15 - 4s - loss: 0.3894 - AUC: 0.5233 - val_loss: 0.3450 - val_AUC: 0.5667 - 4s/epoch - 248ms/step
# Epoch 21/40
# 15/15 - 4s - loss: 0.3885 - AUC: 0.5328 - val_loss: 0.3453 - val_AUC: 0.5688 - 4s/epoch - 261ms/step
# Epoch 22/40
# 15/15 - 3s - loss: 0.3884 - AUC: 0.5394 - val_loss: 0.3435 - val_AUC: 0.5616 - 3s/epoch - 226ms/step
# Epoch 23/40
# 15/15 - 3s - loss: 0.3877 - AUC: 0.5456 - val_loss: 0.3437 - val_AUC: 0.5754 - 3s/epoch - 227ms/step
# Epoch 24/40
# 15/15 - 4s - loss: 0.3878 - AUC: 0.5446 - val_loss: 0.3442 - val_AUC: 0.5688 - 4s/epoch - 256ms/step
# Epoch 25/40
# 15/15 - 3s - loss: 0.3867 - AUC: 0.5594 - val_loss: 0.3426 - val_AUC: 0.5739 - 3s/epoch - 226ms/step
# Epoch 26/40
# 15/15 - 3s - loss: 0.3869 - AUC: 0.5549 - val_loss: 0.3415 - val_AUC: 0.5888 - 3s/epoch - 226ms/step
# Epoch 27/40
# 15/15 - 4s - loss: 0.3853 - AUC: 0.5673 - val_loss: 0.3417 - val_AUC: 0.5839 - 4s/epoch - 255ms/step
# Epoch 28/40
# 15/15 - 3s - loss: 0.3866 - AUC: 0.5567 - val_loss: 0.3414 - val_AUC: 0.6014 - 3s/epoch - 227ms/step
# Epoch 29/40
# 15/15 - 3s - loss: 0.3837 - AUC: 0.5775 - val_loss: 0.3425 - val_AUC: 0.5851 - 3s/epoch - 227ms/step
# Epoch 30/40
# 15/15 - 4s - loss: 0.3844 - AUC: 0.5787 - val_loss: 0.3413 - val_AUC: 0.5946 - 4s/epoch - 260ms/step
# Epoch 31/40
# 15/15 - 4s - loss: 0.3839 - AUC: 0.5818 - val_loss: 0.3400 - val_AUC: 0.5863 - 4s/epoch - 250ms/step
# Epoch 32/40
# 15/15 - 4s - loss: 0.3851 - AUC: 0.5668 - val_loss: 0.3396 - val_AUC: 0.5998 - 4s/epoch - 234ms/step
# Epoch 33/40
# 15/15 - 4s - loss: 0.3824 - AUC: 0.5875 - val_loss: 0.3407 - val_AUC: 0.5996 - 4s/epoch - 253ms/step
# Epoch 34/40
# 15/15 - 3s - loss: 0.3837 - AUC: 0.5853 - val_loss: 0.3402 - val_AUC: 0.6045 - 3s/epoch - 225ms/step
# Epoch 35/40
# 15/15 - 3s - loss: 0.3819 - AUC: 0.5928 - val_loss: 0.3390 - val_AUC: 0.6086 - 3s/epoch - 228ms/step
# Epoch 36/40
# 15/15 - 4s - loss: 0.3830 - AUC: 0.5851 - val_loss: 0.3390 - val_AUC: 0.6099 - 4s/epoch - 257ms/step
# Epoch 37/40
# 15/15 - 3s - loss: 0.3813 - AUC: 0.5979 - val_loss: 0.3387 - val_AUC: 0.6129 - 3s/epoch - 226ms/step
# Epoch 38/40
# 15/15 - 3s - loss: 0.3825 - AUC: 0.5927 - val_loss: 0.3386 - val_AUC: 0.6156 - 3s/epoch - 226ms/step
# Epoch 39/40
# 15/15 - 4s - loss: 0.3802 - AUC: 0.6057 - val_loss: 0.3379 - val_AUC: 0.6063 - 4s/epoch - 259ms/step
# Epoch 40/40
# 15/15 - 3s - loss: 0.3804 - AUC: 0.6016 - val_loss: 0.3364 - val_AUC: 0.6261 - 3s/epoch - 226ms/step
#
# (4) =======mental_and_behavioural_disorder=======
#
# Epoch 1/40
# 15/15 - 19s - loss: 0.1851 - AUC: 0.4845 - val_loss: 0.1520 - val_AUC: 0.4054 - 19s/epoch - 1s/step
# Epoch 2/40
# 15/15 - 3s - loss: 0.1435 - AUC: 0.4703 - val_loss: 0.1501 - val_AUC: 0.4855 - 3s/epoch - 225ms/step
# Epoch 3/40
# 15/15 - 3s - loss: 0.1404 - AUC: 0.5165 - val_loss: 0.1481 - val_AUC: 0.7057 - 3s/epoch - 219ms/step
# Epoch 4/40
# 15/15 - 3s - loss: 0.1390 - AUC: 0.5869 - val_loss: 0.1468 - val_AUC: 0.7108 - 3s/epoch - 217ms/step
# Epoch 5/40
# 15/15 - 3s - loss: 0.1387 - AUC: 0.5718 - val_loss: 0.1456 - val_AUC: 0.6777 - 3s/epoch - 213ms/step
# Epoch 6/40
# 15/15 - 3s - loss: 0.1381 - AUC: 0.5917 - val_loss: 0.1438 - val_AUC: 0.7116 - 3s/epoch - 226ms/step
# Epoch 7/40
# 15/15 - 3s - loss: 0.1369 - AUC: 0.6175 - val_loss: 0.1428 - val_AUC: 0.7378 - 3s/epoch - 223ms/step
# Epoch 8/40
# 15/15 - 3s - loss: 0.1354 - AUC: 0.6565 - val_loss: 0.1417 - val_AUC: 0.7432 - 3s/epoch - 233ms/step
# Epoch 9/40
# 15/15 - 3s - loss: 0.1330 - AUC: 0.6906 - val_loss: 0.1371 - val_AUC: 0.7680 - 3s/epoch - 213ms/step
# Epoch 10/40
# 15/15 - 3s - loss: 0.1304 - AUC: 0.7213 - val_loss: 0.1363 - val_AUC: 0.7533 - 3s/epoch - 218ms/step
# Epoch 11/40
# 15/15 - 3s - loss: 0.1292 - AUC: 0.7271 - val_loss: 0.1348 - val_AUC: 0.7635 - 3s/epoch - 229ms/step
# Epoch 12/40
# 15/15 - 3s - loss: 0.1284 - AUC: 0.7304 - val_loss: 0.1340 - val_AUC: 0.7758 - 3s/epoch - 218ms/step
# Epoch 13/40
# 15/15 - 3s - loss: 0.1275 - AUC: 0.7377 - val_loss: 0.1327 - val_AUC: 0.7829 - 3s/epoch - 219ms/step
# Epoch 14/40
# 15/15 - 4s - loss: 0.1268 - AUC: 0.7423 - val_loss: 0.1307 - val_AUC: 0.7895 - 4s/epoch - 234ms/step
# Epoch 15/40
# 15/15 - 3s - loss: 0.1264 - AUC: 0.7467 - val_loss: 0.1279 - val_AUC: 0.7980 - 3s/epoch - 213ms/step
# Epoch 16/40
# 15/15 - 3s - loss: 0.1268 - AUC: 0.7476 - val_loss: 0.1278 - val_AUC: 0.8152 - 3s/epoch - 213ms/step
# Epoch 17/40
# 15/15 - 4s - loss: 0.1268 - AUC: 0.7524 - val_loss: 0.1303 - val_AUC: 0.8107 - 4s/epoch - 234ms/step
# Epoch 18/40
# 15/15 - 3s - loss: 0.1219 - AUC: 0.7639 - val_loss: 0.1187 - val_AUC: 0.8550 - 3s/epoch - 220ms/step
# Epoch 19/40
# 15/15 - 3s - loss: 0.1250 - AUC: 0.7595 - val_loss: 0.1250 - val_AUC: 0.8127 - 3s/epoch - 222ms/step
# Epoch 20/40
# 15/15 - 3s - loss: 0.1312 - AUC: 0.7122 - val_loss: 0.1326 - val_AUC: 0.7761 - 3s/epoch - 222ms/step
# Epoch 21/40
# 15/15 - 3s - loss: 0.1250 - AUC: 0.7549 - val_loss: 0.1274 - val_AUC: 0.8039 - 3s/epoch - 219ms/step
# Epoch 22/40
# 15/15 - 3s - loss: 0.1218 - AUC: 0.7746 - val_loss: 0.1215 - val_AUC: 0.8315 - 3s/epoch - 229ms/step
# Epoch 23/40
# 15/15 - 3s - loss: 0.1235 - AUC: 0.7758 - val_loss: 0.1245 - val_AUC: 0.8273 - 3s/epoch - 228ms/step
# Epoch 24/40
# 15/15 - 3s - loss: 0.1299 - AUC: 0.7322 - val_loss: 0.1327 - val_AUC: 0.7940 - 3s/epoch - 214ms/step
# Epoch 25/40
# 15/15 - 3s - loss: 0.1218 - AUC: 0.7858 - val_loss: 0.1203 - val_AUC: 0.8473 - 3s/epoch - 219ms/step
# Epoch 26/40
# 15/15 - 4s - loss: 0.1190 - AUC: 0.7806 - val_loss: 0.1146 - val_AUC: 0.8565 - 4s/epoch - 234ms/step
# Epoch 27/40
# 15/15 - 3s - loss: 0.1295 - AUC: 0.7391 - val_loss: 0.1309 - val_AUC: 0.7901 - 3s/epoch - 214ms/step
# Epoch 28/40
# 15/15 - 3s - loss: 0.1202 - AUC: 0.7939 - val_loss: 0.1162 - val_AUC: 0.8470 - 3s/epoch - 218ms/step
# Epoch 29/40
# 15/15 - 3s - loss: 0.1193 - AUC: 0.7871 - val_loss: 0.1146 - val_AUC: 0.8596 - 3s/epoch - 233ms/step
# Epoch 30/40
# 15/15 - 3s - loss: 0.1165 - AUC: 0.8129 - val_loss: 0.1164 - val_AUC: 0.8506 - 3s/epoch - 222ms/step
# Epoch 31/40
# 15/15 - 3s - loss: 0.1314 - AUC: 0.7186 - val_loss: 0.1348 - val_AUC: 0.7817 - 3s/epoch - 226ms/step
# Epoch 32/40
# 15/15 - 3s - loss: 0.1250 - AUC: 0.7504 - val_loss: 0.1241 - val_AUC: 0.8321 - 3s/epoch - 225ms/step
# Epoch 33/40
# 15/15 - 3s - loss: 0.1243 - AUC: 0.7724 - val_loss: 0.1199 - val_AUC: 0.8306 - 3s/epoch - 220ms/step
# Epoch 34/40
# 15/15 - 3s - loss: 0.1156 - AUC: 0.8153 - val_loss: 0.1043 - val_AUC: 0.8751 - 3s/epoch - 218ms/step
# Epoch 35/40
# 15/15 - 3s - loss: 0.1124 - AUC: 0.8223 - val_loss: 0.1037 - val_AUC: 0.8773 - 3s/epoch - 226ms/step
# Epoch 36/40
# 15/15 - 3s - loss: 0.1139 - AUC: 0.8163 - val_loss: 0.1098 - val_AUC: 0.8618 - 3s/epoch - 228ms/step
# Epoch 37/40
# 15/15 - 3s - loss: 0.1205 - AUC: 0.7902 - val_loss: 0.1142 - val_AUC: 0.8429 - 3s/epoch - 217ms/step
# Epoch 38/40
# 15/15 - 3s - loss: 0.1183 - AUC: 0.8049 - val_loss: 0.1100 - val_AUC: 0.8355 - 3s/epoch - 220ms/step
# Epoch 39/40
# 15/15 - 3s - loss: 0.1111 - AUC: 0.8270 - val_loss: 0.1026 - val_AUC: 0.8664 - 3s/epoch - 226ms/step
# Epoch 40/40
# 15/15 - 3s - loss: 0.1134 - AUC: 0.8326 - val_loss: 0.1065 - val_AUC: 0.8709 - 3s/epoch - 218ms/step
#
# (5) =======metabolic_disease=======
#
# Epoch 1/40
# 15/15 - 17s - loss: 0.2427 - AUC: 0.4674 - val_loss: 0.2093 - val_AUC: 0.4020 - 17s/epoch - 1s/step
# Epoch 2/40
# 15/15 - 3s - loss: 0.2002 - AUC: 0.4756 - val_loss: 0.2073 - val_AUC: 0.4963 - 3s/epoch - 226ms/step
# Epoch 3/40
# 15/15 - 3s - loss: 0.1978 - AUC: 0.4852 - val_loss: 0.2054 - val_AUC: 0.4874 - 3s/epoch - 217ms/step
# Epoch 4/40
# 15/15 - 3s - loss: 0.1965 - AUC: 0.5112 - val_loss: 0.2053 - val_AUC: 0.5250 - 3s/epoch - 218ms/step
# Epoch 5/40
# 15/15 - 4s - loss: 0.1970 - AUC: 0.5005 - val_loss: 0.2052 - val_AUC: 0.5274 - 4s/epoch - 233ms/step
# Epoch 6/40
# 15/15 - 3s - loss: 0.1970 - AUC: 0.5106 - val_loss: 0.2048 - val_AUC: 0.5427 - 3s/epoch - 217ms/step
# Epoch 7/40
# 15/15 - 3s - loss: 0.1969 - AUC: 0.5185 - val_loss: 0.2046 - val_AUC: 0.5473 - 3s/epoch - 224ms/step
# Epoch 8/40
# 15/15 - 4s - loss: 0.1969 - AUC: 0.5219 - val_loss: 0.2044 - val_AUC: 0.5437 - 4s/epoch - 234ms/step
# Epoch 9/40
# 15/15 - 3s - loss: 0.1969 - AUC: 0.5229 - val_loss: 0.2041 - val_AUC: 0.5605 - 3s/epoch - 224ms/step
# Epoch 10/40
# 15/15 - 3s - loss: 0.1967 - AUC: 0.5257 - val_loss: 0.2037 - val_AUC: 0.5571 - 3s/epoch - 222ms/step
# Epoch 11/40
# 15/15 - 3s - loss: 0.1966 - AUC: 0.5233 - val_loss: 0.2032 - val_AUC: 0.5651 - 3s/epoch - 228ms/step
# Epoch 12/40
# 15/15 - 3s - loss: 0.1964 - AUC: 0.5210 - val_loss: 0.2026 - val_AUC: 0.5677 - 3s/epoch - 231ms/step
# Epoch 13/40
# 15/15 - 3s - loss: 0.1962 - AUC: 0.5214 - val_loss: 0.2017 - val_AUC: 0.5665 - 3s/epoch - 220ms/step
# Epoch 14/40
# 15/15 - 4s - loss: 0.1960 - AUC: 0.5296 - val_loss: 0.2004 - val_AUC: 0.5666 - 4s/epoch - 235ms/step
# Epoch 15/40
# 15/15 - 3s - loss: 0.1958 - AUC: 0.5326 - val_loss: 0.1989 - val_AUC: 0.5927 - 3s/epoch - 222ms/step
# Epoch 16/40
# 15/15 - 3s - loss: 0.1961 - AUC: 0.5241 - val_loss: 0.1978 - val_AUC: 0.5717 - 3s/epoch - 221ms/step
# Epoch 17/40
# 15/15 - 3s - loss: 0.1965 - AUC: 0.5282 - val_loss: 0.1993 - val_AUC: 0.5940 - 3s/epoch - 233ms/step
# Epoch 18/40
# 15/15 - 3s - loss: 0.1947 - AUC: 0.5337 - val_loss: 0.1969 - val_AUC: 0.5867 - 3s/epoch - 218ms/step
# Epoch 19/40
# 15/15 - 3s - loss: 0.1938 - AUC: 0.5450 - val_loss: 0.1963 - val_AUC: 0.5639 - 3s/epoch - 220ms/step
# Epoch 20/40
# 15/15 - 3s - loss: 0.1937 - AUC: 0.5449 - val_loss: 0.1952 - val_AUC: 0.5753 - 3s/epoch - 219ms/step
# Epoch 21/40
# 15/15 - 3s - loss: 0.1945 - AUC: 0.5272 - val_loss: 0.1947 - val_AUC: 0.6263 - 3s/epoch - 227ms/step
# Epoch 22/40
# 15/15 - 3s - loss: 0.1946 - AUC: 0.5282 - val_loss: 0.1952 - val_AUC: 0.6098 - 3s/epoch - 221ms/step
# Epoch 23/40
# 15/15 - 3s - loss: 0.1939 - AUC: 0.5551 - val_loss: 0.1969 - val_AUC: 0.6127 - 3s/epoch - 233ms/step
# Epoch 24/40
# 15/15 - 3s - loss: 0.1911 - AUC: 0.5573 - val_loss: 0.1908 - val_AUC: 0.5985 - 3s/epoch - 220ms/step
# Epoch 25/40
# 15/15 - 3s - loss: 0.1919 - AUC: 0.5586 - val_loss: 0.1902 - val_AUC: 0.6246 - 3s/epoch - 226ms/step
# Epoch 26/40
# 15/15 - 4s - loss: 0.1924 - AUC: 0.5452 - val_loss: 0.1904 - val_AUC: 0.6070 - 4s/epoch - 239ms/step
# Epoch 27/40
# 15/15 - 3s - loss: 0.1914 - AUC: 0.5493 - val_loss: 0.1891 - val_AUC: 0.6143 - 3s/epoch - 219ms/step
# Epoch 28/40
# 15/15 - 3s - loss: 0.1913 - AUC: 0.5677 - val_loss: 0.1935 - val_AUC: 0.6163 - 3s/epoch - 226ms/step
# Epoch 29/40
# 15/15 - 4s - loss: 0.1977 - AUC: 0.5352 - val_loss: 0.2051 - val_AUC: 0.5799 - 4s/epoch - 234ms/step
# Epoch 30/40
# 15/15 - 3s - loss: 0.1953 - AUC: 0.5413 - val_loss: 0.2028 - val_AUC: 0.6003 - 3s/epoch - 219ms/step
# Epoch 31/40
# 15/15 - 3s - loss: 0.1929 - AUC: 0.5723 - val_loss: 0.2004 - val_AUC: 0.5784 - 3s/epoch - 220ms/step
# Epoch 32/40
# 15/15 - 4s - loss: 0.1920 - AUC: 0.5695 - val_loss: 0.1962 - val_AUC: 0.6015 - 4s/epoch - 237ms/step
# Epoch 33/40
# 15/15 - 3s - loss: 0.1906 - AUC: 0.5772 - val_loss: 0.1899 - val_AUC: 0.6285 - 3s/epoch - 229ms/step
# Epoch 34/40
# 15/15 - 3s - loss: 0.1900 - AUC: 0.5810 - val_loss: 0.1876 - val_AUC: 0.6472 - 3s/epoch - 220ms/step
# Epoch 35/40
# 15/15 - 4s - loss: 0.1889 - AUC: 0.5837 - val_loss: 0.1872 - val_AUC: 0.6424 - 4s/epoch - 238ms/step
# Epoch 36/40
# 15/15 - 3s - loss: 0.1886 - AUC: 0.5902 - val_loss: 0.1869 - val_AUC: 0.6394 - 3s/epoch - 220ms/step
# Epoch 37/40
# 15/15 - 3s - loss: 0.1887 - AUC: 0.5897 - val_loss: 0.1861 - val_AUC: 0.6480 - 3s/epoch - 223ms/step
# Epoch 38/40
# 15/15 - 4s - loss: 0.1873 - AUC: 0.6016 - val_loss: 0.1860 - val_AUC: 0.6538 - 4s/epoch - 238ms/step
# Epoch 39/40
# 15/15 - 3s - loss: 0.1866 - AUC: 0.6128 - val_loss: 0.1856 - val_AUC: 0.6536 - 3s/epoch - 223ms/step
# Epoch 40/40
# 15/15 - 3s - loss: 0.1869 - AUC: 0.6073 - val_loss: 0.1846 - val_AUC: 0.6572 - 3s/epoch - 220ms/step
#
# (6) =======nervous_system_disease=======
#
# Epoch 1/40
# 15/15 - 19s - loss: 0.3269 - AUC: 0.5262 - val_loss: 0.3185 - val_AUC: 0.5247 - 19s/epoch - 1s/step
# Epoch 2/40
# 15/15 - 3s - loss: 0.3101 - AUC: 0.5376 - val_loss: 0.3266 - val_AUC: 0.5247 - 3s/epoch - 203ms/step
# Epoch 3/40
# 15/15 - 3s - loss: 0.3126 - AUC: 0.5391 - val_loss: 0.3324 - val_AUC: 0.5412 - 3s/epoch - 209ms/step
# Epoch 4/40
# 15/15 - 3s - loss: 0.3159 - AUC: 0.5157 - val_loss: 0.3231 - val_AUC: 0.5367 - 3s/epoch - 216ms/step
# Epoch 5/40
# 15/15 - 3s - loss: 0.3166 - AUC: 0.4968 - val_loss: 0.3173 - val_AUC: 0.5649 - 3s/epoch - 215ms/step
# Epoch 6/40
# 15/15 - 3s - loss: 0.3116 - AUC: 0.5068 - val_loss: 0.3167 - val_AUC: 0.5718 - 3s/epoch - 208ms/step
# Epoch 7/40
# 15/15 - 3s - loss: 0.3078 - AUC: 0.5482 - val_loss: 0.3173 - val_AUC: 0.5654 - 3s/epoch - 218ms/step
# Epoch 8/40
# 15/15 - 3s - loss: 0.3066 - AUC: 0.5722 - val_loss: 0.3269 - val_AUC: 0.5774 - 3s/epoch - 210ms/step
# Epoch 9/40
# 15/15 - 3s - loss: 0.3070 - AUC: 0.5828 - val_loss: 0.3259 - val_AUC: 0.5780 - 3s/epoch - 216ms/step
# Epoch 10/40
# 15/15 - 3s - loss: 0.3083 - AUC: 0.5696 - val_loss: 0.3188 - val_AUC: 0.5830 - 3s/epoch - 222ms/step
# Epoch 11/40
# 15/15 - 3s - loss: 0.3059 - AUC: 0.5806 - val_loss: 0.3183 - val_AUC: 0.5922 - 3s/epoch - 209ms/step
# Epoch 12/40
# 15/15 - 3s - loss: 0.3045 - AUC: 0.5899 - val_loss: 0.3156 - val_AUC: 0.5918 - 3s/epoch - 204ms/step
# Epoch 13/40
# 15/15 - 3s - loss: 0.3022 - AUC: 0.6049 - val_loss: 0.3173 - val_AUC: 0.5905 - 3s/epoch - 224ms/step
# Epoch 14/40
# 15/15 - 3s - loss: 0.3022 - AUC: 0.6042 - val_loss: 0.3148 - val_AUC: 0.5955 - 3s/epoch - 207ms/step
# Epoch 15/40
# 15/15 - 3s - loss: 0.3011 - AUC: 0.6126 - val_loss: 0.3141 - val_AUC: 0.5950 - 3s/epoch - 216ms/step
# Epoch 16/40
# 15/15 - 3s - loss: 0.3003 - AUC: 0.6152 - val_loss: 0.3131 - val_AUC: 0.5959 - 3s/epoch - 221ms/step
# Epoch 17/40
# 15/15 - 3s - loss: 0.3000 - AUC: 0.6170 - val_loss: 0.3115 - val_AUC: 0.6037 - 3s/epoch - 215ms/step
# Epoch 18/40
# 15/15 - 3s - loss: 0.2983 - AUC: 0.6253 - val_loss: 0.3115 - val_AUC: 0.6070 - 3s/epoch - 209ms/step
# Epoch 19/40
# 15/15 - 3s - loss: 0.2976 - AUC: 0.6282 - val_loss: 0.3106 - val_AUC: 0.6107 - 3s/epoch - 224ms/step
# Epoch 20/40
# 15/15 - 3s - loss: 0.2966 - AUC: 0.6348 - val_loss: 0.3104 - val_AUC: 0.6122 - 3s/epoch - 215ms/step
# Epoch 21/40
# 15/15 - 3s - loss: 0.2960 - AUC: 0.6374 - val_loss: 0.3097 - val_AUC: 0.6179 - 3s/epoch - 213ms/step
# Epoch 22/40
# 15/15 - 3s - loss: 0.2954 - AUC: 0.6425 - val_loss: 0.3092 - val_AUC: 0.6216 - 3s/epoch - 211ms/step
# Epoch 23/40
# 15/15 - 3s - loss: 0.2948 - AUC: 0.6467 - val_loss: 0.3086 - val_AUC: 0.6279 - 3s/epoch - 219ms/step
# Epoch 24/40
# 15/15 - 3s - loss: 0.2942 - AUC: 0.6483 - val_loss: 0.3081 - val_AUC: 0.6345 - 3s/epoch - 204ms/step
# Epoch 25/40
# 15/15 - 3s - loss: 0.2938 - AUC: 0.6510 - val_loss: 0.3076 - val_AUC: 0.6393 - 3s/epoch - 224ms/step
# Epoch 26/40
# 15/15 - 3s - loss: 0.2935 - AUC: 0.6527 - val_loss: 0.3057 - val_AUC: 0.6528 - 3s/epoch - 215ms/step
# Epoch 27/40
# 15/15 - 3s - loss: 0.2929 - AUC: 0.6562 - val_loss: 0.3054 - val_AUC: 0.6585 - 3s/epoch - 216ms/step
# Epoch 28/40
# 15/15 - 4s - loss: 0.2927 - AUC: 0.6588 - val_loss: 0.3023 - val_AUC: 0.6741 - 4s/epoch - 242ms/step
# Epoch 29/40
# 15/15 - 3s - loss: 0.2914 - AUC: 0.6647 - val_loss: 0.3003 - val_AUC: 0.6910 - 3s/epoch - 218ms/step
# Epoch 30/40
# 15/15 - 3s - loss: 0.2907 - AUC: 0.6701 - val_loss: 0.3050 - val_AUC: 0.6671 - 3s/epoch - 205ms/step
# Epoch 31/40
# 15/15 - 3s - loss: 0.2882 - AUC: 0.6790 - val_loss: 0.2988 - val_AUC: 0.6998 - 3s/epoch - 226ms/step
# Epoch 32/40
# 15/15 - 3s - loss: 0.2878 - AUC: 0.6852 - val_loss: 0.2979 - val_AUC: 0.6974 - 3s/epoch - 209ms/step
# Epoch 33/40
# 15/15 - 3s - loss: 0.2843 - AUC: 0.6965 - val_loss: 0.2978 - val_AUC: 0.7053 - 3s/epoch - 213ms/step
# Epoch 34/40
# 15/15 - 3s - loss: 0.2818 - AUC: 0.7091 - val_loss: 0.2936 - val_AUC: 0.7392 - 3s/epoch - 213ms/step
# Epoch 35/40
# 15/15 - 3s - loss: 0.2809 - AUC: 0.7148 - val_loss: 0.2948 - val_AUC: 0.7338 - 3s/epoch - 226ms/step
# Epoch 36/40
# 15/15 - 3s - loss: 0.2788 - AUC: 0.7116 - val_loss: 0.2954 - val_AUC: 0.7309 - 3s/epoch - 215ms/step
# Epoch 37/40
# 15/15 - 3s - loss: 0.2833 - AUC: 0.6994 - val_loss: 0.2873 - val_AUC: 0.7372 - 3s/epoch - 213ms/step
# Epoch 38/40
# 15/15 - 3s - loss: 0.2845 - AUC: 0.6982 - val_loss: 0.2957 - val_AUC: 0.7287 - 3s/epoch - 212ms/step
# Epoch 39/40
# 15/15 - 3s - loss: 0.2828 - AUC: 0.7035 - val_loss: 0.3035 - val_AUC: 0.6873 - 3s/epoch - 223ms/step
# Epoch 40/40
# 15/15 - 3s - loss: 0.2803 - AUC: 0.7117 - val_loss: 0.2944 - val_AUC: 0.7315 - 3s/epoch - 219ms/step
#
# (7) =======urinary_system_disease=======
#
# Epoch 1/40
# 15/15 - 17s - loss: 0.2157 - AUC: 0.5433 - val_loss: 0.1059 - val_AUC: 0.5176 - 17s/epoch - 1s/step
# Epoch 2/40
# 15/15 - 3s - loss: 0.1455 - AUC: 0.5084 - val_loss: 0.1018 - val_AUC: 0.6113 - 3s/epoch - 226ms/step
# Epoch 3/40
# 15/15 - 3s - loss: 0.1433 - AUC: 0.5513 - val_loss: 0.1024 - val_AUC: 0.6724 - 3s/epoch - 220ms/step
# Epoch 4/40
# 15/15 - 3s - loss: 0.1407 - AUC: 0.6242 - val_loss: 0.0999 - val_AUC: 0.6686 - 3s/epoch - 222ms/step
# Epoch 5/40
# 15/15 - 3s - loss: 0.1389 - AUC: 0.6425 - val_loss: 0.0968 - val_AUC: 0.6939 - 3s/epoch - 221ms/step
# Epoch 6/40
# 15/15 - 3s - loss: 0.1387 - AUC: 0.6434 - val_loss: 0.0977 - val_AUC: 0.6922 - 3s/epoch - 229ms/step
# Epoch 7/40
# 15/15 - 3s - loss: 0.1372 - AUC: 0.6588 - val_loss: 0.0976 - val_AUC: 0.7036 - 3s/epoch - 226ms/step
# Epoch 8/40
# 15/15 - 3s - loss: 0.1366 - AUC: 0.6629 - val_loss: 0.0961 - val_AUC: 0.6930 - 3s/epoch - 233ms/step
# Epoch 9/40
# 15/15 - 3s - loss: 0.1364 - AUC: 0.6592 - val_loss: 0.0948 - val_AUC: 0.7019 - 3s/epoch - 221ms/step
# Epoch 10/40
# 15/15 - 3s - loss: 0.1360 - AUC: 0.6609 - val_loss: 0.0935 - val_AUC: 0.7091 - 3s/epoch - 220ms/step
# Epoch 11/40
# 15/15 - 3s - loss: 0.1353 - AUC: 0.6645 - val_loss: 0.0924 - val_AUC: 0.7172 - 3s/epoch - 225ms/step
# Epoch 12/40
# 15/15 - 3s - loss: 0.1346 - AUC: 0.6697 - val_loss: 0.0918 - val_AUC: 0.6935 - 3s/epoch - 229ms/step
# Epoch 13/40
# 15/15 - 3s - loss: 0.1338 - AUC: 0.6785 - val_loss: 0.0915 - val_AUC: 0.6999 - 3s/epoch - 222ms/step
# Epoch 14/40
# 15/15 - 3s - loss: 0.1331 - AUC: 0.6811 - val_loss: 0.0915 - val_AUC: 0.7136 - 3s/epoch - 222ms/step
# Epoch 15/40
# 15/15 - 3s - loss: 0.1325 - AUC: 0.6859 - val_loss: 0.0913 - val_AUC: 0.7131 - 3s/epoch - 229ms/step
# Epoch 16/40
# 15/15 - 3s - loss: 0.1316 - AUC: 0.6915 - val_loss: 0.0912 - val_AUC: 0.7111 - 3s/epoch - 221ms/step
# Epoch 17/40
# 15/15 - 3s - loss: 0.1308 - AUC: 0.6926 - val_loss: 0.0907 - val_AUC: 0.7076 - 3s/epoch - 221ms/step
# Epoch 18/40
# 15/15 - 4s - loss: 0.1299 - AUC: 0.6943 - val_loss: 0.0903 - val_AUC: 0.7038 - 4s/epoch - 234ms/step
# Epoch 19/40
# 15/15 - 3s - loss: 0.1292 - AUC: 0.6981 - val_loss: 0.0897 - val_AUC: 0.7108 - 3s/epoch - 221ms/step
# Epoch 20/40
# 15/15 - 3s - loss: 0.1283 - AUC: 0.6963 - val_loss: 0.0891 - val_AUC: 0.7111 - 3s/epoch - 223ms/step
# Epoch 21/40
# 15/15 - 3s - loss: 0.1280 - AUC: 0.7015 - val_loss: 0.0890 - val_AUC: 0.7029 - 3s/epoch - 230ms/step
# Epoch 22/40
# 15/15 - 4s - loss: 0.1267 - AUC: 0.7135 - val_loss: 0.0880 - val_AUC: 0.7116 - 4s/epoch - 235ms/step
# Epoch 23/40
# 15/15 - 3s - loss: 0.1269 - AUC: 0.7106 - val_loss: 0.0883 - val_AUC: 0.7027 - 3s/epoch - 226ms/step
# Epoch 24/40
# 15/15 - 3s - loss: 0.1257 - AUC: 0.7190 - val_loss: 0.0865 - val_AUC: 0.7168 - 3s/epoch - 227ms/step
# Epoch 25/40
# 15/15 - 3s - loss: 0.1256 - AUC: 0.7163 - val_loss: 0.0871 - val_AUC: 0.7334 - 3s/epoch - 228ms/step
# Epoch 26/40
# 15/15 - 3s - loss: 0.1247 - AUC: 0.7115 - val_loss: 0.0884 - val_AUC: 0.7900 - 3s/epoch - 224ms/step
# Epoch 27/40
# 15/15 - 3s - loss: 0.1245 - AUC: 0.7190 - val_loss: 0.0865 - val_AUC: 0.7651 - 3s/epoch - 225ms/step
# Epoch 28/40
# 15/15 - 3s - loss: 0.1243 - AUC: 0.7056 - val_loss: 0.0845 - val_AUC: 0.7331 - 3s/epoch - 231ms/step
# Epoch 29/40
# 15/15 - 3s - loss: 0.1236 - AUC: 0.7011 - val_loss: 0.0845 - val_AUC: 0.6741 - 3s/epoch - 222ms/step
# Epoch 30/40
# 15/15 - 3s - loss: 0.1281 - AUC: 0.6851 - val_loss: 0.0875 - val_AUC: 0.7188 - 3s/epoch - 223ms/step
# Epoch 31/40
# 15/15 - 3s - loss: 0.1299 - AUC: 0.6857 - val_loss: 0.0891 - val_AUC: 0.7743 - 3s/epoch - 229ms/step
# Epoch 32/40
# 15/15 - 3s - loss: 0.1266 - AUC: 0.7228 - val_loss: 0.0856 - val_AUC: 0.7366 - 3s/epoch - 229ms/step
# Epoch 33/40
# 15/15 - 3s - loss: 0.1296 - AUC: 0.7094 - val_loss: 0.0910 - val_AUC: 0.7468 - 3s/epoch - 223ms/step
# Epoch 34/40
# 15/15 - 3s - loss: 0.1294 - AUC: 0.7082 - val_loss: 0.0839 - val_AUC: 0.6565 - 3s/epoch - 229ms/step
# Epoch 35/40
# 15/15 - 3s - loss: 0.1273 - AUC: 0.7051 - val_loss: 0.0918 - val_AUC: 0.7286 - 3s/epoch - 229ms/step
# Epoch 36/40
# 15/15 - 3s - loss: 0.1280 - AUC: 0.7281 - val_loss: 0.0871 - val_AUC: 0.7522 - 3s/epoch - 224ms/step
# Epoch 37/40
# 15/15 - 3s - loss: 0.1257 - AUC: 0.7291 - val_loss: 0.0834 - val_AUC: 0.7192 - 3s/epoch - 221ms/step
# Epoch 38/40
# 15/15 - 4s - loss: 0.1236 - AUC: 0.7297 - val_loss: 0.0817 - val_AUC: 0.7354 - 4s/epoch - 237ms/step
# Epoch 39/40
# 15/15 - 3s - loss: 0.1208 - AUC: 0.7352 - val_loss: 0.0804 - val_AUC: 0.7699 - 3s/epoch - 223ms/step
# Epoch 40/40
# 15/15 - 3s - loss: 0.1194 - AUC: 0.7479 - val_loss: 0.0798 - val_AUC: 0.8091 - 3s/epoch - 226ms/step

# %%
disease_pipeline.predict([df.iloc[133].Smiles]), df.iloc[133].Disease
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b3978c89cf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b397897d240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# ({'digestive_system_disease': array([[0.44990876]], dtype=float32),
#   'skin_and_connective_tissue_disease': array([[0.00795242]], dtype=float32),
#   'cardiovascular_disease': array([[0.22503713]], dtype=float32),
#   'immune_system_disease': array([[0.1450851]], dtype=float32),
#   'mental_and_behavioural_disorder': array([[0.0030801]], dtype=float32),
#   'metabolic_disease': array([[0.09662353]], dtype=float32),
#   'nervous_system_disease': array([[0.03983595]], dtype=float32),
#   'urinary_system_disease': array([[0.20622356]], dtype=float32)},
#  'digestive_system_disease')

# %%
disease_pipeline.train_history['cardiovascular_disease']

# %%
for model in disease_pipeline.models:
  with open(f'./drive/MyDrive/Models/{model}', 'wb') as f:
    pickle.dump(disease_pipeline.models[model], f)

# %%
# !ls ./drive/MyDrive/Models
# Out:
# cardiovascular_disease		 mental_disease
# digestive_disease		 metabolic_disease
# digestive_system_disease	 nervous_system_disease
# immune_disease			 skin_and_connective_tissue_disease
# immune_system_disease		 urinary_disease
# mental_and_behavioural_disorder  urinary_system_disease
