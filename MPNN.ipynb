# %% [markdown]
# <a href="https://colab.research.google.com/github/lockiultra/SCAMT/blob/main/MPNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install rdkit-pypi
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 40.3 MB/s eta 0:00:00

# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import re
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.Draw import MolsToGridImage

warnings.filterwarnings("ignore")
RDLogger.DisableLog("rdApp.*")

np.random.seed(42)
tf.random.set_seed(42)

# Featurizers

class Featurizer:
    def __init__(self, allowable_sets):
        self.dim = 0
        self.feature_mapping = {}
        for k, s in allowable_sets.items():
            s = sorted(list(s))
            self.feature_mapping[k] = dict(zip(s, range(self.dim, self.dim + len(s))))
            self.dim += len(s)

    def encode(self, inputs):
        output = np.zeros((self.dim,))
        for name_feature, feature_mapping in self.feature_mapping.items():
            feature = getattr(self, name_feature)(inputs)
            if feature not in feature_mapping:
                continue
            output[feature_mapping[feature]] = 1.0
        return output


class AtomFeaturizer(Featurizer):
    def __init__(self, allowable_sets):
        super().__init__(allowable_sets)

    def symbol(self, atom):
        return atom.GetSymbol()

    def n_valence(self, atom):
        return atom.GetTotalValence()

    def n_hydrogens(self, atom):
        return atom.GetTotalNumHs()

    def hybridization(self, atom):
        return atom.GetHybridization().name.lower()


class BondFeaturizer(Featurizer):
    def __init__(self, allowable_sets):
        super().__init__(allowable_sets)

    def encode(self, bond):
        output = np.zeros((self.dim,))
        if bond is None:
            output[-1] = 1.0
            return output
        output = super().encode(bond)
        return output

    def bond_type(self, bond):
        return bond.GetBondType().name.lower()

    def conjugated(self, bond):
        return bond.GetIsConjugated()
# Model

class EdgeNetwork(layers.Layer):
    def build(self, input_shape):
        self.atom_dim = input_shape[0][-1]
        self.bond_dim = input_shape[1][-1]
        self.kernel  = self.add_weight(
            shape=(self.bond_dim, self.atom_dim * self.atom_dim),
            initializer="glorot_uniform",
            name="kernel",
        )
        self.bias = self.add_weight(
            shape=(self.atom_dim * self.atom_dim),
            initializer="zeros",
            name="bias",
        )
        self.built = True

    def call(self, inputs):
        atom_features, bond_features, pair_indices = inputs
        bond_features = tf.matmul(bond_features, self.kernel) + self.bias
        bond_features = tf.reshape(bond_features, (-1, self.atom_dim, self.atom_dim))
        atom_features_neighbors = tf.gather(atom_features, pair_indices[:, 1])
        atom_features_neighbors = tf.expand_dims(atom_features_neighbors, axis=-1)
        transformed_features = tf.matmul(bond_features, atom_features_neighbors)
        transformed_features = tf.squeeze(transformed_features, axis=-1)
        aggregated_features = tf.math.unsorted_segment_sum(
            transformed_features,
            pair_indices[:, 0],
            num_segments=tf.shape(atom_features)[0]
        )
        return aggregated_features

class MessagePassing(layers.Layer):
    def __init__(self, units, steps=4, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.steps = steps

    def build(self, input_shape):
        self.atom_dim = input_shape[0][-1]
        self.message_step = EdgeNetwork()
        self.pad_length = max(0, self.units - self.atom_dim)
        self.update_step = layers.GRUCell(self.atom_dim + self.pad_length)
        self.built = True

    def call(self, inputs):
        atom_features, bond_features, pair_indices = inputs
        atom_features_updated = tf.pad(atom_features, [[0, 0], [self.pad_length, 0]])
        for i in range(self.steps):
            atom_features_aggregated = self.message_step([atom_features_updated, bond_features, pair_indices])
            atom_features_updated, _ = self.update_step(atom_features_aggregated, atom_features_updated)
        return atom_features_updated

class PartitionPadding(layers.Layer):
    def __init__(self, batch_size, **kwargs):
        super().__init__(**kwargs)
        self.batch_size = batch_size

    def call(self, inputs):
        atom_features, molecule_indicator = inputs
        atom_features_partitioned = tf.dynamic_partition(atom_features, molecule_indicator, self.batch_size)
        num_atoms = [tf.shape(x)[0] for x in atom_features_partitioned]
        max_num_atoms = tf.reduce_max(num_atoms)
        atom_features_stacked = tf.stack(
            [
                tf.pad(f, [(0, max_num_atoms - n), (0, 0)]) for f, n in zip(atom_features_partitioned, num_atoms)
            ],
            axis=0
        )
        gather_indices = tf.where(tf.reduce_sum(atom_features_stacked, (1, 2)) != 0)
        gather_indices = tf.squeeze(gather_indices, axis=-1)
        return tf.gather(atom_features_stacked, gather_indices, axis=0)

class TransformerEncoderReadout(layers.Layer):
    def __init__(self, num_heads=8, embed_dim=64, dense_dim=512, batch_size=32, **kwargs):
        super().__init__(**kwargs)
        self.partition_padding = PartitionPadding(batch_size)
        self.attention = layers.MultiHeadAttention(num_heads, embed_dim)
        self.dense_proj = keras.Sequential(
            [
                layers.Dense(dense_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.average_pooling = layers.GlobalAveragePooling1D()

    def call(self, inputs):
        x = self.partition_padding(inputs)
        padding_mask = tf.reduce_any(tf.not_equal(x, 0.0), axis=-1)
        padding_mask = padding_mask[:, tf.newaxis, tf.newaxis, :]
        attention_output = self.attention(x, x, attention_mask=padding_mask)
        proj_input = self.layernorm_1(x + attention_output)
        proj_output = self.layernorm_2(proj_input + self.dense_proj(proj_input))
        return self.average_pooling(proj_output)

def MPNNModel(atom_dim, bond_dim, batch_size=32, message_units=64, message_steps=4, num_attention_heads=8, dense_units=512):
    atom_features = layers.Input((atom_dim,), dtype=tf.float32, name="atom_features")
    bond_features = layers.Input((bond_dim,), dtype=tf.float32, name="bond_features")
    pair_indices = layers.Input((2,), dtype=tf.int32, name="pair_indices")
    molecule_indicator = layers.Input((), dtype=tf.int32, name="molecule_indicator")
    x = MessagePassing(message_units, message_steps)([atom_features, bond_features, pair_indices])
    x = TransformerEncoderReadout(num_attention_heads, message_units, dense_units, batch_size)([x, molecule_indicator])
    x = layers.Dense(dense_units, activation="relu")(x)
    x = layers.Dense(1, activation="sigmoid")(x)
    model = keras.Model(inputs=[atom_features, bond_features, pair_indices, molecule_indicator], outputs=[x])
    return model

# %%
pattern = r'\.csv$'
files = [f for f in os.listdir('./drive/MyDrive/data/molecule') if re.search(pattern, f)]

# %%
data = pd.DataFrame(columns=['Name', 'Smiles', 'Disease'])

# %%
for f in files:
  tmp_df = pd.read_csv(f'./drive/MyDrive/data/molecule/{f}', usecols=['Name', 'Smiles'], sep=';')
  tmp_df['Disease'] = f[:-4]
  frames = [data, tmp_df]
  data = pd.concat(frames)

# %%
data
# Out:
#                Name                                             Smiles  \
# 0        ERLOSAMIDE                  COC[C@@H](NC(C)=O)C(=O)NCc1ccccc1
# 1       FLUNARIZINE  Fc1ccc(C(c2ccc(F)cc2)N2CCN(C/C=C/c3ccccc3)CC2)cc1
# 2       PROXIBARBAL                     C=CCC1(CC(C)O)C(=O)NC(=O)NC1=O
# 3    DESVENLAFAXINE                    CN(C)CC(c1ccc(O)cc1)C1(O)CCCCC1
# 4       RISPERIDONE  Cc1nc2n(c(=O)c1CCN1CCC(c3noc4cc(F)ccc34)CC1)CCCC2
# ..              ...                                                ...
# 128     CABERGOLINE  C=CCN1C[C@H](C(=O)N(CCCN(C)C)C(=O)NCC)C[C@@H]2...
# 129      CICLOPIROX                         Cc1cc(C2CCCCC2)n(O)c(=O)c1
# 130     DEQUALINIUM  Cc1cc(N)c2ccccc2[n+]1CCCCCCCCCC[n+]1c(C)cc(N)c...
# 131   SERTACONAZOLE     Clc1ccc(C(Cn2ccnc2)OCc2csc3c(Cl)cccc23)c(Cl)c1
# 132   ALLYLESTRENOL  C=CC[C@]1(O)CC[C@H]2[C@@H]3CCC4=CCCCC4[C@H]3CC...
#
#              Disease
# 0     mental_disease
# 1     mental_disease
# 2     mental_disease
# 3     mental_disease
# 4     mental_disease
# ..               ...
# 128  urinary_disease
# 129  urinary_disease
# 130  urinary_disease
# 131  urinary_disease
# 132  urinary_disease
#
# [789 rows x 3 columns]

# %%
class DiseasePipeline:
  def __init__(self, data: pd.DataFrame):
    self.diseases = data.Disease.unique()
    self.atom_featurizer = AtomFeaturizer(
      allowable_sets={
        "symbol": {'B', 'Br', 'C', 'Ca', 'Cl', 'F', 'H', 'I', 'N', 'Na', 'O', 'P', 'S'},
        "n_valence": {0, 1, 2, 3, 4, 5, 6},
        "n_hydrogens": {0, 1, 2, 3, 4},
        "hybridization": {'s', 'sp', 'sp2', 'sp3'},
      }
    )
    self.bond_featurizer = BondFeaturizer(
      allowable_sets={
        "bond_type": {'single', 'double', 'triple', 'aromatic'},
        "conjugated": {False, True},
      }
    )
    self.x_train, self.y_train, self.x_val, self.y_val = self.__get_train_val_data(data)
    self.models = {disease: MPNNModel(atom_dim=self.x_train[0][0][0].shape[0], bond_dim=self.x_train[1][0][0].shape[0]) for disease in self.diseases}
    self.is_trained = False

  def train(self):
    for i, disease in enumerate(self.diseases):
      print(f'\n{i}======={disease}=======\n')
      train_dataset = self.__get_dataset(self.x_train, self.y_train, disease)
      val_dataset = self.__get_dataset(self.x_val, self.y_val, disease)
      self.models[disease].compile(
        loss=keras.losses.BinaryCrossentropy(),
        optimizer=keras.optimizers.Adam(learning_rate=5e-4),
        metrics=[keras.metrics.AUC(name='AUC')],
      )
      history = self.models[disease].fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=40,
        verbose=2,
      )
    self.is_trained = True

  def predict(self, smiles):
    if not self.is_trained:
      print('Error! Model is not trained')
      return
    result = {disease: None for disease in self.diseases}
    g = self.graph_from_smiles(smiles)
    dataset = tf.data.Dataset.from_tensors(((g), (1))).map(self.prepare_batch, -1).prefetch(-1)
    for disease, model in zip(self.models.keys(), self.models.values()):
      result[disease] = model.predict(dataset)
    return result


  def __get_train_val_data(self, data):
    data = data.dropna()
    permutation = np.random.permutation(np.arange(data.shape[0]))
    train_index = permutation[:int(data.shape[0] * 0.8)]
    x_train = self.graph_from_smiles(data.iloc[train_index].Smiles)
    y_train = data.iloc[train_index].Disease
    val_index = permutation[int(data.shape[0] * 0.8):]
    x_val = self.graph_from_smiles(data.iloc[val_index].Smiles)
    y_val = data.iloc[val_index].Disease
    return (x_train, y_train, x_val, y_val)

  def __get_dataset(self, X, y, curr_disease, batch_size=32, shuffle=False):
    replace_disease_dict = {
      x: 1 if x == curr_disease else 0 for x in self.diseases
    }
    y = y.replace(replace_disease_dict)
    dataset = tf.data.Dataset.from_tensor_slices((X, (y)))
    if shuffle:
      dataset = dataset.shuffle(1024)
    return dataset.batch(batch_size).map(self.prepare_batch, -1).prefetch(-1)

  def prepare_batch(self, x_batch, y_batch):
    atom_features, bond_features, pair_indices = x_batch
    num_atoms = atom_features.row_lengths()
    num_bonds = bond_features.row_lengths()
    molecule_indices = tf.range(len(num_atoms))
    molecule_indicator = tf.repeat(molecule_indices, num_atoms)
    gather_indices = tf.repeat(molecule_indices[:-1], num_bonds[1:])
    increment = tf.cumsum(num_atoms[:-1])
    increment = tf.pad(tf.gather(increment, gather_indices), [(num_bonds[0], 0)])
    pair_indices = pair_indices.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    pair_indices = pair_indices + increment[:, tf.newaxis]
    atom_features = atom_features.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    bond_features = bond_features.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    return (atom_features, bond_features, pair_indices, molecule_indicator), y_batch

  def molecule_from_smiles(self, smiles):
    molecule = Chem.MolFromSmiles(smiles, sanitize=False)
    flag = Chem.SanitizeMol(molecule, catchErrors=True)
    if flag != Chem.SanitizeFlags.SANITIZE_NONE:
        Chem.SanitizeMol(molecule, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ flag)
    Chem.AssignStereochemistry(molecule, cleanIt=True, force=True)
    return molecule

  def graph_from_molecule(self, molecule):
      atom_features = []
      bond_features = []
      pair_indices = []
      for atom in molecule.GetAtoms():
          atom_features.append(self.atom_featurizer.encode(atom))
          pair_indices.append((atom.GetIdx(), atom.GetIdx()))
          bond_features.append(self.bond_featurizer.encode(None))
          for neighbor in atom.GetNeighbors():
              bond = molecule.GetBondBetweenAtoms(atom.GetIdx(), neighbor.GetIdx())
              pair_indices.append((atom.GetIdx(), neighbor.GetIdx()))
              bond_features.append(self.bond_featurizer.encode(bond))
      return np.array(atom_features), np.array(bond_features), np.array(pair_indices)

  def graph_from_smiles(self, smiles_list):
      atom_features_list = []
      bond_features_list = []
      pair_indices_list = []
      for smiles in smiles_list:
          molecule = self.molecule_from_smiles(smiles)
          atom_features, bond_features, pair_indices = self.graph_from_molecule(molecule)
          atom_features_list.append(atom_features)
          bond_features_list.append(bond_features)
          pair_indices_list.append(pair_indices)
      return (
          tf.ragged.constant(atom_features_list, dtype=tf.float32),
          tf.ragged.constant(bond_features_list, dtype=tf.float32),
          tf.ragged.constant(pair_indices_list, dtype=tf.int64),
      )

# %%
disease_pipeline = DiseasePipeline(data)

# %%
disease_pipeline.train()
# Out:
# 0=======mental_disease=======
#
# Epoch 1/40
# 20/20 - 21s - loss: 0.6828 - AUC: 0.5958 - val_loss: 0.6139 - val_AUC: 0.6890 - 21s/epoch - 1s/step
# Epoch 2/40
# 20/20 - 12s - loss: 0.6367 - AUC: 0.6720 - val_loss: 0.5971 - val_AUC: 0.7221 - 12s/epoch - 589ms/step
# Epoch 3/40
# 20/20 - 10s - loss: 0.6078 - AUC: 0.7190 - val_loss: 0.5517 - val_AUC: 0.8059 - 10s/epoch - 506ms/step
# Epoch 4/40
# 20/20 - 12s - loss: 0.5840 - AUC: 0.7485 - val_loss: 0.4929 - val_AUC: 0.8391 - 12s/epoch - 576ms/step
# Epoch 5/40
# 20/20 - 12s - loss: 0.5553 - AUC: 0.7841 - val_loss: 0.4974 - val_AUC: 0.8380 - 12s/epoch - 593ms/step
# Epoch 6/40
# 20/20 - 13s - loss: 0.5515 - AUC: 0.7813 - val_loss: 0.5080 - val_AUC: 0.8363 - 13s/epoch - 638ms/step
# Epoch 7/40
# 20/20 - 10s - loss: 0.5518 - AUC: 0.7796 - val_loss: 0.5108 - val_AUC: 0.8564 - 10s/epoch - 518ms/step
# Epoch 8/40
# 20/20 - 12s - loss: 0.5527 - AUC: 0.7846 - val_loss: 0.4825 - val_AUC: 0.8410 - 12s/epoch - 602ms/step
# Epoch 9/40
# 20/20 - 12s - loss: 0.5538 - AUC: 0.7880 - val_loss: 0.4731 - val_AUC: 0.8478 - 12s/epoch - 602ms/step
# Epoch 10/40
# 20/20 - 12s - loss: 0.5520 - AUC: 0.7872 - val_loss: 0.4948 - val_AUC: 0.8401 - 12s/epoch - 601ms/step
# Epoch 11/40
# 20/20 - 10s - loss: 0.5672 - AUC: 0.7718 - val_loss: 0.5188 - val_AUC: 0.8190 - 10s/epoch - 489ms/step
# Epoch 12/40
# 20/20 - 12s - loss: 0.5356 - AUC: 0.8041 - val_loss: 0.4696 - val_AUC: 0.8517 - 12s/epoch - 590ms/step
# Epoch 13/40
# 20/20 - 11s - loss: 0.5258 - AUC: 0.8112 - val_loss: 0.4994 - val_AUC: 0.8410 - 11s/epoch - 560ms/step
# Epoch 14/40
# 20/20 - 12s - loss: 0.5248 - AUC: 0.8110 - val_loss: 0.5003 - val_AUC: 0.8455 - 12s/epoch - 600ms/step
# Epoch 15/40
# 20/20 - 12s - loss: 0.5259 - AUC: 0.8101 - val_loss: 0.5347 - val_AUC: 0.8457 - 12s/epoch - 591ms/step
# Epoch 16/40
# 20/20 - 11s - loss: 0.5309 - AUC: 0.8076 - val_loss: 0.5777 - val_AUC: 0.8594 - 11s/epoch - 543ms/step
# Epoch 17/40
# 20/20 - 11s - loss: 0.5347 - AUC: 0.8011 - val_loss: 0.5278 - val_AUC: 0.8512 - 11s/epoch - 562ms/step
# Epoch 18/40
# 20/20 - 11s - loss: 0.4908 - AUC: 0.8383 - val_loss: 0.5104 - val_AUC: 0.8649 - 11s/epoch - 572ms/step
# Epoch 19/40
# 20/20 - 12s - loss: 0.4894 - AUC: 0.8406 - val_loss: 0.5412 - val_AUC: 0.8608 - 12s/epoch - 593ms/step
# Epoch 20/40
# 20/20 - 9s - loss: 0.4894 - AUC: 0.8365 - val_loss: 0.5465 - val_AUC: 0.8585 - 9s/epoch - 473ms/step
# Epoch 21/40
# 20/20 - 11s - loss: 0.5008 - AUC: 0.8288 - val_loss: 0.5355 - val_AUC: 0.8609 - 11s/epoch - 532ms/step
# Epoch 22/40
# 20/20 - 12s - loss: 0.4954 - AUC: 0.8337 - val_loss: 0.5360 - val_AUC: 0.8541 - 12s/epoch - 598ms/step
# Epoch 23/40
# 20/20 - 12s - loss: 0.4728 - AUC: 0.8527 - val_loss: 0.5294 - val_AUC: 0.8616 - 12s/epoch - 589ms/step
# Epoch 24/40
# 20/20 - 12s - loss: 0.4662 - AUC: 0.8585 - val_loss: 0.5266 - val_AUC: 0.8707 - 12s/epoch - 593ms/step
# Epoch 25/40
# 20/20 - 11s - loss: 0.4615 - AUC: 0.8605 - val_loss: 0.5427 - val_AUC: 0.8641 - 11s/epoch - 572ms/step
# Epoch 26/40
# 20/20 - 12s - loss: 0.4771 - AUC: 0.8512 - val_loss: 0.5782 - val_AUC: 0.8605 - 12s/epoch - 577ms/step
# Epoch 27/40
# 20/20 - 12s - loss: 0.4737 - AUC: 0.8497 - val_loss: 0.5418 - val_AUC: 0.8498 - 12s/epoch - 611ms/step
# Epoch 28/40
# 20/20 - 12s - loss: 0.4554 - AUC: 0.8639 - val_loss: 0.4966 - val_AUC: 0.8651 - 12s/epoch - 599ms/step
# Epoch 29/40
# 20/20 - 11s - loss: 0.4419 - AUC: 0.8759 - val_loss: 0.4985 - val_AUC: 0.8547 - 11s/epoch - 574ms/step
# Epoch 30/40
# 20/20 - 20s - loss: 0.4197 - AUC: 0.8870 - val_loss: 0.4790 - val_AUC: 0.8731 - 20s/epoch - 1s/step
# Epoch 31/40
# 20/20 - 12s - loss: 0.4125 - AUC: 0.8921 - val_loss: 0.5151 - val_AUC: 0.8598 - 12s/epoch - 613ms/step
# Epoch 32/40
# 20/20 - 12s - loss: 0.4031 - AUC: 0.8969 - val_loss: 0.5221 - val_AUC: 0.8629 - 12s/epoch - 603ms/step
# Epoch 33/40
# 20/20 - 12s - loss: 0.4027 - AUC: 0.8978 - val_loss: 0.5057 - val_AUC: 0.8569 - 12s/epoch - 587ms/step
# Epoch 34/40
# 20/20 - 12s - loss: 0.3757 - AUC: 0.9133 - val_loss: 0.4963 - val_AUC: 0.8633 - 12s/epoch - 605ms/step
# Epoch 35/40
# 20/20 - 12s - loss: 0.3912 - AUC: 0.9035 - val_loss: 0.4875 - val_AUC: 0.8525 - 12s/epoch - 625ms/step
# Epoch 36/40
# 20/20 - 12s - loss: 0.3863 - AUC: 0.9076 - val_loss: 0.4658 - val_AUC: 0.8684 - 12s/epoch - 581ms/step
# Epoch 37/40
# 20/20 - 11s - loss: 0.3745 - AUC: 0.9125 - val_loss: 0.5441 - val_AUC: 0.8741 - 11s/epoch - 568ms/step
# Epoch 38/40
# 20/20 - 12s - loss: 0.3548 - AUC: 0.9230 - val_loss: 0.4613 - val_AUC: 0.8729 - 12s/epoch - 618ms/step
# Epoch 39/40
# 20/20 - 10s - loss: 0.3507 - AUC: 0.9237 - val_loss: 0.4873 - val_AUC: 0.8865 - 10s/epoch - 515ms/step
# Epoch 40/40
# 20/20 - 12s - loss: 0.3396 - AUC: 0.9286 - val_loss: 0.5913 - val_AUC: 0.8685 - 12s/epoch - 612ms/step
#
# 1=======cardiovascular_disease=======
#
# Epoch 1/40
# 20/20 - 19s - loss: 0.5890 - AUC: 0.5565 - val_loss: 0.6155 - val_AUC: 0.6365 - 19s/epoch - 956ms/step
# Epoch 2/40
# 20/20 - 12s - loss: 0.5632 - AUC: 0.6309 - val_loss: 0.6061 - val_AUC: 0.6823 - 12s/epoch - 587ms/step
# Epoch 3/40
# 20/20 - 12s - loss: 0.5201 - AUC: 0.7343 - val_loss: 0.5837 - val_AUC: 0.7292 - 12s/epoch - 580ms/step
# Epoch 4/40
# 20/20 - 12s - loss: 0.5053 - AUC: 0.7576 - val_loss: 0.5583 - val_AUC: 0.7509 - 12s/epoch - 589ms/step
# Epoch 5/40
# 20/20 - 12s - loss: 0.4929 - AUC: 0.7732 - val_loss: 0.5552 - val_AUC: 0.7560 - 12s/epoch - 610ms/step
# Epoch 6/40
# 20/20 - 12s - loss: 0.4824 - AUC: 0.7849 - val_loss: 0.5614 - val_AUC: 0.7588 - 12s/epoch - 581ms/step
# Epoch 7/40
# 20/20 - 13s - loss: 0.4886 - AUC: 0.7776 - val_loss: 0.5483 - val_AUC: 0.7774 - 13s/epoch - 648ms/step
# Epoch 8/40
# 20/20 - 12s - loss: 0.4893 - AUC: 0.7736 - val_loss: 0.5545 - val_AUC: 0.7698 - 12s/epoch - 590ms/step
# Epoch 9/40
# 20/20 - 11s - loss: 0.4884 - AUC: 0.7723 - val_loss: 0.5385 - val_AUC: 0.7874 - 11s/epoch - 543ms/step
# Epoch 10/40
# 20/20 - 11s - loss: 0.5148 - AUC: 0.7341 - val_loss: 0.5589 - val_AUC: 0.7576 - 11s/epoch - 566ms/step
# Epoch 11/40
# 20/20 - 10s - loss: 0.5018 - AUC: 0.7530 - val_loss: 0.5439 - val_AUC: 0.7608 - 10s/epoch - 497ms/step
# Epoch 12/40
# 20/20 - 12s - loss: 0.5143 - AUC: 0.7352 - val_loss: 0.5701 - val_AUC: 0.7817 - 12s/epoch - 588ms/step
# Epoch 13/40
# 20/20 - 12s - loss: 0.4985 - AUC: 0.7567 - val_loss: 0.5418 - val_AUC: 0.7789 - 12s/epoch - 611ms/step
# Epoch 14/40
# 20/20 - 12s - loss: 0.4901 - AUC: 0.7704 - val_loss: 0.5544 - val_AUC: 0.7764 - 12s/epoch - 582ms/step
# Epoch 15/40
# 20/20 - 12s - loss: 0.4812 - AUC: 0.7821 - val_loss: 0.5570 - val_AUC: 0.7920 - 12s/epoch - 593ms/step
# Epoch 16/40
# 20/20 - 10s - loss: 0.4787 - AUC: 0.7798 - val_loss: 0.5503 - val_AUC: 0.7764 - 10s/epoch - 515ms/step
# Epoch 17/40
# 20/20 - 12s - loss: 0.4677 - AUC: 0.7968 - val_loss: 0.5443 - val_AUC: 0.8024 - 12s/epoch - 591ms/step
# Epoch 18/40
# 20/20 - 10s - loss: 0.4618 - AUC: 0.8017 - val_loss: 0.5499 - val_AUC: 0.7877 - 10s/epoch - 513ms/step
# Epoch 19/40
# 20/20 - 12s - loss: 0.4498 - AUC: 0.8150 - val_loss: 0.5399 - val_AUC: 0.8009 - 12s/epoch - 605ms/step
# Epoch 20/40
# 20/20 - 12s - loss: 0.4536 - AUC: 0.8091 - val_loss: 0.5362 - val_AUC: 0.7994 - 12s/epoch - 607ms/step
# Epoch 21/40
# 20/20 - 12s - loss: 0.4468 - AUC: 0.8160 - val_loss: 0.5511 - val_AUC: 0.7947 - 12s/epoch - 607ms/step
# Epoch 22/40
# 20/20 - 12s - loss: 0.4227 - AUC: 0.8418 - val_loss: 0.5013 - val_AUC: 0.8248 - 12s/epoch - 602ms/step
# Epoch 23/40
# 20/20 - 14s - loss: 0.4507 - AUC: 0.8161 - val_loss: 0.5454 - val_AUC: 0.8021 - 14s/epoch - 705ms/step
# Epoch 24/40
# 20/20 - 13s - loss: 0.4314 - AUC: 0.8318 - val_loss: 0.5192 - val_AUC: 0.8016 - 13s/epoch - 626ms/step
# Epoch 25/40
# 20/20 - 12s - loss: 0.4340 - AUC: 0.8270 - val_loss: 0.5405 - val_AUC: 0.8124 - 12s/epoch - 585ms/step
# Epoch 26/40
# 20/20 - 12s - loss: 0.4220 - AUC: 0.8392 - val_loss: 0.5669 - val_AUC: 0.7983 - 12s/epoch - 580ms/step
# Epoch 27/40
# 20/20 - 12s - loss: 0.4150 - AUC: 0.8438 - val_loss: 0.5708 - val_AUC: 0.7877 - 12s/epoch - 611ms/step
# Epoch 28/40
# 20/20 - 11s - loss: 0.4350 - AUC: 0.8251 - val_loss: 0.5226 - val_AUC: 0.8179 - 11s/epoch - 571ms/step
# Epoch 29/40
# 20/20 - 12s - loss: 0.4211 - AUC: 0.8410 - val_loss: 0.5189 - val_AUC: 0.8191 - 12s/epoch - 611ms/step
# Epoch 30/40
# 20/20 - 10s - loss: 0.3949 - AUC: 0.8661 - val_loss: 0.5373 - val_AUC: 0.8181 - 10s/epoch - 497ms/step
# Epoch 31/40
# 20/20 - 12s - loss: 0.3880 - AUC: 0.8667 - val_loss: 0.5079 - val_AUC: 0.8241 - 12s/epoch - 598ms/step
# Epoch 32/40
# 20/20 - 12s - loss: 0.3903 - AUC: 0.8660 - val_loss: 0.5210 - val_AUC: 0.8294 - 12s/epoch - 617ms/step
# Epoch 33/40
# 20/20 - 12s - loss: 0.3610 - AUC: 0.8884 - val_loss: 0.5186 - val_AUC: 0.8278 - 12s/epoch - 608ms/step
# Epoch 34/40
# 20/20 - 11s - loss: 0.3591 - AUC: 0.8901 - val_loss: 0.5299 - val_AUC: 0.8237 - 11s/epoch - 572ms/step
# Epoch 35/40
# 20/20 - 12s - loss: 0.3607 - AUC: 0.8881 - val_loss: 0.5374 - val_AUC: 0.7976 - 12s/epoch - 600ms/step
# Epoch 36/40
# 20/20 - 12s - loss: 0.3690 - AUC: 0.8828 - val_loss: 0.5999 - val_AUC: 0.7862 - 12s/epoch - 611ms/step
# Epoch 37/40
# 20/20 - 11s - loss: 0.3663 - AUC: 0.8847 - val_loss: 0.5305 - val_AUC: 0.8236 - 11s/epoch - 572ms/step
# Epoch 38/40
# 20/20 - 13s - loss: 0.3439 - AUC: 0.8998 - val_loss: 0.6158 - val_AUC: 0.7916 - 13s/epoch - 651ms/step
# Epoch 39/40
# 20/20 - 12s - loss: 0.3238 - AUC: 0.9108 - val_loss: 0.5945 - val_AUC: 0.7913 - 12s/epoch - 588ms/step
# Epoch 40/40
# 20/20 - 12s - loss: 0.3196 - AUC: 0.9143 - val_loss: 0.6862 - val_AUC: 0.7434 - 12s/epoch - 596ms/step
#
# 2=======digestive_disease=======
#
# Epoch 1/40
# 20/20 - 19s - loss: 0.2304 - AUC: 0.5298 - val_loss: 0.1833 - val_AUC: 0.4948 - 19s/epoch - 949ms/step
# Epoch 2/40
# 20/20 - 10s - loss: 0.1889 - AUC: 0.4988 - val_loss: 0.1827 - val_AUC: 0.4838 - 10s/epoch - 479ms/step
# Epoch 3/40
# 20/20 - 12s - loss: 0.1882 - AUC: 0.5557 - val_loss: 0.1830 - val_AUC: 0.5638 - 12s/epoch - 583ms/step
# Epoch 4/40
# 20/20 - 12s - loss: 0.1861 - AUC: 0.5923 - val_loss: 0.1835 - val_AUC: 0.5681 - 12s/epoch - 604ms/step
# Epoch 5/40
# 20/20 - 9s - loss: 0.1811 - AUC: 0.6646 - val_loss: 0.1854 - val_AUC: 0.5652 - 9s/epoch - 449ms/step
# Epoch 6/40
# 20/20 - 12s - loss: 0.1715 - AUC: 0.7515 - val_loss: 0.1964 - val_AUC: 0.5543 - 12s/epoch - 596ms/step
# Epoch 7/40
# 20/20 - 12s - loss: 0.1626 - AUC: 0.7980 - val_loss: 0.2034 - val_AUC: 0.5800 - 12s/epoch - 607ms/step
# Epoch 8/40
# 20/20 - 12s - loss: 0.1564 - AUC: 0.8187 - val_loss: 0.1959 - val_AUC: 0.6248 - 12s/epoch - 587ms/step
# Epoch 9/40
# 20/20 - 12s - loss: 0.1567 - AUC: 0.8030 - val_loss: 0.1893 - val_AUC: 0.6329 - 12s/epoch - 595ms/step
# Epoch 10/40
# 20/20 - 12s - loss: 0.1488 - AUC: 0.8349 - val_loss: 0.1857 - val_AUC: 0.6490 - 12s/epoch - 603ms/step
# Epoch 11/40
# 20/20 - 11s - loss: 0.1492 - AUC: 0.8537 - val_loss: 0.2262 - val_AUC: 0.6352 - 11s/epoch - 554ms/step
# Epoch 12/40
# 20/20 - 12s - loss: 0.1506 - AUC: 0.8416 - val_loss: 0.1974 - val_AUC: 0.6476 - 12s/epoch - 583ms/step
# Epoch 13/40
# 20/20 - 12s - loss: 0.1600 - AUC: 0.7972 - val_loss: 0.1932 - val_AUC: 0.6352 - 12s/epoch - 603ms/step
# Epoch 14/40
# 20/20 - 12s - loss: 0.1415 - AUC: 0.8696 - val_loss: 0.1980 - val_AUC: 0.6595 - 12s/epoch - 575ms/step
# Epoch 15/40
# 20/20 - 12s - loss: 0.1384 - AUC: 0.8766 - val_loss: 0.2128 - val_AUC: 0.6581 - 12s/epoch - 581ms/step
# Epoch 16/40
# 20/20 - 10s - loss: 0.1553 - AUC: 0.8189 - val_loss: 0.1953 - val_AUC: 0.6329 - 10s/epoch - 482ms/step
# Epoch 17/40
# 20/20 - 11s - loss: 0.1363 - AUC: 0.8880 - val_loss: 0.2023 - val_AUC: 0.6471 - 11s/epoch - 566ms/step
# Epoch 18/40
# 20/20 - 12s - loss: 0.1425 - AUC: 0.8584 - val_loss: 0.1964 - val_AUC: 0.6633 - 12s/epoch - 603ms/step
# Epoch 19/40
# 20/20 - 12s - loss: 0.1216 - AUC: 0.9067 - val_loss: 0.2027 - val_AUC: 0.6548 - 12s/epoch - 591ms/step
# Epoch 20/40
# 20/20 - 12s - loss: 0.1323 - AUC: 0.8916 - val_loss: 0.1843 - val_AUC: 0.6667 - 12s/epoch - 584ms/step
# Epoch 21/40
# 20/20 - 12s - loss: 0.1295 - AUC: 0.8810 - val_loss: 0.1806 - val_AUC: 0.6886 - 12s/epoch - 604ms/step
# Epoch 22/40
# 20/20 - 10s - loss: 0.1203 - AUC: 0.9046 - val_loss: 0.1606 - val_AUC: 0.7243 - 10s/epoch - 503ms/step
# Epoch 23/40
# 20/20 - 12s - loss: 0.1009 - AUC: 0.9454 - val_loss: 0.1799 - val_AUC: 0.6862 - 12s/epoch - 605ms/step
# Epoch 24/40
# 20/20 - 11s - loss: 0.1078 - AUC: 0.9116 - val_loss: 0.1632 - val_AUC: 0.7324 - 11s/epoch - 570ms/step
# Epoch 25/40
# 20/20 - 10s - loss: 0.0823 - AUC: 0.9642 - val_loss: 0.1731 - val_AUC: 0.7429 - 10s/epoch - 498ms/step
# Epoch 26/40
# 20/20 - 12s - loss: 0.0886 - AUC: 0.9563 - val_loss: 0.1624 - val_AUC: 0.7695 - 12s/epoch - 607ms/step
# Epoch 27/40
# 20/20 - 12s - loss: 0.0809 - AUC: 0.9656 - val_loss: 0.2057 - val_AUC: 0.7690 - 12s/epoch - 578ms/step
# Epoch 28/40
# 20/20 - 12s - loss: 0.0838 - AUC: 0.9619 - val_loss: 0.1576 - val_AUC: 0.7676 - 12s/epoch - 590ms/step
# Epoch 29/40
# 20/20 - 10s - loss: 0.0861 - AUC: 0.9575 - val_loss: 0.1917 - val_AUC: 0.7233 - 10s/epoch - 505ms/step
# Epoch 30/40
# 20/20 - 11s - loss: 0.1057 - AUC: 0.9071 - val_loss: 0.1463 - val_AUC: 0.7571 - 11s/epoch - 574ms/step
# Epoch 31/40
# 20/20 - 12s - loss: 0.0830 - AUC: 0.9703 - val_loss: 0.1829 - val_AUC: 0.7429 - 12s/epoch - 591ms/step
# Epoch 32/40
# 20/20 - 12s - loss: 0.0748 - AUC: 0.9678 - val_loss: 0.1714 - val_AUC: 0.7686 - 12s/epoch - 603ms/step
# Epoch 33/40
# 20/20 - 11s - loss: 0.0876 - AUC: 0.9646 - val_loss: 0.1645 - val_AUC: 0.7524 - 11s/epoch - 543ms/step
# Epoch 34/40
# 20/20 - 11s - loss: 0.0757 - AUC: 0.9646 - val_loss: 0.1750 - val_AUC: 0.7695 - 11s/epoch - 571ms/step
# Epoch 35/40
# 20/20 - 11s - loss: 0.0746 - AUC: 0.9557 - val_loss: 0.1654 - val_AUC: 0.7638 - 11s/epoch - 548ms/step
# Epoch 36/40
# 20/20 - 10s - loss: 0.0595 - AUC: 0.9858 - val_loss: 0.1812 - val_AUC: 0.7733 - 10s/epoch - 513ms/step
# Epoch 37/40
# 20/20 - 11s - loss: 0.0580 - AUC: 0.9858 - val_loss: 0.1976 - val_AUC: 0.7067 - 11s/epoch - 574ms/step
# Epoch 38/40
# 20/20 - 11s - loss: 0.0609 - AUC: 0.9782 - val_loss: 0.1989 - val_AUC: 0.7676 - 11s/epoch - 548ms/step
# Epoch 39/40
# 20/20 - 12s - loss: 0.0693 - AUC: 0.9770 - val_loss: 0.2111 - val_AUC: 0.6757 - 12s/epoch - 603ms/step
# Epoch 40/40
# 20/20 - 11s - loss: 0.0640 - AUC: 0.9858 - val_loss: 0.2176 - val_AUC: 0.6410 - 11s/epoch - 574ms/step
#
# 3=======immune_disease=======
#
# Epoch 1/40
# 20/20 - 20s - loss: 0.2108 - AUC: 0.4606 - val_loss: 0.0921 - val_AUC: 0.6623 - 20s/epoch - 1s/step
# Epoch 2/40
# 20/20 - 10s - loss: 0.1753 - AUC: 0.5279 - val_loss: 0.1055 - val_AUC: 0.7468 - 10s/epoch - 493ms/step
# Epoch 3/40
# 20/20 - 11s - loss: 0.1719 - AUC: 0.5492 - val_loss: 0.1131 - val_AUC: 0.8160 - 11s/epoch - 562ms/step
# Epoch 4/40
# 20/20 - 12s - loss: 0.1703 - AUC: 0.6168 - val_loss: 0.1025 - val_AUC: 0.8582 - 12s/epoch - 583ms/step
# Epoch 5/40
# 20/20 - 10s - loss: 0.1531 - AUC: 0.7563 - val_loss: 0.0957 - val_AUC: 0.8626 - 10s/epoch - 503ms/step
# Epoch 6/40
# 20/20 - 11s - loss: 0.1516 - AUC: 0.7625 - val_loss: 0.0931 - val_AUC: 0.8885 - 11s/epoch - 574ms/step
# Epoch 7/40
# 20/20 - 12s - loss: 0.1479 - AUC: 0.7749 - val_loss: 0.0959 - val_AUC: 0.8864 - 12s/epoch - 596ms/step
# Epoch 8/40
# 20/20 - 10s - loss: 0.1472 - AUC: 0.7845 - val_loss: 0.0977 - val_AUC: 0.8907 - 10s/epoch - 507ms/step
# Epoch 9/40
# 20/20 - 12s - loss: 0.1449 - AUC: 0.7947 - val_loss: 0.0967 - val_AUC: 0.8777 - 12s/epoch - 604ms/step
# Epoch 10/40
# 20/20 - 12s - loss: 0.1439 - AUC: 0.7991 - val_loss: 0.0990 - val_AUC: 0.8615 - 12s/epoch - 596ms/step
# Epoch 11/40
# 20/20 - 10s - loss: 0.1418 - AUC: 0.8055 - val_loss: 0.1019 - val_AUC: 0.8496 - 10s/epoch - 478ms/step
# Epoch 12/40
# 20/20 - 12s - loss: 0.1380 - AUC: 0.8102 - val_loss: 0.0969 - val_AUC: 0.8593 - 12s/epoch - 587ms/step
# Epoch 13/40
# 20/20 - 11s - loss: 0.1334 - AUC: 0.8303 - val_loss: 0.1106 - val_AUC: 0.8528 - 11s/epoch - 561ms/step
# Epoch 14/40
# 20/20 - 12s - loss: 0.1348 - AUC: 0.8075 - val_loss: 0.0835 - val_AUC: 0.8766 - 12s/epoch - 598ms/step
# Epoch 15/40
# 20/20 - 11s - loss: 0.1293 - AUC: 0.8375 - val_loss: 0.0885 - val_AUC: 0.8950 - 11s/epoch - 573ms/step
# Epoch 16/40
# 20/20 - 10s - loss: 0.1283 - AUC: 0.8159 - val_loss: 0.1113 - val_AUC: 0.8961 - 10s/epoch - 494ms/step
# Epoch 17/40
# 20/20 - 12s - loss: 0.1298 - AUC: 0.8469 - val_loss: 0.1087 - val_AUC: 0.9048 - 12s/epoch - 593ms/step
# Epoch 18/40
# 20/20 - 11s - loss: 0.1195 - AUC: 0.8651 - val_loss: 0.0993 - val_AUC: 0.8896 - 11s/epoch - 556ms/step
# Epoch 19/40
# 20/20 - 11s - loss: 0.1204 - AUC: 0.8618 - val_loss: 0.0878 - val_AUC: 0.9188 - 11s/epoch - 547ms/step
# Epoch 20/40
# 20/20 - 12s - loss: 0.1179 - AUC: 0.8536 - val_loss: 0.1522 - val_AUC: 0.8929 - 12s/epoch - 592ms/step
# Epoch 21/40
# 20/20 - 11s - loss: 0.1223 - AUC: 0.8730 - val_loss: 0.0832 - val_AUC: 0.9048 - 11s/epoch - 557ms/step
# Epoch 22/40
# 20/20 - 12s - loss: 0.1340 - AUC: 0.8370 - val_loss: 0.1000 - val_AUC: 0.9210 - 12s/epoch - 586ms/step
# Epoch 23/40
# 20/20 - 10s - loss: 0.1267 - AUC: 0.8573 - val_loss: 0.1108 - val_AUC: 0.9286 - 10s/epoch - 508ms/step
# Epoch 24/40
# 20/20 - 12s - loss: 0.1231 - AUC: 0.8721 - val_loss: 0.1158 - val_AUC: 0.8907 - 12s/epoch - 591ms/step
# Epoch 25/40
# 20/20 - 10s - loss: 0.1151 - AUC: 0.8619 - val_loss: 0.1144 - val_AUC: 0.9037 - 10s/epoch - 516ms/step
# Epoch 26/40
# 20/20 - 12s - loss: 0.1116 - AUC: 0.8767 - val_loss: 0.1564 - val_AUC: 0.8939 - 12s/epoch - 578ms/step
# Epoch 27/40
# 20/20 - 10s - loss: 0.1143 - AUC: 0.8946 - val_loss: 0.1158 - val_AUC: 0.8994 - 10s/epoch - 503ms/step
# Epoch 28/40
# 20/20 - 12s - loss: 0.1147 - AUC: 0.8678 - val_loss: 0.1082 - val_AUC: 0.9297 - 12s/epoch - 582ms/step
# Epoch 29/40
# 20/20 - 12s - loss: 0.1035 - AUC: 0.8945 - val_loss: 0.1609 - val_AUC: 0.9437 - 12s/epoch - 586ms/step
# Epoch 30/40
# 20/20 - 10s - loss: 0.1033 - AUC: 0.9023 - val_loss: 0.1386 - val_AUC: 0.9329 - 10s/epoch - 482ms/step
# Epoch 31/40
# 20/20 - 11s - loss: 0.0974 - AUC: 0.9173 - val_loss: 0.1452 - val_AUC: 0.9156 - 11s/epoch - 575ms/step
# Epoch 32/40
# 20/20 - 11s - loss: 0.1041 - AUC: 0.9109 - val_loss: 0.0907 - val_AUC: 0.9491 - 11s/epoch - 574ms/step
# Epoch 33/40
# 20/20 - 9s - loss: 0.1001 - AUC: 0.9103 - val_loss: 0.1016 - val_AUC: 0.9578 - 9s/epoch - 469ms/step
# Epoch 34/40
# 20/20 - 11s - loss: 0.1073 - AUC: 0.9060 - val_loss: 0.1597 - val_AUC: 0.9297 - 11s/epoch - 564ms/step
# Epoch 35/40
# 20/20 - 12s - loss: 0.0970 - AUC: 0.9143 - val_loss: 0.1860 - val_AUC: 0.9502 - 12s/epoch - 580ms/step
# Epoch 36/40
# 20/20 - 10s - loss: 0.0908 - AUC: 0.9385 - val_loss: 0.1837 - val_AUC: 0.9405 - 10s/epoch - 491ms/step
# Epoch 37/40
# 20/20 - 12s - loss: 0.0870 - AUC: 0.9418 - val_loss: 0.1107 - val_AUC: 0.9784 - 12s/epoch - 576ms/step
# Epoch 38/40
# 20/20 - 12s - loss: 0.0843 - AUC: 0.9396 - val_loss: 0.1020 - val_AUC: 0.9805 - 12s/epoch - 602ms/step
# Epoch 39/40
# 20/20 - 12s - loss: 0.0873 - AUC: 0.9467 - val_loss: 0.0858 - val_AUC: 0.9275 - 12s/epoch - 583ms/step
# Epoch 40/40
# 20/20 - 11s - loss: 0.0870 - AUC: 0.9416 - val_loss: 0.1298 - val_AUC: 0.9600 - 11s/epoch - 569ms/step
#
# 4=======urinary_disease=======
#
# Epoch 1/40
# 20/20 - 20s - loss: 0.4484 - AUC: 0.5871 - val_loss: 0.5109 - val_AUC: 0.6114 - 20s/epoch - 982ms/step
# Epoch 2/40
# 20/20 - 10s - loss: 0.4172 - AUC: 0.6667 - val_loss: 0.5490 - val_AUC: 0.6207 - 10s/epoch - 479ms/step
# Epoch 3/40
# 20/20 - 11s - loss: 0.4184 - AUC: 0.6489 - val_loss: 0.5719 - val_AUC: 0.6379 - 11s/epoch - 558ms/step
# Epoch 4/40
# 20/20 - 12s - loss: 0.4125 - AUC: 0.6267 - val_loss: 0.5633 - val_AUC: 0.6338 - 12s/epoch - 595ms/step
# Epoch 5/40
# 20/20 - 10s - loss: 0.4008 - AUC: 0.6418 - val_loss: 0.5430 - val_AUC: 0.6400 - 10s/epoch - 510ms/step
# Epoch 6/40
# 20/20 - 12s - loss: 0.3878 - AUC: 0.6666 - val_loss: 0.5396 - val_AUC: 0.6478 - 12s/epoch - 595ms/step
# Epoch 7/40
# 20/20 - 11s - loss: 0.3828 - AUC: 0.6861 - val_loss: 0.5438 - val_AUC: 0.6371 - 11s/epoch - 571ms/step
# Epoch 8/40
# 20/20 - 12s - loss: 0.3803 - AUC: 0.6891 - val_loss: 0.5228 - val_AUC: 0.6409 - 12s/epoch - 591ms/step
# Epoch 9/40
# 20/20 - 11s - loss: 0.3702 - AUC: 0.7240 - val_loss: 0.5381 - val_AUC: 0.6388 - 11s/epoch - 557ms/step
# Epoch 10/40
# 20/20 - 12s - loss: 0.3710 - AUC: 0.7074 - val_loss: 0.5294 - val_AUC: 0.6466 - 12s/epoch - 582ms/step
# Epoch 11/40
# 20/20 - 12s - loss: 0.3684 - AUC: 0.7405 - val_loss: 0.5158 - val_AUC: 0.6644 - 12s/epoch - 594ms/step
# Epoch 12/40
# 20/20 - 12s - loss: 0.3539 - AUC: 0.7549 - val_loss: 0.5179 - val_AUC: 0.6676 - 12s/epoch - 582ms/step
# Epoch 13/40
# 20/20 - 11s - loss: 0.3443 - AUC: 0.7692 - val_loss: 0.5111 - val_AUC: 0.6810 - 11s/epoch - 564ms/step
# Epoch 14/40
# 20/20 - 9s - loss: 0.3385 - AUC: 0.7794 - val_loss: 0.5222 - val_AUC: 0.6623 - 9s/epoch - 473ms/step
# Epoch 15/40
# 20/20 - 11s - loss: 0.3420 - AUC: 0.7795 - val_loss: 0.5308 - val_AUC: 0.6727 - 11s/epoch - 574ms/step
# Epoch 16/40
# 20/20 - 12s - loss: 0.3453 - AUC: 0.7693 - val_loss: 0.5205 - val_AUC: 0.6669 - 12s/epoch - 597ms/step
# Epoch 17/40
# 20/20 - 11s - loss: 0.3363 - AUC: 0.7810 - val_loss: 0.5019 - val_AUC: 0.6874 - 11s/epoch - 556ms/step
# Epoch 18/40
# 20/20 - 12s - loss: 0.3349 - AUC: 0.7869 - val_loss: 0.5287 - val_AUC: 0.6462 - 12s/epoch - 590ms/step
# Epoch 19/40
# 20/20 - 10s - loss: 0.3359 - AUC: 0.7845 - val_loss: 0.4977 - val_AUC: 0.6768 - 10s/epoch - 498ms/step
# Epoch 20/40
# 20/20 - 12s - loss: 0.3381 - AUC: 0.7786 - val_loss: 0.5341 - val_AUC: 0.7028 - 12s/epoch - 585ms/step
# Epoch 21/40
# 20/20 - 11s - loss: 0.3366 - AUC: 0.7783 - val_loss: 0.5173 - val_AUC: 0.6631 - 11s/epoch - 574ms/step
# Epoch 22/40
# 20/20 - 10s - loss: 0.3565 - AUC: 0.7747 - val_loss: 0.4910 - val_AUC: 0.6740 - 10s/epoch - 503ms/step
# Epoch 23/40
# 20/20 - 12s - loss: 0.3373 - AUC: 0.7858 - val_loss: 0.5474 - val_AUC: 0.6679 - 12s/epoch - 594ms/step
# Epoch 24/40
# 20/20 - 11s - loss: 0.3403 - AUC: 0.7695 - val_loss: 0.5088 - val_AUC: 0.7029 - 11s/epoch - 549ms/step
# Epoch 25/40
# 20/20 - 12s - loss: 0.3389 - AUC: 0.7954 - val_loss: 0.5081 - val_AUC: 0.6951 - 12s/epoch - 612ms/step
# Epoch 26/40
# 20/20 - 12s - loss: 0.3514 - AUC: 0.7768 - val_loss: 0.4841 - val_AUC: 0.7327 - 12s/epoch - 591ms/step
# Epoch 27/40
# 20/20 - 10s - loss: 0.3197 - AUC: 0.8064 - val_loss: 0.5045 - val_AUC: 0.6843 - 10s/epoch - 495ms/step
# Epoch 28/40
# 20/20 - 11s - loss: 0.3280 - AUC: 0.7880 - val_loss: 0.4595 - val_AUC: 0.7920 - 11s/epoch - 565ms/step
# Epoch 29/40
# 20/20 - 11s - loss: 0.3138 - AUC: 0.7978 - val_loss: 0.4566 - val_AUC: 0.7232 - 11s/epoch - 562ms/step
# Epoch 30/40
# 20/20 - 10s - loss: 0.2958 - AUC: 0.8359 - val_loss: 0.4905 - val_AUC: 0.7113 - 10s/epoch - 485ms/step
# Epoch 31/40
# 20/20 - 11s - loss: 0.2926 - AUC: 0.8336 - val_loss: 0.4738 - val_AUC: 0.7263 - 11s/epoch - 569ms/step
# Epoch 32/40
# 20/20 - 11s - loss: 0.2848 - AUC: 0.8465 - val_loss: 0.4677 - val_AUC: 0.7572 - 11s/epoch - 556ms/step
# Epoch 33/40
# 20/20 - 10s - loss: 0.2819 - AUC: 0.8487 - val_loss: 0.4611 - val_AUC: 0.7582 - 10s/epoch - 499ms/step
# Epoch 34/40
# 20/20 - 12s - loss: 0.2741 - AUC: 0.8589 - val_loss: 0.4576 - val_AUC: 0.7446 - 12s/epoch - 580ms/step
# Epoch 35/40
# 20/20 - 12s - loss: 0.2657 - AUC: 0.8673 - val_loss: 0.4322 - val_AUC: 0.7993 - 12s/epoch - 604ms/step
# Epoch 36/40
# 20/20 - 23s - loss: 0.2737 - AUC: 0.8633 - val_loss: 0.4761 - val_AUC: 0.7312 - 23s/epoch - 1s/step
# Epoch 37/40
# 20/20 - 11s - loss: 0.2705 - AUC: 0.8633 - val_loss: 0.5105 - val_AUC: 0.7276 - 11s/epoch - 558ms/step
# Epoch 38/40
# 20/20 - 10s - loss: 0.2618 - AUC: 0.8810 - val_loss: 0.4883 - val_AUC: 0.7540 - 10s/epoch - 500ms/step
# Epoch 39/40
# 20/20 - 12s - loss: 0.2602 - AUC: 0.8825 - val_loss: 0.5097 - val_AUC: 0.7161 - 12s/epoch - 585ms/step
# Epoch 40/40
# 20/20 - 10s - loss: 0.2590 - AUC: 0.8831 - val_loss: 0.4533 - val_AUC: 0.7721 - 10s/epoch - 481ms/step

# %%
disease_pipeline.predict([data.iloc[133].Smiles]), data.iloc[133].Disease
# Out:
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 104ms/step
# ({'mental_disease': array([[0.86554986]], dtype=float32),
#   'cardiovascular_disease': array([[0.3225131]], dtype=float32),
#   'digestive_disease': array([[0.00685264]], dtype=float32),
#   'immune_disease': array([[0.471586]], dtype=float32),
#   'urinary_disease': array([[0.04342876]], dtype=float32)},
#  'mental_disease')

# %%
for model in disease_pipeline.models:
  with open(f'./drive/MyDrive/Models/{model}', 'wb') as f:
    pickle.dump(disease_pipeline.models[model], f)
