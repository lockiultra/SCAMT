# %% [markdown]
# <a href="https://colab.research.google.com/github/lockiultra/SCAMT/blob/main/MPNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install rdkit-pypi
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 54.7 MB/s eta 0:00:00

# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import re
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.Draw import MolsToGridImage

warnings.filterwarnings("ignore")
RDLogger.DisableLog("rdApp.*")

np.random.seed(42)
tf.random.set_seed(42)

# Featurizers

class Featurizer:
    def __init__(self, allowable_sets):
        self.dim = 0
        self.feature_mapping = {}
        for k, s in allowable_sets.items():
            s = sorted(list(s))
            self.feature_mapping[k] = dict(zip(s, range(self.dim, self.dim + len(s))))
            self.dim += len(s)

    def encode(self, inputs):
        output = np.zeros((self.dim,))
        for name_feature, feature_mapping in self.feature_mapping.items():
            feature = getattr(self, name_feature)(inputs)
            if feature not in feature_mapping:
                continue
            output[feature_mapping[feature]] = 1.0
        return output


class AtomFeaturizer(Featurizer):
    def __init__(self, allowable_sets):
        super().__init__(allowable_sets)

    def symbol(self, atom):
        return atom.GetSymbol()

    def n_valence(self, atom):
        return atom.GetTotalValence()

    def n_hydrogens(self, atom):
        return atom.GetTotalNumHs()

    def hybridization(self, atom):
        return atom.GetHybridization().name.lower()


class BondFeaturizer(Featurizer):
    def __init__(self, allowable_sets):
        super().__init__(allowable_sets)

    def encode(self, bond):
        output = np.zeros((self.dim,))
        if bond is None:
            output[-1] = 1.0
            return output
        output = super().encode(bond)
        return output

    def bond_type(self, bond):
        return bond.GetBondType().name.lower()

    def conjugated(self, bond):
        return bond.GetIsConjugated()
# Model

class EdgeNetwork(layers.Layer):
    def build(self, input_shape):
        self.atom_dim = input_shape[0][-1]
        self.bond_dim = input_shape[1][-1]
        self.kernel  = self.add_weight(
            shape=(self.bond_dim, self.atom_dim * self.atom_dim),
            initializer="glorot_uniform",
            name="kernel",
        )
        self.bias = self.add_weight(
            shape=(self.atom_dim * self.atom_dim),
            initializer="zeros",
            name="bias",
        )
        self.built = True

    def call(self, inputs):
        atom_features, bond_features, pair_indices = inputs
        bond_features = tf.matmul(bond_features, self.kernel) + self.bias
        bond_features = tf.reshape(bond_features, (-1, self.atom_dim, self.atom_dim))
        atom_features_neighbors = tf.gather(atom_features, pair_indices[:, 1])
        atom_features_neighbors = tf.expand_dims(atom_features_neighbors, axis=-1)
        transformed_features = tf.matmul(bond_features, atom_features_neighbors)
        transformed_features = tf.squeeze(transformed_features, axis=-1)
        aggregated_features = tf.math.unsorted_segment_sum(
            transformed_features,
            pair_indices[:, 0],
            num_segments=tf.shape(atom_features)[0]
        )
        return aggregated_features

class MessagePassing(layers.Layer):
    def __init__(self, units, steps=4, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.steps = steps

    def build(self, input_shape):
        self.atom_dim = input_shape[0][-1]
        self.message_step = EdgeNetwork()
        self.pad_length = max(0, self.units - self.atom_dim)
        self.update_step = layers.GRUCell(self.atom_dim + self.pad_length)
        self.built = True

    def call(self, inputs):
        atom_features, bond_features, pair_indices = inputs
        atom_features_updated = tf.pad(atom_features, [[0, 0], [self.pad_length, 0]])
        for i in range(self.steps):
            atom_features_aggregated = self.message_step([atom_features_updated, bond_features, pair_indices])
            atom_features_updated, _ = self.update_step(atom_features_aggregated, atom_features_updated)
        return atom_features_updated

class PartitionPadding(layers.Layer):
    def __init__(self, batch_size, **kwargs):
        super().__init__(**kwargs)
        self.batch_size = batch_size

    def call(self, inputs):
        atom_features, molecule_indicator = inputs
        atom_features_partitioned = tf.dynamic_partition(atom_features, molecule_indicator, self.batch_size)
        num_atoms = [tf.shape(x)[0] for x in atom_features_partitioned]
        max_num_atoms = tf.reduce_max(num_atoms)
        atom_features_stacked = tf.stack(
            [
                tf.pad(f, [(0, max_num_atoms - n), (0, 0)]) for f, n in zip(atom_features_partitioned, num_atoms)
            ],
            axis=0
        )
        gather_indices = tf.where(tf.reduce_sum(atom_features_stacked, (1, 2)) != 0)
        gather_indices = tf.squeeze(gather_indices, axis=-1)
        return tf.gather(atom_features_stacked, gather_indices, axis=0)

class TransformerEncoderReadout(layers.Layer):
    def __init__(self, num_heads=8, embed_dim=64, dense_dim=512, batch_size=32, **kwargs):
        super().__init__(**kwargs)
        self.partition_padding = PartitionPadding(batch_size)
        self.attention = layers.MultiHeadAttention(num_heads, embed_dim)
        self.dense_proj = keras.Sequential(
            [
                layers.Dense(dense_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.average_pooling = layers.GlobalAveragePooling1D()

    def call(self, inputs):
        x = self.partition_padding(inputs)
        padding_mask = tf.reduce_any(tf.not_equal(x, 0.0), axis=-1)
        padding_mask = padding_mask[:, tf.newaxis, tf.newaxis, :]
        attention_output = self.attention(x, x, attention_mask=padding_mask)
        proj_input = self.layernorm_1(x + attention_output)
        proj_output = self.layernorm_2(proj_input + self.dense_proj(proj_input))
        return self.average_pooling(proj_output)

def MPNNModel(atom_dim, bond_dim, batch_size=128, message_units=64, message_steps=4, num_attention_heads=8, dense_units=512):
    atom_features = layers.Input((atom_dim,), dtype=tf.float32, name="atom_features")
    bond_features = layers.Input((bond_dim,), dtype=tf.float32, name="bond_features")
    pair_indices = layers.Input((2,), dtype=tf.int32, name="pair_indices")
    molecule_indicator = layers.Input((), dtype=tf.int32, name="molecule_indicator")
    x = MessagePassing(message_units, message_steps)([atom_features, bond_features, pair_indices])
    x = TransformerEncoderReadout(num_attention_heads, message_units, dense_units, batch_size)([x, molecule_indicator])
    x = layers.Dense(dense_units, activation='elu')(x)
    x = layers.Dense(1, activation="sigmoid")(x)
    model = keras.Model(inputs=[atom_features, bond_features, pair_indices, molecule_indicator], outputs=[x])
    return model

# %%
class DiseasePipeline:
  def __init__(self, data: pd.DataFrame):
    self.diseases = data.Disease.unique()
    self.atom_featurizer = AtomFeaturizer(
      allowable_sets={
        "symbol": {'B', 'Br', 'C', 'Ca', 'Cl', 'F', 'H', 'I', 'N', 'Na', 'O', 'P', 'S'},
        "n_valence": {0, 1, 2, 3, 4, 5, 6},
        "n_hydrogens": {0, 1, 2, 3, 4},
        "hybridization": {'s', 'sp', 'sp2', 'sp3'},
      }
    )
    self.bond_featurizer = BondFeaturizer(
      allowable_sets={
        "bond_type": {'single', 'double', 'triple', 'aromatic'},
        "conjugated": {False, True},
      }
    )
    self.data = data.copy()
    self.curr_df = None
    self.x_train, self.y_train, self.x_val, self.y_val = self.__get_train_val_data(data)
    self.models = {disease: MPNNModel(atom_dim=self.x_train[0][0][0].shape[0], bond_dim=self.x_train[1][0][0].shape[0]) for disease in self.diseases}
    self.is_trained = False
    self.train_history = dict()

  def train(self):
    for i, disease in enumerate(self.diseases):
      print(f'\n({i}) ======={disease}=======\n')
      self.curr_df = self.data.copy()
      self.curr_df['Disease'] = self.curr_df['Disease'].replace({x: 1 if x == disease else 0 for x in self.diseases})
      self.curr_df = self.curr_df.drop_duplicates(subset=['Drug'])
      x_train, y_train, x_val, y_val = self.__get_train_val_data(self.curr_df)
      train_dataset = self.__get_dataset(x_train, y_train, disease)
      val_dataset = self.__get_dataset(x_val, y_val, disease)
      self.models[disease].compile(
        loss=keras.losses.BinaryCrossentropy(),
        optimizer=keras.optimizers.AdamW(learning_rate=3e-4),
        metrics=[keras.metrics.AUC(name='AUC')],
      )
      history = self.models[disease].fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=40,
        verbose=2,
      )
      self.train_history[disease] = history
    self.is_trained = True

  def predict(self, smiles):
    if not self.is_trained:
      print('Error! Model is not trained')
      return
    result = {disease: None for disease in self.diseases}
    g = self.graph_from_smiles(smiles)
    dataset = tf.data.Dataset.from_tensors(((g), (1))).map(self.prepare_batch, -1).prefetch(-1)
    for disease, model in zip(self.models.keys(), self.models.values()):
      result[disease] = model.predict(dataset)
    return result


  def __get_train_val_data(self, data):
    data = data.dropna()
    permutation = np.random.permutation(np.arange(data.shape[0]))
    train_index = permutation#[:int(data.shape[0] * 0.8)]
    x_train = self.graph_from_smiles(data.iloc[train_index].Smiles)
    y_train = data.iloc[train_index].Disease
    val_index = permutation[int(data.shape[0] * 0.8):]
    x_val = self.graph_from_smiles(data.iloc[val_index].Smiles)
    y_val = data.iloc[val_index].Disease
    return (x_train, y_train, x_val, y_val)

  def __get_dataset(self, X, y, curr_disease, batch_size=128, shuffle=False):
    # replace_disease_dict = {
    #   x: 1 if x == curr_disease else 0 for x in self.diseases
    # }
    # y = y.replace(replace_disease_dict)
    dataset = tf.data.Dataset.from_tensor_slices((X, (y)))
    if shuffle:
      dataset = dataset.shuffle(1024)
    return dataset.batch(batch_size).map(self.prepare_batch, -1).prefetch(-1)

  def prepare_batch(self, x_batch, y_batch):
    atom_features, bond_features, pair_indices = x_batch
    num_atoms = atom_features.row_lengths()
    num_bonds = bond_features.row_lengths()
    molecule_indices = tf.range(len(num_atoms))
    molecule_indicator = tf.repeat(molecule_indices, num_atoms)
    gather_indices = tf.repeat(molecule_indices[:-1], num_bonds[1:])
    increment = tf.cumsum(num_atoms[:-1])
    increment = tf.pad(tf.gather(increment, gather_indices), [(num_bonds[0], 0)])
    pair_indices = pair_indices.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    pair_indices = pair_indices + increment[:, tf.newaxis]
    atom_features = atom_features.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    bond_features = bond_features.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    return (atom_features, bond_features, pair_indices, molecule_indicator), y_batch

  def molecule_from_smiles(self, smiles):
    molecule = Chem.MolFromSmiles(smiles, sanitize=False)
    flag = Chem.SanitizeMol(molecule, catchErrors=True)
    if flag != Chem.SanitizeFlags.SANITIZE_NONE:
        Chem.SanitizeMol(molecule, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ flag)
    Chem.AssignStereochemistry(molecule, cleanIt=True, force=True)
    return molecule

  def graph_from_molecule(self, molecule):
      atom_features = []
      bond_features = []
      pair_indices = []
      for atom in molecule.GetAtoms():
          atom_features.append(self.atom_featurizer.encode(atom))
          pair_indices.append((atom.GetIdx(), atom.GetIdx()))
          bond_features.append(self.bond_featurizer.encode(None))
          for neighbor in atom.GetNeighbors():
              bond = molecule.GetBondBetweenAtoms(atom.GetIdx(), neighbor.GetIdx())
              pair_indices.append((atom.GetIdx(), neighbor.GetIdx()))
              bond_features.append(self.bond_featurizer.encode(bond))
      return np.array(atom_features), np.array(bond_features), np.array(pair_indices)

  def graph_from_smiles(self, smiles_list):
      atom_features_list = []
      bond_features_list = []
      pair_indices_list = []
      for smiles in smiles_list:
          molecule = self.molecule_from_smiles(smiles)
          atom_features, bond_features, pair_indices = self.graph_from_molecule(molecule)
          atom_features_list.append(atom_features)
          bond_features_list.append(bond_features)
          pair_indices_list.append(pair_indices)
      return (
          tf.ragged.constant(atom_features_list, dtype=tf.float32),
          tf.ragged.constant(bond_features_list, dtype=tf.float32),
          tf.ragged.constant(pair_indices_list, dtype=tf.int64),
      )

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                                              Conditions          Drug  \
# 0                                        HIV Infections   Enfuvirtide
# 4                             Status Asthmaticus|Asthma   Montelukast
# 5                             Status Asthmaticus|Asthma   Chloroquine
# 6                             Status Asthmaticus|Asthma   Ciclosporin
# 7     Recurrent Mantle Cell Lymphoma|Refractory Mant...    Copanlisib
# ...                                                 ...           ...
# 6563      Type 2 Diabetes Mellitus, CKD and Albuminuria   Saxagliptin
# 6564  Diabetic Kidney Disease|Diabetic Nephropathy|D...  Lixisenatide
# 6565                           Healthy|Renal Impairment     Cenerimod
# 6567  Advanced or Metastatic Hepatocellular Cancer|A...   Tasquinimod
# 6568      Renal Impairment|Renal Disease|Kidney Disease  Nitazoxanide
#
#                                                  Smiles         Phases  \
# 0     CCC(C)C(C(=O)NC(CCC(=O)O)C(=O)NC(CCC(=O)O)C(=O...       APPROVED
# 4     CC(C)(C1=CC=CC=C1CCC(C2=CC=CC(=C2)C=CC3=NC4=C(...  PHASE2|PHASE3
# 5                CCN(CC)CCCC(C)NC1=C2C=CC(=CC2=NC=C1)Cl  PHASE2|PHASE3
# 6     CCC1C(=O)N(CC(=O)N(C(C(=O)NC(C(=O)N(C(C(=O)NC(...  PHASE2|PHASE3
# 7     COC1=C(C=CC2=C3NCCN3C(=NC(=O)C4=CN=C(N=C4)N)N=...  PHASE1|PHASE2
# ...                                                 ...            ...
# 6563    C1C2CC2N(C1C#N)C(=O)C(C34CC5CC(C3)CC(C5)(C4)O)N  PHASE2|PHASE3
# 6564  CCC(C)C(C(=O)NC(CCC(=O)O)C(=O)NC(CC1=CNC2=CC=C...       APPROVED
# 6565  CCC1=C(C(=CC(=C1)C2=NOC(=N2)C3=CC(=NC(=C3)OC)C...         PHASE1
# 6567  CN1C2=C(C(=CC=C2)OC)C(=C(C1=O)C(=O)N(C)C3=CC=C...         PHASE2
# 6568    CC(=O)OC1=CC=CC=C1C(=O)NC2=NC=C(S2)[N+](=O)[O-]         PHASE1
#
#                      Disease
# 0      immune_system_disease
# 4      immune_system_disease
# 5      immune_system_disease
# 6      immune_system_disease
# 7      immune_system_disease
# ...                      ...
# 6563  urinary_system_disease
# 6564  urinary_system_disease
# 6565  urinary_system_disease
# 6567  urinary_system_disease
# 6568  urinary_system_disease
#
# [5633 rows x 5 columns]

# %%
disease_pipeline = DiseasePipeline(df)

# %%
disease_pipeline.train()
# Out:
# (0) =======immune_system_disease=======
#
# Epoch 1/40
# 17/17 - 17s - loss: 0.7291 - AUC: 0.5047 - val_loss: 0.6859 - val_AUC: 0.5715 - 17s/epoch - 986ms/step
# Epoch 2/40
# 17/17 - 3s - loss: 0.6962 - AUC: 0.5077 - val_loss: 0.6874 - val_AUC: 0.5068 - 3s/epoch - 205ms/step
# Epoch 3/40
# 17/17 - 3s - loss: 0.6939 - AUC: 0.5138 - val_loss: 0.6859 - val_AUC: 0.5425 - 3s/epoch - 190ms/step
# Epoch 4/40
# 17/17 - 3s - loss: 0.6932 - AUC: 0.5152 - val_loss: 0.6855 - val_AUC: 0.5393 - 3s/epoch - 201ms/step
# Epoch 5/40
# 17/17 - 3s - loss: 0.6924 - AUC: 0.5188 - val_loss: 0.6837 - val_AUC: 0.6036 - 3s/epoch - 191ms/step
# Epoch 6/40
# 17/17 - 3s - loss: 0.6921 - AUC: 0.5236 - val_loss: 0.6823 - val_AUC: 0.5628 - 3s/epoch - 190ms/step
# Epoch 7/40
# 17/17 - 3s - loss: 0.6893 - AUC: 0.5304 - val_loss: 0.6835 - val_AUC: 0.5448 - 3s/epoch - 191ms/step
# Epoch 8/40
# 17/17 - 4s - loss: 0.6898 - AUC: 0.5301 - val_loss: 0.6796 - val_AUC: 0.5687 - 4s/epoch - 210ms/step
# Epoch 9/40
# 17/17 - 3s - loss: 0.6861 - AUC: 0.5477 - val_loss: 0.6762 - val_AUC: 0.6297 - 3s/epoch - 192ms/step
# Epoch 10/40
# 17/17 - 3s - loss: 0.6860 - AUC: 0.5526 - val_loss: 0.6754 - val_AUC: 0.6172 - 3s/epoch - 187ms/step
# Epoch 11/40
# 17/17 - 3s - loss: 0.6846 - AUC: 0.5598 - val_loss: 0.6689 - val_AUC: 0.6467 - 3s/epoch - 192ms/step
# Epoch 12/40
# 17/17 - 3s - loss: 0.6854 - AUC: 0.5593 - val_loss: 0.6665 - val_AUC: 0.6431 - 3s/epoch - 202ms/step
# Epoch 13/40
# 17/17 - 3s - loss: 0.6844 - AUC: 0.5621 - val_loss: 0.6630 - val_AUC: 0.6496 - 3s/epoch - 194ms/step
# Epoch 14/40
# 17/17 - 3s - loss: 0.6838 - AUC: 0.5660 - val_loss: 0.6588 - val_AUC: 0.6457 - 3s/epoch - 188ms/step
# Epoch 15/40
# 17/17 - 3s - loss: 0.6857 - AUC: 0.5531 - val_loss: 0.6681 - val_AUC: 0.6381 - 3s/epoch - 202ms/step
# Epoch 16/40
# 17/17 - 3s - loss: 0.6826 - AUC: 0.5718 - val_loss: 0.6654 - val_AUC: 0.6497 - 3s/epoch - 185ms/step
# Epoch 17/40
# 17/17 - 3s - loss: 0.6808 - AUC: 0.5677 - val_loss: 0.6551 - val_AUC: 0.6559 - 3s/epoch - 197ms/step
# Epoch 18/40
# 17/17 - 3s - loss: 0.6814 - AUC: 0.5688 - val_loss: 0.6601 - val_AUC: 0.6437 - 3s/epoch - 205ms/step
# Epoch 19/40
# 17/17 - 3s - loss: 0.6821 - AUC: 0.5792 - val_loss: 0.6568 - val_AUC: 0.6538 - 3s/epoch - 187ms/step
# Epoch 20/40
# 17/17 - 3s - loss: 0.6796 - AUC: 0.5701 - val_loss: 0.6539 - val_AUC: 0.6567 - 3s/epoch - 185ms/step
# Epoch 21/40
# 17/17 - 3s - loss: 0.6845 - AUC: 0.5696 - val_loss: 0.6610 - val_AUC: 0.6575 - 3s/epoch - 193ms/step
# Epoch 22/40
# 17/17 - 3s - loss: 0.6755 - AUC: 0.5864 - val_loss: 0.6507 - val_AUC: 0.6622 - 3s/epoch - 203ms/step
# Epoch 23/40
# 17/17 - 3s - loss: 0.6770 - AUC: 0.5915 - val_loss: 0.6515 - val_AUC: 0.6580 - 3s/epoch - 192ms/step
# Epoch 24/40
# 17/17 - 3s - loss: 0.6762 - AUC: 0.5887 - val_loss: 0.6479 - val_AUC: 0.6676 - 3s/epoch - 193ms/step
# Epoch 25/40
# 17/17 - 4s - loss: 0.6783 - AUC: 0.5756 - val_loss: 0.6492 - val_AUC: 0.6642 - 4s/epoch - 207ms/step
# Epoch 26/40
# 17/17 - 3s - loss: 0.6734 - AUC: 0.5916 - val_loss: 0.6435 - val_AUC: 0.6669 - 3s/epoch - 196ms/step
# Epoch 27/40
# 17/17 - 3s - loss: 0.6805 - AUC: 0.5725 - val_loss: 0.6489 - val_AUC: 0.6699 - 3s/epoch - 187ms/step
# Epoch 28/40
# 17/17 - 3s - loss: 0.6729 - AUC: 0.6008 - val_loss: 0.6473 - val_AUC: 0.6719 - 3s/epoch - 196ms/step
# Epoch 29/40
# 17/17 - 3s - loss: 0.6709 - AUC: 0.6008 - val_loss: 0.6385 - val_AUC: 0.6774 - 3s/epoch - 199ms/step
# Epoch 30/40
# 17/17 - 3s - loss: 0.6667 - AUC: 0.6111 - val_loss: 0.6352 - val_AUC: 0.6806 - 3s/epoch - 191ms/step
# Epoch 31/40
# 17/17 - 3s - loss: 0.6690 - AUC: 0.6044 - val_loss: 0.6362 - val_AUC: 0.6750 - 3s/epoch - 201ms/step
# Epoch 32/40
# 17/17 - 3s - loss: 0.6700 - AUC: 0.6050 - val_loss: 0.6316 - val_AUC: 0.6896 - 3s/epoch - 199ms/step
# Epoch 33/40
# 17/17 - 3s - loss: 0.6643 - AUC: 0.6158 - val_loss: 0.6436 - val_AUC: 0.6775 - 3s/epoch - 192ms/step
# Epoch 34/40
# 17/17 - 3s - loss: 0.6593 - AUC: 0.6290 - val_loss: 0.6321 - val_AUC: 0.6810 - 3s/epoch - 199ms/step
# Epoch 35/40
# 17/17 - 3s - loss: 0.6604 - AUC: 0.6274 - val_loss: 0.6304 - val_AUC: 0.6824 - 3s/epoch - 188ms/step
# Epoch 36/40
# 17/17 - 3s - loss: 0.6593 - AUC: 0.6294 - val_loss: 0.6284 - val_AUC: 0.6938 - 3s/epoch - 195ms/step
# Epoch 37/40
# 17/17 - 3s - loss: 0.6558 - AUC: 0.6374 - val_loss: 0.6265 - val_AUC: 0.6889 - 3s/epoch - 206ms/step
# Epoch 38/40
# 17/17 - 3s - loss: 0.6547 - AUC: 0.6380 - val_loss: 0.6287 - val_AUC: 0.6883 - 3s/epoch - 187ms/step
# Epoch 39/40
# 17/17 - 3s - loss: 0.6570 - AUC: 0.6353 - val_loss: 0.6270 - val_AUC: 0.6894 - 3s/epoch - 194ms/step
# Epoch 40/40
# 17/17 - 3s - loss: 0.6540 - AUC: 0.6418 - val_loss: 0.6307 - val_AUC: 0.6928 - 3s/epoch - 198ms/step
#
# (1) =======metabolic_disease=======
#
# Epoch 1/40
# 17/17 - 18s - loss: 0.4221 - AUC: 0.5328 - val_loss: 0.4054 - val_AUC: 0.5506 - 18s/epoch - 1s/step
# Epoch 2/40
# 17/17 - 3s - loss: 0.4093 - AUC: 0.4996 - val_loss: 0.4009 - val_AUC: 0.5573 - 3s/epoch - 195ms/step
# Epoch 3/40
# 17/17 - 3s - loss: 0.4071 - AUC: 0.5085 - val_loss: 0.3986 - val_AUC: 0.5870 - 3s/epoch - 199ms/step
# Epoch 4/40
# 17/17 - 4s - loss: 0.4058 - AUC: 0.5255 - val_loss: 0.3973 - val_AUC: 0.5894 - 4s/epoch - 206ms/step
# Epoch 5/40
# 17/17 - 3s - loss: 0.4048 - AUC: 0.5383 - val_loss: 0.3957 - val_AUC: 0.5952 - 3s/epoch - 196ms/step
# Epoch 6/40
# 17/17 - 3s - loss: 0.4034 - AUC: 0.5521 - val_loss: 0.3917 - val_AUC: 0.6015 - 3s/epoch - 201ms/step
# Epoch 7/40
# 17/17 - 4s - loss: 0.4013 - AUC: 0.5640 - val_loss: 0.3874 - val_AUC: 0.6130 - 4s/epoch - 207ms/step
# Epoch 8/40
# 17/17 - 3s - loss: 0.3979 - AUC: 0.5863 - val_loss: 0.3848 - val_AUC: 0.6336 - 3s/epoch - 196ms/step
# Epoch 9/40
# 17/17 - 3s - loss: 0.3939 - AUC: 0.6107 - val_loss: 0.3797 - val_AUC: 0.6520 - 3s/epoch - 194ms/step
# Epoch 10/40
# 17/17 - 3s - loss: 0.3913 - AUC: 0.6293 - val_loss: 0.3753 - val_AUC: 0.6681 - 3s/epoch - 203ms/step
# Epoch 11/40
# 17/17 - 3s - loss: 0.3929 - AUC: 0.6206 - val_loss: 0.3760 - val_AUC: 0.6784 - 3s/epoch - 194ms/step
# Epoch 12/40
# 17/17 - 3s - loss: 0.3911 - AUC: 0.6314 - val_loss: 0.3754 - val_AUC: 0.6828 - 3s/epoch - 194ms/step
# Epoch 13/40
# 17/17 - 4s - loss: 0.3886 - AUC: 0.6416 - val_loss: 0.3703 - val_AUC: 0.6958 - 4s/epoch - 207ms/step
# Epoch 14/40
# 17/17 - 3s - loss: 0.3880 - AUC: 0.6431 - val_loss: 0.3709 - val_AUC: 0.6975 - 3s/epoch - 194ms/step
# Epoch 15/40
# 17/17 - 4s - loss: 0.3871 - AUC: 0.6478 - val_loss: 0.3707 - val_AUC: 0.6977 - 4s/epoch - 208ms/step
# Epoch 16/40
# 17/17 - 3s - loss: 0.3878 - AUC: 0.6437 - val_loss: 0.3713 - val_AUC: 0.6956 - 3s/epoch - 204ms/step
# Epoch 17/40
# 17/17 - 3s - loss: 0.3909 - AUC: 0.6308 - val_loss: 0.3723 - val_AUC: 0.6992 - 3s/epoch - 196ms/step
# Epoch 18/40
# 17/17 - 3s - loss: 0.3867 - AUC: 0.6411 - val_loss: 0.3682 - val_AUC: 0.7130 - 3s/epoch - 196ms/step
# Epoch 19/40
# 17/17 - 3s - loss: 0.3809 - AUC: 0.6666 - val_loss: 0.3614 - val_AUC: 0.7228 - 3s/epoch - 202ms/step
# Epoch 20/40
# 17/17 - 3s - loss: 0.3814 - AUC: 0.6671 - val_loss: 0.3607 - val_AUC: 0.7222 - 3s/epoch - 199ms/step
# Epoch 21/40
# 17/17 - 3s - loss: 0.3785 - AUC: 0.6765 - val_loss: 0.3582 - val_AUC: 0.7238 - 3s/epoch - 197ms/step
# Epoch 22/40
# 17/17 - 3s - loss: 0.3777 - AUC: 0.6778 - val_loss: 0.3548 - val_AUC: 0.7346 - 3s/epoch - 204ms/step
# Epoch 23/40
# 17/17 - 3s - loss: 0.3772 - AUC: 0.6769 - val_loss: 0.3543 - val_AUC: 0.7391 - 3s/epoch - 194ms/step
# Epoch 24/40
# 17/17 - 3s - loss: 0.3760 - AUC: 0.6776 - val_loss: 0.3545 - val_AUC: 0.7427 - 3s/epoch - 197ms/step
# Epoch 25/40
# 17/17 - 4s - loss: 0.3750 - AUC: 0.6823 - val_loss: 0.3539 - val_AUC: 0.7376 - 4s/epoch - 211ms/step
# Epoch 26/40
# 17/17 - 3s - loss: 0.3721 - AUC: 0.6943 - val_loss: 0.3511 - val_AUC: 0.7484 - 3s/epoch - 201ms/step
# Epoch 27/40
# 17/17 - 3s - loss: 0.3744 - AUC: 0.6876 - val_loss: 0.3556 - val_AUC: 0.7451 - 3s/epoch - 196ms/step
# Epoch 28/40
# 17/17 - 3s - loss: 0.3752 - AUC: 0.6858 - val_loss: 0.3589 - val_AUC: 0.7353 - 3s/epoch - 199ms/step
# Epoch 29/40
# 17/17 - 4s - loss: 0.3773 - AUC: 0.6760 - val_loss: 0.3505 - val_AUC: 0.7286 - 4s/epoch - 213ms/step
# Epoch 30/40
# 17/17 - 3s - loss: 0.3787 - AUC: 0.6734 - val_loss: 0.3542 - val_AUC: 0.7275 - 3s/epoch - 202ms/step
# Epoch 31/40
# 17/17 - 3s - loss: 0.3783 - AUC: 0.6741 - val_loss: 0.3539 - val_AUC: 0.7237 - 3s/epoch - 195ms/step
# Epoch 32/40
# 17/17 - 4s - loss: 0.3755 - AUC: 0.6785 - val_loss: 0.3451 - val_AUC: 0.7462 - 4s/epoch - 207ms/step
# Epoch 33/40
# 17/17 - 3s - loss: 0.3717 - AUC: 0.6973 - val_loss: 0.3568 - val_AUC: 0.7328 - 3s/epoch - 200ms/step
# Epoch 34/40
# 17/17 - 3s - loss: 0.3711 - AUC: 0.6985 - val_loss: 0.3508 - val_AUC: 0.7459 - 3s/epoch - 198ms/step
# Epoch 35/40
# 17/17 - 3s - loss: 0.3704 - AUC: 0.7006 - val_loss: 0.3409 - val_AUC: 0.7526 - 3s/epoch - 206ms/step
# Epoch 36/40
# 17/17 - 3s - loss: 0.3676 - AUC: 0.7032 - val_loss: 0.3424 - val_AUC: 0.7448 - 3s/epoch - 198ms/step
# Epoch 37/40
# 17/17 - 3s - loss: 0.3671 - AUC: 0.7054 - val_loss: 0.3437 - val_AUC: 0.7516 - 3s/epoch - 195ms/step
# Epoch 38/40
# 17/17 - 3s - loss: 0.3632 - AUC: 0.7174 - val_loss: 0.3421 - val_AUC: 0.7632 - 3s/epoch - 205ms/step
# Epoch 39/40
# 17/17 - 4s - loss: 0.3602 - AUC: 0.7172 - val_loss: 0.3313 - val_AUC: 0.7728 - 4s/epoch - 206ms/step
# Epoch 40/40
# 17/17 - 3s - loss: 0.3600 - AUC: 0.7218 - val_loss: 0.3337 - val_AUC: 0.7623 - 3s/epoch - 195ms/step
#
# (2) =======digestive_system_disease=======
#
# Epoch 1/40
# 17/17 - 18s - loss: 0.4923 - AUC: 0.5253 - val_loss: 0.4208 - val_AUC: 0.5904 - 18s/epoch - 1s/step
# Epoch 2/40
# 17/17 - 4s - loss: 0.4647 - AUC: 0.5736 - val_loss: 0.4215 - val_AUC: 0.6019 - 4s/epoch - 208ms/step
# Epoch 3/40
# 17/17 - 3s - loss: 0.4678 - AUC: 0.5546 - val_loss: 0.4214 - val_AUC: 0.6043 - 3s/epoch - 203ms/step
# Epoch 4/40
# 17/17 - 3s - loss: 0.4703 - AUC: 0.5490 - val_loss: 0.4202 - val_AUC: 0.6093 - 3s/epoch - 199ms/step
# Epoch 5/40
# 17/17 - 4s - loss: 0.4731 - AUC: 0.5402 - val_loss: 0.4161 - val_AUC: 0.6141 - 4s/epoch - 212ms/step
# Epoch 6/40
# 17/17 - 3s - loss: 0.4733 - AUC: 0.5334 - val_loss: 0.4139 - val_AUC: 0.6130 - 3s/epoch - 206ms/step
# Epoch 7/40
# 17/17 - 3s - loss: 0.4702 - AUC: 0.5260 - val_loss: 0.4164 - val_AUC: 0.6190 - 3s/epoch - 203ms/step
# Epoch 8/40
# 17/17 - 3s - loss: 0.4668 - AUC: 0.5332 - val_loss: 0.4128 - val_AUC: 0.6252 - 3s/epoch - 205ms/step
# Epoch 9/40
# 17/17 - 3s - loss: 0.4651 - AUC: 0.5444 - val_loss: 0.4083 - val_AUC: 0.6295 - 3s/epoch - 199ms/step
# Epoch 10/40
# 17/17 - 3s - loss: 0.4655 - AUC: 0.5499 - val_loss: 0.4064 - val_AUC: 0.6482 - 3s/epoch - 195ms/step
# Epoch 11/40
# 17/17 - 3s - loss: 0.4653 - AUC: 0.5581 - val_loss: 0.4051 - val_AUC: 0.6446 - 3s/epoch - 203ms/step
# Epoch 12/40
# 17/17 - 4s - loss: 0.4626 - AUC: 0.5775 - val_loss: 0.4061 - val_AUC: 0.6232 - 4s/epoch - 207ms/step
# Epoch 13/40
# 17/17 - 4s - loss: 0.4621 - AUC: 0.5728 - val_loss: 0.4030 - val_AUC: 0.6515 - 4s/epoch - 207ms/step
# Epoch 14/40
# 17/17 - 4s - loss: 0.4702 - AUC: 0.5543 - val_loss: 0.4050 - val_AUC: 0.6467 - 4s/epoch - 212ms/step
# Epoch 15/40
# 17/17 - 3s - loss: 0.4662 - AUC: 0.5638 - val_loss: 0.4061 - val_AUC: 0.6309 - 3s/epoch - 195ms/step
# Epoch 16/40
# 17/17 - 3s - loss: 0.4672 - AUC: 0.5508 - val_loss: 0.4087 - val_AUC: 0.6445 - 3s/epoch - 197ms/step
# Epoch 17/40
# 17/17 - 3s - loss: 0.4607 - AUC: 0.5836 - val_loss: 0.4013 - val_AUC: 0.6366 - 3s/epoch - 205ms/step
# Epoch 18/40
# 17/17 - 3s - loss: 0.4594 - AUC: 0.5915 - val_loss: 0.4028 - val_AUC: 0.6547 - 3s/epoch - 195ms/step
# Epoch 19/40
# 17/17 - 3s - loss: 0.4674 - AUC: 0.5713 - val_loss: 0.4049 - val_AUC: 0.6421 - 3s/epoch - 199ms/step
# Epoch 20/40
# 17/17 - 4s - loss: 0.4644 - AUC: 0.5644 - val_loss: 0.4124 - val_AUC: 0.6564 - 4s/epoch - 214ms/step
# Epoch 21/40
# 17/17 - 3s - loss: 0.4628 - AUC: 0.5800 - val_loss: 0.4055 - val_AUC: 0.6489 - 3s/epoch - 203ms/step
# Epoch 22/40
# 17/17 - 3s - loss: 0.4616 - AUC: 0.5853 - val_loss: 0.4038 - val_AUC: 0.6545 - 3s/epoch - 196ms/step
# Epoch 23/40
# 17/17 - 4s - loss: 0.4625 - AUC: 0.5842 - val_loss: 0.4038 - val_AUC: 0.6556 - 4s/epoch - 212ms/step
# Epoch 24/40
# 17/17 - 3s - loss: 0.4581 - AUC: 0.5963 - val_loss: 0.4056 - val_AUC: 0.6549 - 3s/epoch - 204ms/step
# Epoch 25/40
# 17/17 - 3s - loss: 0.4558 - AUC: 0.6050 - val_loss: 0.4077 - val_AUC: 0.6658 - 3s/epoch - 205ms/step
# Epoch 26/40
# 17/17 - 4s - loss: 0.4580 - AUC: 0.6032 - val_loss: 0.4093 - val_AUC: 0.6644 - 4s/epoch - 216ms/step
# Epoch 27/40
# 17/17 - 3s - loss: 0.4531 - AUC: 0.6107 - val_loss: 0.4072 - val_AUC: 0.6694 - 3s/epoch - 198ms/step
# Epoch 28/40
# 17/17 - 3s - loss: 0.4528 - AUC: 0.6161 - val_loss: 0.4063 - val_AUC: 0.6675 - 3s/epoch - 204ms/step
# Epoch 29/40
# 17/17 - 3s - loss: 0.4506 - AUC: 0.6185 - val_loss: 0.4054 - val_AUC: 0.6731 - 3s/epoch - 194ms/step
# Epoch 30/40
# 17/17 - 4s - loss: 0.4476 - AUC: 0.6328 - val_loss: 0.4028 - val_AUC: 0.6722 - 4s/epoch - 209ms/step
# Epoch 31/40
# 17/17 - 3s - loss: 0.4473 - AUC: 0.6355 - val_loss: 0.4015 - val_AUC: 0.6732 - 3s/epoch - 204ms/step
# Epoch 32/40
# 17/17 - 3s - loss: 0.4502 - AUC: 0.6312 - val_loss: 0.3995 - val_AUC: 0.6706 - 3s/epoch - 201ms/step
# Epoch 33/40
# 17/17 - 4s - loss: 0.4577 - AUC: 0.6032 - val_loss: 0.4073 - val_AUC: 0.6818 - 4s/epoch - 216ms/step
# Epoch 34/40
# 17/17 - 3s - loss: 0.4459 - AUC: 0.6347 - val_loss: 0.4020 - val_AUC: 0.6797 - 3s/epoch - 206ms/step
# Epoch 35/40
# 17/17 - 3s - loss: 0.4454 - AUC: 0.6365 - val_loss: 0.3978 - val_AUC: 0.6873 - 3s/epoch - 197ms/step
# Epoch 36/40
# 17/17 - 4s - loss: 0.4461 - AUC: 0.6368 - val_loss: 0.3952 - val_AUC: 0.6894 - 4s/epoch - 211ms/step
# Epoch 37/40
# 17/17 - 3s - loss: 0.4519 - AUC: 0.6197 - val_loss: 0.4073 - val_AUC: 0.6787 - 3s/epoch - 204ms/step
# Epoch 38/40
# 17/17 - 3s - loss: 0.4440 - AUC: 0.6477 - val_loss: 0.3993 - val_AUC: 0.6976 - 3s/epoch - 197ms/step
# Epoch 39/40
# 17/17 - 4s - loss: 0.4470 - AUC: 0.6365 - val_loss: 0.3970 - val_AUC: 0.6848 - 4s/epoch - 213ms/step
# Epoch 40/40
# 17/17 - 3s - loss: 0.4483 - AUC: 0.6301 - val_loss: 0.4016 - val_AUC: 0.6891 - 3s/epoch - 205ms/step
#
# (3) =======cardiovascular_disease=======
#
# Epoch 1/40
# 17/17 - 17s - loss: 0.3707 - AUC: 0.5119 - val_loss: 0.3355 - val_AUC: 0.5564 - 17s/epoch - 1s/step
# Epoch 2/40
# 17/17 - 4s - loss: 0.3136 - AUC: 0.4987 - val_loss: 0.3327 - val_AUC: 0.5179 - 4s/epoch - 221ms/step
# Epoch 3/40
# 17/17 - 4s - loss: 0.3162 - AUC: 0.4583 - val_loss: 0.3296 - val_AUC: 0.4927 - 4s/epoch - 211ms/step
# Epoch 4/40
# 17/17 - 3s - loss: 0.3098 - AUC: 0.4575 - val_loss: 0.3305 - val_AUC: 0.4555 - 3s/epoch - 199ms/step
# Epoch 5/40
# 17/17 - 4s - loss: 0.3089 - AUC: 0.4636 - val_loss: 0.3309 - val_AUC: 0.4865 - 4s/epoch - 219ms/step
# Epoch 6/40
# 17/17 - 3s - loss: 0.3105 - AUC: 0.4629 - val_loss: 0.3315 - val_AUC: 0.5141 - 3s/epoch - 200ms/step
# Epoch 7/40
# 17/17 - 3s - loss: 0.3113 - AUC: 0.4657 - val_loss: 0.3321 - val_AUC: 0.5299 - 3s/epoch - 198ms/step
# Epoch 8/40
# 17/17 - 4s - loss: 0.3112 - AUC: 0.4649 - val_loss: 0.3322 - val_AUC: 0.5599 - 4s/epoch - 225ms/step
# Epoch 9/40
# 17/17 - 3s - loss: 0.3113 - AUC: 0.4658 - val_loss: 0.3324 - val_AUC: 0.5739 - 3s/epoch - 203ms/step
# Epoch 10/40
# 17/17 - 4s - loss: 0.3113 - AUC: 0.4706 - val_loss: 0.3324 - val_AUC: 0.6051 - 4s/epoch - 217ms/step
# Epoch 11/40
# 17/17 - 4s - loss: 0.3111 - AUC: 0.4747 - val_loss: 0.3321 - val_AUC: 0.5924 - 4s/epoch - 216ms/step
# Epoch 12/40
# 17/17 - 4s - loss: 0.3111 - AUC: 0.4767 - val_loss: 0.3321 - val_AUC: 0.6159 - 4s/epoch - 226ms/step
# Epoch 13/40
# 17/17 - 4s - loss: 0.3109 - AUC: 0.4838 - val_loss: 0.3313 - val_AUC: 0.6113 - 4s/epoch - 215ms/step
# Epoch 14/40
# 17/17 - 3s - loss: 0.3109 - AUC: 0.4860 - val_loss: 0.3325 - val_AUC: 0.6330 - 3s/epoch - 203ms/step
# Epoch 15/40
# 17/17 - 4s - loss: 0.3107 - AUC: 0.4984 - val_loss: 0.3278 - val_AUC: 0.6305 - 4s/epoch - 223ms/step
# Epoch 16/40
# 17/17 - 3s - loss: 0.3113 - AUC: 0.4948 - val_loss: 0.3355 - val_AUC: 0.5381 - 3s/epoch - 199ms/step
# Epoch 17/40
# 17/17 - 4s - loss: 0.3096 - AUC: 0.5202 - val_loss: 0.3347 - val_AUC: 0.6795 - 4s/epoch - 215ms/step
# Epoch 18/40
# 17/17 - 4s - loss: 0.3154 - AUC: 0.4889 - val_loss: 0.3296 - val_AUC: 0.6513 - 4s/epoch - 229ms/step
# Epoch 19/40
# 17/17 - 3s - loss: 0.3118 - AUC: 0.4916 - val_loss: 0.3279 - val_AUC: 0.6489 - 3s/epoch - 201ms/step
# Epoch 20/40
# 17/17 - 4s - loss: 0.3073 - AUC: 0.5155 - val_loss: 0.3260 - val_AUC: 0.6827 - 4s/epoch - 216ms/step
# Epoch 21/40
# 17/17 - 4s - loss: 0.3058 - AUC: 0.5536 - val_loss: 0.3255 - val_AUC: 0.6973 - 4s/epoch - 227ms/step
# Epoch 22/40
# 17/17 - 3s - loss: 0.3078 - AUC: 0.5509 - val_loss: 0.3286 - val_AUC: 0.6906 - 3s/epoch - 202ms/step
# Epoch 23/40
# 17/17 - 4s - loss: 0.3108 - AUC: 0.5285 - val_loss: 0.3243 - val_AUC: 0.7005 - 4s/epoch - 217ms/step
# Epoch 24/40
# 17/17 - 4s - loss: 0.3085 - AUC: 0.5331 - val_loss: 0.3171 - val_AUC: 0.7088 - 4s/epoch - 225ms/step
# Epoch 25/40
# 17/17 - 4s - loss: 0.3048 - AUC: 0.5623 - val_loss: 0.3195 - val_AUC: 0.7135 - 4s/epoch - 220ms/step
# Epoch 26/40
# 17/17 - 4s - loss: 0.3059 - AUC: 0.5586 - val_loss: 0.3143 - val_AUC: 0.7100 - 4s/epoch - 219ms/step
# Epoch 27/40
# 17/17 - 4s - loss: 0.3046 - AUC: 0.5771 - val_loss: 0.3229 - val_AUC: 0.6936 - 4s/epoch - 219ms/step
# Epoch 28/40
# 17/17 - 3s - loss: 0.3083 - AUC: 0.5533 - val_loss: 0.3129 - val_AUC: 0.7402 - 3s/epoch - 205ms/step
# Epoch 29/40
# 17/17 - 4s - loss: 0.3082 - AUC: 0.5482 - val_loss: 0.3280 - val_AUC: 0.6490 - 4s/epoch - 221ms/step
# Epoch 30/40
# 17/17 - 4s - loss: 0.3018 - AUC: 0.5905 - val_loss: 0.3125 - val_AUC: 0.7325 - 4s/epoch - 226ms/step
# Epoch 31/40
# 17/17 - 3s - loss: 0.3060 - AUC: 0.5730 - val_loss: 0.3143 - val_AUC: 0.7226 - 3s/epoch - 204ms/step
# Epoch 32/40
# 17/17 - 4s - loss: 0.3025 - AUC: 0.5881 - val_loss: 0.3110 - val_AUC: 0.7273 - 4s/epoch - 219ms/step
# Epoch 33/40
# 17/17 - 4s - loss: 0.3016 - AUC: 0.5929 - val_loss: 0.3050 - val_AUC: 0.7372 - 4s/epoch - 225ms/step
# Epoch 34/40
# 17/17 - 4s - loss: 0.2971 - AUC: 0.6246 - val_loss: 0.3101 - val_AUC: 0.7282 - 4s/epoch - 217ms/step
# Epoch 35/40
# 17/17 - 4s - loss: 0.3005 - AUC: 0.6104 - val_loss: 0.3052 - val_AUC: 0.7328 - 4s/epoch - 219ms/step
# Epoch 36/40
# 17/17 - 4s - loss: 0.2963 - AUC: 0.6337 - val_loss: 0.3216 - val_AUC: 0.6944 - 4s/epoch - 224ms/step
# Epoch 37/40
# 17/17 - 4s - loss: 0.3006 - AUC: 0.6188 - val_loss: 0.3120 - val_AUC: 0.7072 - 4s/epoch - 218ms/step
# Epoch 38/40
# 17/17 - 3s - loss: 0.3005 - AUC: 0.6103 - val_loss: 0.3141 - val_AUC: 0.7080 - 3s/epoch - 200ms/step
# Epoch 39/40
# 17/17 - 4s - loss: 0.2997 - AUC: 0.6230 - val_loss: 0.3073 - val_AUC: 0.7351 - 4s/epoch - 224ms/step
# Epoch 40/40
# 17/17 - 4s - loss: 0.2968 - AUC: 0.6321 - val_loss: 0.2997 - val_AUC: 0.7457 - 4s/epoch - 217ms/step
#
# (4) =======mental_and_behavioural_disorder=======
#
# Epoch 1/40
# 17/17 - 17s - loss: 0.1334 - AUC: 0.5285 - val_loss: 0.1130 - val_AUC: 0.5340 - 17s/epoch - 1s/step
# Epoch 2/40
# 17/17 - 4s - loss: 0.1132 - AUC: 0.5710 - val_loss: 0.1111 - val_AUC: 0.7030 - 4s/epoch - 230ms/step
# Epoch 3/40
# 17/17 - 3s - loss: 0.1127 - AUC: 0.5964 - val_loss: 0.1090 - val_AUC: 0.7632 - 3s/epoch - 199ms/step
# Epoch 4/40
# 17/17 - 3s - loss: 0.1125 - AUC: 0.6164 - val_loss: 0.1071 - val_AUC: 0.7632 - 3s/epoch - 201ms/step
# Epoch 5/40
# 17/17 - 4s - loss: 0.1116 - AUC: 0.6323 - val_loss: 0.1056 - val_AUC: 0.7910 - 4s/epoch - 221ms/step
# Epoch 6/40
# 17/17 - 3s - loss: 0.1105 - AUC: 0.6534 - val_loss: 0.1030 - val_AUC: 0.8175 - 3s/epoch - 202ms/step
# Epoch 7/40
# 17/17 - 3s - loss: 0.1093 - AUC: 0.6674 - val_loss: 0.0998 - val_AUC: 0.8252 - 3s/epoch - 200ms/step
# Epoch 8/40
# 17/17 - 4s - loss: 0.1088 - AUC: 0.6757 - val_loss: 0.0986 - val_AUC: 0.8281 - 4s/epoch - 225ms/step
# Epoch 9/40
# 17/17 - 4s - loss: 0.1084 - AUC: 0.6844 - val_loss: 0.0978 - val_AUC: 0.8437 - 4s/epoch - 206ms/step
# Epoch 10/40
# 17/17 - 3s - loss: 0.1079 - AUC: 0.6911 - val_loss: 0.0969 - val_AUC: 0.8493 - 3s/epoch - 200ms/step
# Epoch 11/40
# 17/17 - 3s - loss: 0.1076 - AUC: 0.6949 - val_loss: 0.0967 - val_AUC: 0.8506 - 3s/epoch - 201ms/step
# Epoch 12/40
# 17/17 - 4s - loss: 0.1069 - AUC: 0.6967 - val_loss: 0.0948 - val_AUC: 0.8412 - 4s/epoch - 227ms/step
# Epoch 13/40
# 17/17 - 3s - loss: 0.1068 - AUC: 0.7073 - val_loss: 0.0962 - val_AUC: 0.8534 - 3s/epoch - 201ms/step
# Epoch 14/40
# 17/17 - 3s - loss: 0.1058 - AUC: 0.7116 - val_loss: 0.0933 - val_AUC: 0.8480 - 3s/epoch - 201ms/step
# Epoch 15/40
# 17/17 - 4s - loss: 0.1063 - AUC: 0.7035 - val_loss: 0.0992 - val_AUC: 0.8650 - 4s/epoch - 229ms/step
# Epoch 16/40
# 17/17 - 3s - loss: 0.1046 - AUC: 0.7108 - val_loss: 0.0922 - val_AUC: 0.8619 - 3s/epoch - 202ms/step
# Epoch 17/40
# 17/17 - 3s - loss: 0.1055 - AUC: 0.6895 - val_loss: 0.1031 - val_AUC: 0.8619 - 3s/epoch - 201ms/step
# Epoch 18/40
# 17/17 - 4s - loss: 0.1036 - AUC: 0.7262 - val_loss: 0.0915 - val_AUC: 0.8613 - 4s/epoch - 233ms/step
# Epoch 19/40
# 17/17 - 3s - loss: 0.1071 - AUC: 0.6793 - val_loss: 0.1063 - val_AUC: 0.8178 - 3s/epoch - 200ms/step
# Epoch 20/40
# 17/17 - 3s - loss: 0.1082 - AUC: 0.6895 - val_loss: 0.0951 - val_AUC: 0.8511 - 3s/epoch - 201ms/step
# Epoch 21/40
# 17/17 - 4s - loss: 0.1032 - AUC: 0.7100 - val_loss: 0.0940 - val_AUC: 0.8534 - 4s/epoch - 210ms/step
# Epoch 22/40
# 17/17 - 4s - loss: 0.1078 - AUC: 0.7068 - val_loss: 0.0992 - val_AUC: 0.8315 - 4s/epoch - 229ms/step
# Epoch 23/40
# 17/17 - 4s - loss: 0.1056 - AUC: 0.7092 - val_loss: 0.0960 - val_AUC: 0.8374 - 4s/epoch - 221ms/step
# Epoch 24/40
# 17/17 - 4s - loss: 0.1123 - AUC: 0.6702 - val_loss: 0.1016 - val_AUC: 0.7950 - 4s/epoch - 208ms/step
# Epoch 25/40
# 17/17 - 3s - loss: 0.1077 - AUC: 0.6890 - val_loss: 0.0901 - val_AUC: 0.8699 - 3s/epoch - 202ms/step
# Epoch 26/40
# 17/17 - 3s - loss: 0.1104 - AUC: 0.6936 - val_loss: 0.0998 - val_AUC: 0.8295 - 3s/epoch - 201ms/step
# Epoch 27/40
# 17/17 - 4s - loss: 0.1033 - AUC: 0.7432 - val_loss: 0.0895 - val_AUC: 0.8429 - 4s/epoch - 208ms/step
# Epoch 28/40
# 17/17 - 3s - loss: 0.1092 - AUC: 0.7029 - val_loss: 0.1031 - val_AUC: 0.8149 - 3s/epoch - 201ms/step
# Epoch 29/40
# 17/17 - 3s - loss: 0.1056 - AUC: 0.7244 - val_loss: 0.0917 - val_AUC: 0.8716 - 3s/epoch - 201ms/step
# Epoch 30/40
# 17/17 - 4s - loss: 0.1079 - AUC: 0.7336 - val_loss: 0.1003 - val_AUC: 0.8289 - 4s/epoch - 207ms/step
# Epoch 31/40
# 17/17 - 3s - loss: 0.1071 - AUC: 0.7119 - val_loss: 0.0969 - val_AUC: 0.8669 - 3s/epoch - 203ms/step
# Epoch 32/40
# 17/17 - 3s - loss: 0.1050 - AUC: 0.7445 - val_loss: 0.0960 - val_AUC: 0.8633 - 3s/epoch - 205ms/step
# Epoch 33/40
# 17/17 - 4s - loss: 0.1054 - AUC: 0.7418 - val_loss: 0.0949 - val_AUC: 0.8994 - 4s/epoch - 213ms/step
# Epoch 34/40
# 17/17 - 3s - loss: 0.1034 - AUC: 0.7661 - val_loss: 0.0938 - val_AUC: 0.8695 - 3s/epoch - 203ms/step
# Epoch 35/40
# 17/17 - 3s - loss: 0.1020 - AUC: 0.7674 - val_loss: 0.0906 - val_AUC: 0.9014 - 3s/epoch - 205ms/step
# Epoch 36/40
# 17/17 - 4s - loss: 0.1016 - AUC: 0.7891 - val_loss: 0.0929 - val_AUC: 0.8892 - 4s/epoch - 235ms/step
# Epoch 37/40
# 17/17 - 3s - loss: 0.1022 - AUC: 0.7762 - val_loss: 0.0896 - val_AUC: 0.9020 - 3s/epoch - 204ms/step
# Epoch 38/40
# 17/17 - 3s - loss: 0.1022 - AUC: 0.7961 - val_loss: 0.0938 - val_AUC: 0.8927 - 3s/epoch - 204ms/step
# Epoch 39/40
# 17/17 - 4s - loss: 0.1017 - AUC: 0.7783 - val_loss: 0.0901 - val_AUC: 0.8769 - 4s/epoch - 230ms/step
# Epoch 40/40
# 17/17 - 3s - loss: 0.0992 - AUC: 0.7998 - val_loss: 0.0898 - val_AUC: 0.9101 - 3s/epoch - 202ms/step
#
# (5) =======nervous_system_disease=======
#
# Epoch 1/40
# 17/17 - 18s - loss: 0.3387 - AUC: 0.4751 - val_loss: 0.3327 - val_AUC: 0.4294 - 18s/epoch - 1s/step
# Epoch 2/40
# 17/17 - 3s - loss: 0.3005 - AUC: 0.5248 - val_loss: 0.3235 - val_AUC: 0.5537 - 3s/epoch - 204ms/step
# Epoch 3/40
# 17/17 - 3s - loss: 0.3000 - AUC: 0.5142 - val_loss: 0.3227 - val_AUC: 0.5763 - 3s/epoch - 205ms/step
# Epoch 4/40
# 17/17 - 4s - loss: 0.2994 - AUC: 0.5096 - val_loss: 0.3220 - val_AUC: 0.5959 - 4s/epoch - 208ms/step
# Epoch 5/40
# 17/17 - 3s - loss: 0.2986 - AUC: 0.5217 - val_loss: 0.3213 - val_AUC: 0.6036 - 3s/epoch - 199ms/step
# Epoch 6/40
# 17/17 - 4s - loss: 0.2981 - AUC: 0.5330 - val_loss: 0.3207 - val_AUC: 0.6055 - 4s/epoch - 208ms/step
# Epoch 7/40
# 17/17 - 4s - loss: 0.2977 - AUC: 0.5424 - val_loss: 0.3202 - val_AUC: 0.6074 - 4s/epoch - 215ms/step
# Epoch 8/40
# 17/17 - 3s - loss: 0.2972 - AUC: 0.5543 - val_loss: 0.3202 - val_AUC: 0.6097 - 3s/epoch - 203ms/step
# Epoch 9/40
# 17/17 - 4s - loss: 0.2963 - AUC: 0.5676 - val_loss: 0.3203 - val_AUC: 0.6213 - 4s/epoch - 208ms/step
# Epoch 10/40
# 17/17 - 4s - loss: 0.2951 - AUC: 0.5794 - val_loss: 0.3201 - val_AUC: 0.6187 - 4s/epoch - 208ms/step
# Epoch 11/40
# 17/17 - 3s - loss: 0.2938 - AUC: 0.5902 - val_loss: 0.3189 - val_AUC: 0.6310 - 3s/epoch - 201ms/step
# Epoch 12/40
# 17/17 - 4s - loss: 0.2926 - AUC: 0.5986 - val_loss: 0.3184 - val_AUC: 0.6364 - 4s/epoch - 208ms/step
# Epoch 13/40
# 17/17 - 3s - loss: 0.2917 - AUC: 0.6054 - val_loss: 0.3169 - val_AUC: 0.6428 - 3s/epoch - 205ms/step
# Epoch 14/40
# 17/17 - 3s - loss: 0.2910 - AUC: 0.6067 - val_loss: 0.3162 - val_AUC: 0.6479 - 3s/epoch - 200ms/step
# Epoch 15/40
# 17/17 - 3s - loss: 0.2905 - AUC: 0.6109 - val_loss: 0.3131 - val_AUC: 0.6541 - 3s/epoch - 200ms/step
# Epoch 16/40
# 17/17 - 4s - loss: 0.2900 - AUC: 0.6119 - val_loss: 0.3118 - val_AUC: 0.6555 - 4s/epoch - 217ms/step
# Epoch 17/40
# 17/17 - 3s - loss: 0.2895 - AUC: 0.6155 - val_loss: 0.3095 - val_AUC: 0.6746 - 3s/epoch - 201ms/step
# Epoch 18/40
# 17/17 - 3s - loss: 0.2886 - AUC: 0.6226 - val_loss: 0.3079 - val_AUC: 0.6658 - 3s/epoch - 199ms/step
# Epoch 19/40
# 17/17 - 4s - loss: 0.2874 - AUC: 0.6276 - val_loss: 0.3078 - val_AUC: 0.6838 - 4s/epoch - 216ms/step
# Epoch 20/40
# 17/17 - 3s - loss: 0.2870 - AUC: 0.6331 - val_loss: 0.3059 - val_AUC: 0.6804 - 3s/epoch - 202ms/step
# Epoch 21/40
# 17/17 - 3s - loss: 0.2863 - AUC: 0.6369 - val_loss: 0.3058 - val_AUC: 0.6873 - 3s/epoch - 203ms/step
# Epoch 22/40
# 17/17 - 4s - loss: 0.2850 - AUC: 0.6431 - val_loss: 0.3048 - val_AUC: 0.6808 - 4s/epoch - 220ms/step
# Epoch 23/40
# 17/17 - 3s - loss: 0.2845 - AUC: 0.6472 - val_loss: 0.3043 - val_AUC: 0.6927 - 3s/epoch - 205ms/step
# Epoch 24/40
# 17/17 - 3s - loss: 0.2843 - AUC: 0.6470 - val_loss: 0.3045 - val_AUC: 0.6964 - 3s/epoch - 200ms/step
# Epoch 25/40
# 17/17 - 4s - loss: 0.2844 - AUC: 0.6482 - val_loss: 0.3047 - val_AUC: 0.6975 - 4s/epoch - 214ms/step
# Epoch 26/40
# 17/17 - 3s - loss: 0.2836 - AUC: 0.6516 - val_loss: 0.3051 - val_AUC: 0.6993 - 3s/epoch - 205ms/step
# Epoch 27/40
# 17/17 - 3s - loss: 0.2838 - AUC: 0.6539 - val_loss: 0.3067 - val_AUC: 0.6944 - 3s/epoch - 204ms/step
# Epoch 28/40
# 17/17 - 3s - loss: 0.2836 - AUC: 0.6587 - val_loss: 0.3080 - val_AUC: 0.6941 - 3s/epoch - 205ms/step
# Epoch 29/40
# 17/17 - 4s - loss: 0.2840 - AUC: 0.6574 - val_loss: 0.3070 - val_AUC: 0.7018 - 4s/epoch - 218ms/step
# Epoch 30/40
# 17/17 - 3s - loss: 0.2831 - AUC: 0.6646 - val_loss: 0.3030 - val_AUC: 0.7126 - 3s/epoch - 203ms/step
# Epoch 31/40
# 17/17 - 3s - loss: 0.2811 - AUC: 0.6746 - val_loss: 0.2997 - val_AUC: 0.7199 - 3s/epoch - 205ms/step
# Epoch 32/40
# 17/17 - 4s - loss: 0.2795 - AUC: 0.6817 - val_loss: 0.3004 - val_AUC: 0.7089 - 4s/epoch - 211ms/step
# Epoch 33/40
# 17/17 - 3s - loss: 0.2855 - AUC: 0.6480 - val_loss: 0.3003 - val_AUC: 0.7010 - 3s/epoch - 201ms/step
# Epoch 34/40
# 17/17 - 4s - loss: 0.2820 - AUC: 0.6623 - val_loss: 0.2999 - val_AUC: 0.7086 - 4s/epoch - 207ms/step
# Epoch 35/40
# 17/17 - 4s - loss: 0.2786 - AUC: 0.6827 - val_loss: 0.2957 - val_AUC: 0.7248 - 4s/epoch - 213ms/step
# Epoch 36/40
# 17/17 - 3s - loss: 0.2763 - AUC: 0.6927 - val_loss: 0.2939 - val_AUC: 0.7231 - 3s/epoch - 202ms/step
# Epoch 37/40
# 17/17 - 3s - loss: 0.2752 - AUC: 0.6987 - val_loss: 0.2937 - val_AUC: 0.7238 - 3s/epoch - 202ms/step
# Epoch 38/40
# 17/17 - 4s - loss: 0.2779 - AUC: 0.6872 - val_loss: 0.2935 - val_AUC: 0.7279 - 4s/epoch - 207ms/step
# Epoch 39/40
# 17/17 - 4s - loss: 0.2724 - AUC: 0.7155 - val_loss: 0.2902 - val_AUC: 0.7432 - 4s/epoch - 207ms/step
# Epoch 40/40
# 17/17 - 3s - loss: 0.2728 - AUC: 0.7124 - val_loss: 0.2890 - val_AUC: 0.7432 - 3s/epoch - 202ms/step
#
# (6) =======skin_and_connective_tissue_disease=======
#
# Epoch 1/40
# 17/17 - 19s - loss: 0.0838 - AUC: 0.4173 - val_loss: 0.0179 - val_AUC: 0.4513 - 19s/epoch - 1s/step
# Epoch 2/40
# 17/17 - 3s - loss: 0.0233 - AUC: 0.5599 - val_loss: 0.0173 - val_AUC: 0.4939 - 3s/epoch - 198ms/step
# Epoch 3/40
# 17/17 - 3s - loss: 0.0233 - AUC: 0.4922 - val_loss: 0.0171 - val_AUC: 0.4915 - 3s/epoch - 200ms/step
# Epoch 4/40
# 17/17 - 4s - loss: 0.0228 - AUC: 0.4895 - val_loss: 0.0173 - val_AUC: 0.4891 - 4s/epoch - 209ms/step
# Epoch 5/40
# 17/17 - 3s - loss: 0.0229 - AUC: 0.4900 - val_loss: 0.0172 - val_AUC: 0.4903 - 3s/epoch - 199ms/step
# Epoch 6/40
# 17/17 - 3s - loss: 0.0229 - AUC: 0.4939 - val_loss: 0.0171 - val_AUC: 0.4939 - 3s/epoch - 203ms/step
# Epoch 7/40
# 17/17 - 3s - loss: 0.0228 - AUC: 0.4988 - val_loss: 0.0171 - val_AUC: 0.4988 - 3s/epoch - 202ms/step
# Epoch 8/40
# 17/17 - 3s - loss: 0.0228 - AUC: 0.5000 - val_loss: 0.0171 - val_AUC: 0.5000 - 3s/epoch - 198ms/step
# Epoch 9/40
# 17/17 - 3s - loss: 0.0228 - AUC: 0.5000 - val_loss: 0.0171 - val_AUC: 0.5000 - 3s/epoch - 200ms/step
# Epoch 10/40
# 17/17 - 4s - loss: 0.0228 - AUC: 0.4998 - val_loss: 0.0170 - val_AUC: 0.4976 - 4s/epoch - 211ms/step
# Epoch 11/40
# 17/17 - 3s - loss: 0.0228 - AUC: 0.4990 - val_loss: 0.0170 - val_AUC: 0.4842 - 3s/epoch - 196ms/step
# Epoch 12/40
# 17/17 - 3s - loss: 0.0228 - AUC: 0.4973 - val_loss: 0.0169 - val_AUC: 0.9623 - 3s/epoch - 198ms/step
# Epoch 13/40
# 17/17 - 4s - loss: 0.0227 - AUC: 0.4920 - val_loss: 0.0167 - val_AUC: 0.9392 - 4s/epoch - 211ms/step
# Epoch 14/40
# 17/17 - 4s - loss: 0.0227 - AUC: 0.4795 - val_loss: 0.0166 - val_AUC: 0.8564 - 4s/epoch - 208ms/step
# Epoch 15/40
# 17/17 - 3s - loss: 0.0226 - AUC: 0.5321 - val_loss: 0.0163 - val_AUC: 0.8029 - 3s/epoch - 200ms/step
# Epoch 16/40
# 17/17 - 3s - loss: 0.0225 - AUC: 0.5143 - val_loss: 0.0161 - val_AUC: 0.9659 - 3s/epoch - 198ms/step
# Epoch 17/40
# 17/17 - 4s - loss: 0.0225 - AUC: 0.5768 - val_loss: 0.0156 - val_AUC: 0.9793 - 4s/epoch - 209ms/step
# Epoch 18/40
# 17/17 - 3s - loss: 0.0222 - AUC: 0.6409 - val_loss: 0.0151 - val_AUC: 0.9830 - 3s/epoch - 199ms/step
# Epoch 19/40
# 17/17 - 3s - loss: 0.0221 - AUC: 0.6477 - val_loss: 0.0146 - val_AUC: 0.9891 - 3s/epoch - 199ms/step
# Epoch 20/40
# 17/17 - 4s - loss: 0.0218 - AUC: 0.7251 - val_loss: 0.0139 - val_AUC: 0.9915 - 4s/epoch - 206ms/step
# Epoch 21/40
# 17/17 - 3s - loss: 0.0212 - AUC: 0.7252 - val_loss: 0.0130 - val_AUC: 0.9951 - 3s/epoch - 199ms/step
# Epoch 22/40
# 17/17 - 3s - loss: 0.0209 - AUC: 0.7434 - val_loss: 0.0125 - val_AUC: 0.9951 - 3s/epoch - 201ms/step
# Epoch 23/40
# 17/17 - 4s - loss: 0.0207 - AUC: 0.7497 - val_loss: 0.0118 - val_AUC: 0.9951 - 4s/epoch - 206ms/step
# Epoch 24/40
# 17/17 - 3s - loss: 0.0201 - AUC: 0.7544 - val_loss: 0.0101 - val_AUC: 0.9951 - 3s/epoch - 199ms/step
# Epoch 25/40
# 17/17 - 3s - loss: 0.0194 - AUC: 0.7524 - val_loss: 0.0093 - val_AUC: 0.9939 - 3s/epoch - 200ms/step
# Epoch 26/40
# 17/17 - 3s - loss: 0.0197 - AUC: 0.7574 - val_loss: 0.0118 - val_AUC: 0.9951 - 3s/epoch - 204ms/step
# Epoch 27/40
# 17/17 - 3s - loss: 0.0203 - AUC: 0.7587 - val_loss: 0.0104 - val_AUC: 0.9939 - 3s/epoch - 199ms/step
# Epoch 28/40
# 17/17 - 3s - loss: 0.0193 - AUC: 0.7586 - val_loss: 0.0084 - val_AUC: 0.9964 - 3s/epoch - 198ms/step
# Epoch 29/40
# 17/17 - 4s - loss: 0.0187 - AUC: 0.6999 - val_loss: 0.0085 - val_AUC: 1.0000 - 4s/epoch - 214ms/step
# Epoch 30/40
# 17/17 - 3s - loss: 0.0196 - AUC: 0.7625 - val_loss: 0.0105 - val_AUC: 1.0000 - 3s/epoch - 199ms/step
# Epoch 31/40
# 17/17 - 3s - loss: 0.0191 - AUC: 0.7629 - val_loss: 0.0077 - val_AUC: 1.0000 - 3s/epoch - 200ms/step
# Epoch 32/40
# 17/17 - 3s - loss: 0.0181 - AUC: 0.7005 - val_loss: 0.0077 - val_AUC: 1.0000 - 3s/epoch - 201ms/step
# Epoch 33/40
# 17/17 - 4s - loss: 0.0198 - AUC: 0.7633 - val_loss: 0.0127 - val_AUC: 1.0000 - 4s/epoch - 211ms/step
# Epoch 34/40
# 17/17 - 3s - loss: 0.0195 - AUC: 0.7604 - val_loss: 0.0070 - val_AUC: 1.0000 - 3s/epoch - 200ms/step
# Epoch 35/40
# 17/17 - 3s - loss: 0.0177 - AUC: 0.7044 - val_loss: 0.0068 - val_AUC: 1.0000 - 3s/epoch - 199ms/step
# Epoch 36/40
# 17/17 - 4s - loss: 0.0205 - AUC: 0.6966 - val_loss: 0.0123 - val_AUC: 1.0000 - 4s/epoch - 208ms/step
# Epoch 37/40
# 17/17 - 3s - loss: 0.0195 - AUC: 0.7551 - val_loss: 0.0066 - val_AUC: 1.0000 - 3s/epoch - 200ms/step
# Epoch 38/40
# 17/17 - 3s - loss: 0.0183 - AUC: 0.7008 - val_loss: 0.0078 - val_AUC: 1.0000 - 3s/epoch - 201ms/step
# Epoch 39/40
# 17/17 - 4s - loss: 0.0189 - AUC: 0.7645 - val_loss: 0.0078 - val_AUC: 1.0000 - 4s/epoch - 213ms/step
# Epoch 40/40
# 17/17 - 3s - loss: 0.0177 - AUC: 0.7683 - val_loss: 0.0069 - val_AUC: 1.0000 - 3s/epoch - 201ms/step
#
# (7) =======urinary_system_disease=======
#
# Epoch 1/40
# 17/17 - 17s - loss: 0.1642 - AUC: 0.4908 - val_loss: 0.1982 - val_AUC: 0.5151 - 17s/epoch - 1s/step
# Epoch 2/40
# 17/17 - 3s - loss: 0.1413 - AUC: 0.4014 - val_loss: 0.2021 - val_AUC: 0.5100 - 3s/epoch - 205ms/step
# Epoch 3/40
# 17/17 - 3s - loss: 0.1229 - AUC: 0.5551 - val_loss: 0.1882 - val_AUC: 0.5084 - 3s/epoch - 204ms/step
# Epoch 4/40
# 17/17 - 4s - loss: 0.1265 - AUC: 0.4243 - val_loss: 0.1912 - val_AUC: 0.4833 - 4s/epoch - 213ms/step
# Epoch 5/40
# 17/17 - 3s - loss: 0.1259 - AUC: 0.4508 - val_loss: 0.1904 - val_AUC: 0.4940 - 3s/epoch - 205ms/step
# Epoch 6/40
# 17/17 - 3s - loss: 0.1264 - AUC: 0.4540 - val_loss: 0.1888 - val_AUC: 0.5607 - 3s/epoch - 201ms/step
# Epoch 7/40
# 17/17 - 4s - loss: 0.1269 - AUC: 0.4908 - val_loss: 0.1862 - val_AUC: 0.5994 - 4s/epoch - 208ms/step
# Epoch 8/40
# 17/17 - 4s - loss: 0.1257 - AUC: 0.4830 - val_loss: 0.1850 - val_AUC: 0.6286 - 4s/epoch - 215ms/step
# Epoch 9/40
# 17/17 - 4s - loss: 0.1254 - AUC: 0.5399 - val_loss: 0.1809 - val_AUC: 0.6628 - 4s/epoch - 207ms/step
# Epoch 10/40
# 17/17 - 3s - loss: 0.1258 - AUC: 0.5140 - val_loss: 0.1812 - val_AUC: 0.6764 - 3s/epoch - 203ms/step
# Epoch 11/40
# 17/17 - 4s - loss: 0.1236 - AUC: 0.5144 - val_loss: 0.1794 - val_AUC: 0.6153 - 4s/epoch - 213ms/step
# Epoch 12/40
# 17/17 - 4s - loss: 0.1239 - AUC: 0.5185 - val_loss: 0.1789 - val_AUC: 0.6280 - 4s/epoch - 207ms/step
# Epoch 13/40
# 17/17 - 4s - loss: 0.1241 - AUC: 0.5139 - val_loss: 0.1801 - val_AUC: 0.6353 - 4s/epoch - 209ms/step
# Epoch 14/40
# 17/17 - 4s - loss: 0.1331 - AUC: 0.4414 - val_loss: 0.1972 - val_AUC: 0.5404 - 4s/epoch - 211ms/step
# Epoch 15/40
# 17/17 - 4s - loss: 0.1225 - AUC: 0.5660 - val_loss: 0.1819 - val_AUC: 0.5404 - 4s/epoch - 206ms/step
# Epoch 16/40
# 17/17 - 3s - loss: 0.1234 - AUC: 0.4439 - val_loss: 0.1839 - val_AUC: 0.5498 - 3s/epoch - 205ms/step
# Epoch 17/40
# 17/17 - 3s - loss: 0.1220 - AUC: 0.4578 - val_loss: 0.1824 - val_AUC: 0.5670 - 3s/epoch - 204ms/step
# Epoch 18/40
# 17/17 - 4s - loss: 0.1222 - AUC: 0.4678 - val_loss: 0.1817 - val_AUC: 0.5386 - 4s/epoch - 211ms/step
# Epoch 19/40
# 17/17 - 4s - loss: 0.1264 - AUC: 0.4788 - val_loss: 0.1812 - val_AUC: 0.5433 - 4s/epoch - 216ms/step
# Epoch 20/40
# 17/17 - 4s - loss: 0.1239 - AUC: 0.4685 - val_loss: 0.1870 - val_AUC: 0.5986 - 4s/epoch - 206ms/step
# Epoch 21/40
# 17/17 - 3s - loss: 0.1241 - AUC: 0.4663 - val_loss: 0.1845 - val_AUC: 0.5553 - 3s/epoch - 205ms/step
# Epoch 22/40
# 17/17 - 3s - loss: 0.1272 - AUC: 0.5005 - val_loss: 0.1830 - val_AUC: 0.5599 - 3s/epoch - 204ms/step
# Epoch 23/40
# 17/17 - 3s - loss: 0.1236 - AUC: 0.4827 - val_loss: 0.1864 - val_AUC: 0.6161 - 3s/epoch - 204ms/step
# Epoch 24/40
# 17/17 - 3s - loss: 0.1239 - AUC: 0.4608 - val_loss: 0.1848 - val_AUC: 0.5300 - 3s/epoch - 201ms/step
# Epoch 25/40
# 17/17 - 4s - loss: 0.1215 - AUC: 0.5305 - val_loss: 0.1820 - val_AUC: 0.5400 - 4s/epoch - 207ms/step
# Epoch 26/40
# 17/17 - 4s - loss: 0.1224 - AUC: 0.4908 - val_loss: 0.1831 - val_AUC: 0.5948 - 4s/epoch - 214ms/step
# Epoch 27/40
# 17/17 - 3s - loss: 0.1211 - AUC: 0.5231 - val_loss: 0.1818 - val_AUC: 0.6011 - 3s/epoch - 202ms/step
# Epoch 28/40
# 17/17 - 4s - loss: 0.1208 - AUC: 0.5336 - val_loss: 0.1803 - val_AUC: 0.5972 - 4s/epoch - 206ms/step
# Epoch 29/40
# 17/17 - 4s - loss: 0.1204 - AUC: 0.5450 - val_loss: 0.1792 - val_AUC: 0.5958 - 4s/epoch - 216ms/step
# Epoch 30/40
# 17/17 - 3s - loss: 0.1203 - AUC: 0.5561 - val_loss: 0.1778 - val_AUC: 0.6560 - 3s/epoch - 206ms/step
# Epoch 31/40
# 17/17 - 3s - loss: 0.1203 - AUC: 0.5641 - val_loss: 0.1768 - val_AUC: 0.6506 - 3s/epoch - 202ms/step
# Epoch 32/40
# 17/17 - 4s - loss: 0.1203 - AUC: 0.5794 - val_loss: 0.1761 - val_AUC: 0.6489 - 4s/epoch - 211ms/step
# Epoch 33/40
# 17/17 - 3s - loss: 0.1202 - AUC: 0.5816 - val_loss: 0.1757 - val_AUC: 0.6635 - 3s/epoch - 202ms/step
# Epoch 34/40
# 17/17 - 3s - loss: 0.1200 - AUC: 0.5840 - val_loss: 0.1752 - val_AUC: 0.6703 - 3s/epoch - 202ms/step
# Epoch 35/40
# 17/17 - 4s - loss: 0.1196 - AUC: 0.5857 - val_loss: 0.1745 - val_AUC: 0.6712 - 4s/epoch - 214ms/step
# Epoch 36/40
# 17/17 - 3s - loss: 0.1195 - AUC: 0.5819 - val_loss: 0.1740 - val_AUC: 0.6930 - 3s/epoch - 206ms/step
# Epoch 37/40
# 17/17 - 3s - loss: 0.1193 - AUC: 0.5881 - val_loss: 0.1735 - val_AUC: 0.6886 - 3s/epoch - 201ms/step
# Epoch 38/40
# 17/17 - 4s - loss: 0.1189 - AUC: 0.5976 - val_loss: 0.1729 - val_AUC: 0.7116 - 4s/epoch - 208ms/step
# Epoch 39/40
# 17/17 - 3s - loss: 0.1187 - AUC: 0.5996 - val_loss: 0.1724 - val_AUC: 0.7209 - 3s/epoch - 205ms/step
# Epoch 40/40
# 17/17 - 3s - loss: 0.1184 - AUC: 0.6009 - val_loss: 0.1721 - val_AUC: 0.7106 - 3s/epoch - 205ms/step

# %%
disease_pipeline.predict([df.iloc[133].Smiles]), df.iloc[133].Disease
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# ({'immune_system_disease': array([[0.7407007]], dtype=float32),
#   'metabolic_disease': array([[0.00563587]], dtype=float32),
#   'digestive_system_disease': array([[0.74404716]], dtype=float32),
#   'cardiovascular_disease': array([[0.06825662]], dtype=float32),
#   'mental_and_behavioural_disorder': array([[0.0023428]], dtype=float32),
#   'nervous_system_disease': array([[0.01584791]], dtype=float32),
#   'skin_and_connective_tissue_disease': array([[0.00207462]], dtype=float32),
#   'urinary_system_disease': array([[0.01593268]], dtype=float32)},
#  'immune_system_disease')

# %%
for model in disease_pipeline.models:
  with open(f'./drive/MyDrive/Models/{model}', 'wb') as f:
    pickle.dump(disease_pipeline.models[model], f)

# %%
# !ls ./drive/MyDrive/Models
# Out:
# cardiovascular_disease		 metabolic_disease
# digestive_system_disease	 nervous_system_disease
# immune_system_disease		 skin_and_connective_tissue_disease
# mental_and_behavioural_disorder  urinary_system_disease
